# %%
#https://sourceforge.net/projects/swig/files/swigwin/swigwin-4.0.2/swigwin-4.0.2.zip/download?use_mirror=ixpeering

# %% [markdown]
# # 1. Import Dependencies

# %%
# Gymnasium imports
import gymnasium as gym 
from gymnasium import Env
from gymnasium.spaces import Discrete, Box, Dict, Tuple, MultiBinary, MultiDiscrete 

# Import helpers
import numpy as np
import random
import os

# Import stable baselines
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# # 2. Types of Spaces

# %%
# Discrete space with three different values
Discrete(3)
# Out:
# Discrete(3)

# %%
# Box space with 3x3 shape
Box(0,1,shape=(3,3)).sample()

# %%
Box(0,255,shape=(3,3), dtype=int).sample()
# Out:
# array([[ 43, 172,  95],
#        [222, 130,  79],
#        [215, 165,  98]])

# %%
# Not supported by stable baselines
# Combination of differet spaces
Tuple((Discrete(2), Box(0,100, shape=(1,)))).sample()
# Out:
# (0, array([46.0833], dtype=float32))

# %%
# Not supported by stable baselines
# Combination of different spaces with keywords
# Most likely the one I will use
Dict({'height':Discrete(2), "speed":Box(0,100, shape=(1,))}).sample()
# Out:
# OrderedDict([('height', 1), ('speed', array([65.581764], dtype=float32))])

# %%
# Binary set of values
MultiBinary(4).sample()
# Out:
# array([0, 0, 1, 0], dtype=int8)

# %%
# Discrete set of values
MultiDiscrete([5,2,2]).sample()
# Out:
# array([3, 0, 1])

# %% [markdown]
# # 3. Building an Environment

# %%
# Build an agent that gives the best shower possible

class ShowerEnv(Env):
    def __init__(self):
        # Actions we can take, down, stay, up
        self.action_space = Discrete(3)
        # Temperature array
        self.observation_space = Box(low=np.array([0]), high=np.array([100]))
        # Set start temp
        self.state = 38 + random.randint(-3,3)
        # Set shower length
        self.shower_length = 60
        
    def step(self, action):
        # Apply action
        # 0 -1 = -1 temperature
        # 1 -1 = 0 
        # 2 -1 = 1 temperature 
        self.state += action - 1 
        # Reduce shower length by 1 second
        self.shower_length -= 1 
        
        # Calculate reward
        if self.state >= 37 and self.state <= 39: 
            reward = 1 
        else: 
            reward = -1 
        
        # Check if shower is done
        if self.shower_length <= 0: 
            done = True
        else:
            done = False
        
        # Apply temperature noise
        #self.state += random.randint(-1,1)
        # Set placeholder for info
        info = {}

        truncated = False

        obs = np.array([self.state], dtype=np.float32)
        
        # Return step information
        return obs, reward, done, truncated, info

    def render(self):
        # Implement viz
        pass
    
    # def reset(self, seed = None):
    #     # Reset shower temperature
    #     self.state = np.array([38 + random.randint(-3,3)]).astype(float)
    #     # Reset shower time
    #     self.shower_length = 60 
    #     return self.state

    def reset(self, seed=None):
        # Handle the seed
        super().reset(seed=seed)
        if seed is not None:
            np.random.seed(seed)
            random.seed(seed)
        # Reset shower temperature
        self.state = 38 + random.randint(-3, 3)

        obs = np.array([self.state], dtype=np.float32)

        # Reset shower time
        self.shower_length = 60

        info = {}

        return obs, info

# %%
env = ShowerEnv()

# %%
env.observation_space.sample()
# Out:
# array([29.095186], dtype=float32)

# %%
env.reset()
# Out:
# (array([38.], dtype=float32), {})

# %%
from stable_baselines3.common.env_checker import check_env

# %%
check_env(env, warn=True)

# %% [markdown]
# # 4. Test Environment

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        action = env.action_space.sample()
        n_state, reward, done, info, _ = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
# Out:
# Episode:1 Score:-24
# Episode:2 Score:0
# Episode:3 Score:12
# Episode:4 Score:-30
# Episode:5 Score:-12

# %% [markdown]
# # 5. Train Model

# %%
log_path = os.path.join('Logs')

# %%
model = PPO("MlpPolicy", env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=400000)
# Out:
# Logging to Logs/PPO_2
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | -22.9    |
# | time/              |          |
# |    fps             | 7188     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -11.1        |
# | time/                   |              |
# |    fps                  | 4146         |
# |    iterations           | 2            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0071394052 |
# |    clip_fraction        | 0.157        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.895       |
# |    explained_variance   | 0.00026      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 31.8         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.0122      |
# |    value_loss           | 70.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -11.5        |
# | time/                   |              |
# |    fps                  | 3628         |
# |    iterations           | 3            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0051522255 |
# |    clip_fraction        | 0.0588       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.876       |
# |    explained_variance   | -0.000864    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 31           |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.000797    |
# |    value_loss           | 71.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -4.8        |
# | time/                   |             |
# |    fps                  | 3444        |
# |    iterations           | 4           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.005054053 |
# |    clip_fraction        | 0.0949      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.871      |
# |    explained_variance   | -0.00349    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.1        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00389    |
# |    value_loss           | 69.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -2.28        |
# | time/                   |              |
# |    fps                  | 3333         |
# |    iterations           | 5            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0046428274 |
# |    clip_fraction        | 0.0996       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.867       |
# |    explained_variance   | -0.00643     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 32.2         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00291     |
# |    value_loss           | 53.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 5.84         |
# | time/                   |              |
# |    fps                  | 3278         |
# |    iterations           | 6            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0057540354 |
# |    clip_fraction        | 0.077        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.863       |
# |    explained_variance   | -5.28e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 23.9         |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -4.46e-06    |
# |    value_loss           | 57.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 10.3        |
# | time/                   |             |
# |    fps                  | 3234        |
# |    iterations           | 7           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.014643952 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.863      |
# |    explained_variance   | 0.00347     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.8        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00171    |
# |    value_loss           | 44.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 13.7         |
# | time/                   |              |
# |    fps                  | 3208         |
# |    iterations           | 8            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0069093094 |
# |    clip_fraction        | 0.121        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.863       |
# |    explained_variance   | -0.0235      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 25           |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00667     |
# |    value_loss           | 56.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 16.3        |
# | time/                   |             |
# |    fps                  | 3180        |
# |    iterations           | 9           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.013870843 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.854      |
# |    explained_variance   | -0.000794   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.6        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0115     |
# |    value_loss           | 56.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 18.9         |
# | time/                   |              |
# |    fps                  | 3155         |
# |    iterations           | 10           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0053845607 |
# |    clip_fraction        | 0.117        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.823       |
# |    explained_variance   | 0.000113     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.7         |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00654     |
# |    value_loss           | 52.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 24.3        |
# | time/                   |             |
# |    fps                  | 3133        |
# |    iterations           | 11          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.006438936 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.798      |
# |    explained_variance   | 6.01e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.5        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00216    |
# |    value_loss           | 59.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 27          |
# | time/                   |             |
# |    fps                  | 3031        |
# |    iterations           | 12          |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.008297851 |
# |    clip_fraction        | 0.0996      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.789      |
# |    explained_variance   | -1.91e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.1        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | 0.000907    |
# |    value_loss           | 49.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 27.2         |
# | time/                   |              |
# |    fps                  | 3025         |
# |    iterations           | 13           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0034619016 |
# |    clip_fraction        | 0.107        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.801       |
# |    explained_variance   | -0.000178    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24.8         |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.000591    |
# |    value_loss           | 50.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 30.3        |
# | time/                   |             |
# |    fps                  | 3020        |
# |    iterations           | 14          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.013520095 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.811      |
# |    explained_variance   | -0.000264   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34          |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.008      |
# |    value_loss           | 64.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 32.7         |
# | time/                   |              |
# |    fps                  | 3015         |
# |    iterations           | 15           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0073269885 |
# |    clip_fraction        | 0.0982       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.803       |
# |    explained_variance   | -1.13e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21.6         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | 0.00241      |
# |    value_loss           | 52.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 38.3         |
# | time/                   |              |
# |    fps                  | 3007         |
# |    iterations           | 16           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0076527363 |
# |    clip_fraction        | 0.142        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.834       |
# |    explained_variance   | 6.48e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 33.2         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00015     |
# |    value_loss           | 67.5         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 40.2       |
# | time/                   |            |
# |    fps                  | 3003       |
# |    iterations           | 17         |
# |    time_elapsed         | 11         |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.00952041 |
# |    clip_fraction        | 0.146      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.846     |
# |    explained_variance   | 7.18e-05   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 31         |
# |    n_updates            | 360        |
# |    policy_gradient_loss | -0.00247   |
# |    value_loss           | 64.4       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 42.7        |
# | time/                   |             |
# |    fps                  | 2999        |
# |    iterations           | 18          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.008557216 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.838      |
# |    explained_variance   | 5.63e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.4        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.000305   |
# |    value_loss           | 69.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 44.3        |
# | time/                   |             |
# |    fps                  | 2992        |
# |    iterations           | 19          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.004061533 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.832      |
# |    explained_variance   | -8.34e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 42          |
# |    n_updates            | 380         |
# |    policy_gradient_loss | 0.00547     |
# |    value_loss           | 72.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 46.6        |
# | time/                   |             |
# |    fps                  | 2992        |
# |    iterations           | 20          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.009435222 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.842      |
# |    explained_variance   | -1.28e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.3        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | 0.004       |
# |    value_loss           | 73.9        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 43.9       |
# | time/                   |            |
# |    fps                  | 2990       |
# |    iterations           | 21         |
# |    time_elapsed         | 14         |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.01571067 |
# |    clip_fraction        | 0.13       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.869     |
# |    explained_variance   | -8.34e-06  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 32.9       |
# |    n_updates            | 400        |
# |    policy_gradient_loss | 0.00418    |
# |    value_loss           | 77.8       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 42.7        |
# | time/                   |             |
# |    fps                  | 2991        |
# |    iterations           | 22          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.015813142 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.89       |
# |    explained_variance   | -1.23e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 48.4        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00636    |
# |    value_loss           | 86.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 41.4        |
# | time/                   |             |
# |    fps                  | 2988        |
# |    iterations           | 23          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.006692053 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.872      |
# |    explained_variance   | -1.11e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28          |
# |    n_updates            | 420         |
# |    policy_gradient_loss | 0.00399     |
# |    value_loss           | 77.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 45.3         |
# | time/                   |              |
# |    fps                  | 2986         |
# |    iterations           | 24           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0077954624 |
# |    clip_fraction        | 0.165        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.867       |
# |    explained_variance   | 3.46e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 40.2         |
# |    n_updates            | 430          |
# |    policy_gradient_loss | 0.0104       |
# |    value_loss           | 73.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 48.4        |
# | time/                   |             |
# |    fps                  | 2985        |
# |    iterations           | 25          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.011986078 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.89       |
# |    explained_variance   | -5.01e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.4        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | 0.00948     |
# |    value_loss           | 75.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 2986        |
# |    iterations           | 26          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.014909701 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.896      |
# |    explained_variance   | 2.15e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 38.2        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | 0.0153      |
# |    value_loss           | 85.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 2986        |
# |    iterations           | 27          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.011532757 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.89       |
# |    explained_variance   | 9.54e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 40.7        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | 0.0067      |
# |    value_loss           | 88.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 50.6        |
# | time/                   |             |
# |    fps                  | 2987        |
# |    iterations           | 28          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.010050675 |
# |    clip_fraction        | 0.221       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.881      |
# |    explained_variance   | -1.07e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24          |
# |    n_updates            | 470         |
# |    policy_gradient_loss | 0.0134      |
# |    value_loss           | 88.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 49.9        |
# | time/                   |             |
# |    fps                  | 2986        |
# |    iterations           | 29          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.005085172 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.895      |
# |    explained_variance   | -2.86e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 52.9        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | 0.0116      |
# |    value_loss           | 96.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 49.6        |
# | time/                   |             |
# |    fps                  | 2986        |
# |    iterations           | 30          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.011939076 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.908      |
# |    explained_variance   | -4.17e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 58.6        |
# |    n_updates            | 490         |
# |    policy_gradient_loss | 0.0045      |
# |    value_loss           | 101         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 48.4        |
# | time/                   |             |
# |    fps                  | 2984        |
# |    iterations           | 31          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.028854433 |
# |    clip_fraction        | 0.276       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.915      |
# |    explained_variance   | -1.79e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 46.9        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | 0.0189      |
# |    value_loss           | 94          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 49.1        |
# | time/                   |             |
# |    fps                  | 2984        |
# |    iterations           | 32          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.018504778 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.912      |
# |    explained_variance   | 1.97e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.7        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | 0.00973     |
# |    value_loss           | 88.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 49          |
# | time/                   |             |
# |    fps                  | 2983        |
# |    iterations           | 33          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.028001297 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.926      |
# |    explained_variance   | 3.04e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.4        |
# |    n_updates            | 520         |
# |    policy_gradient_loss | 0.00881     |
# |    value_loss           | 93.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 50.4        |
# | time/                   |             |
# |    fps                  | 2981        |
# |    iterations           | 34          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.017745022 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.923      |
# |    explained_variance   | 2.38e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 55.4        |
# |    n_updates            | 530         |
# |    policy_gradient_loss | 0.0112      |
# |    value_loss           | 94.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 51.9        |
# | time/                   |             |
# |    fps                  | 2977        |
# |    iterations           | 35          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.016042253 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.913      |
# |    explained_variance   | 2.98e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 42.4        |
# |    n_updates            | 540         |
# |    policy_gradient_loss | 0.0132      |
# |    value_loss           | 95.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 52.6        |
# | time/                   |             |
# |    fps                  | 2976        |
# |    iterations           | 36          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.024258375 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.893      |
# |    explained_variance   | 4.77e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 42.8        |
# |    n_updates            | 550         |
# |    policy_gradient_loss | 0.0132      |
# |    value_loss           | 94.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 52.4        |
# | time/                   |             |
# |    fps                  | 2971        |
# |    iterations           | 37          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.026420671 |
# |    clip_fraction        | 0.269       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.895      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 55.4        |
# |    n_updates            | 560         |
# |    policy_gradient_loss | 0.0183      |
# |    value_loss           | 101         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 52.1        |
# | time/                   |             |
# |    fps                  | 2965        |
# |    iterations           | 38          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.014014141 |
# |    clip_fraction        | 0.248       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.869      |
# |    explained_variance   | 1.37e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 45.2        |
# |    n_updates            | 570         |
# |    policy_gradient_loss | 0.0139      |
# |    value_loss           | 102         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 52.3        |
# | time/                   |             |
# |    fps                  | 2965        |
# |    iterations           | 39          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.019131368 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.865      |
# |    explained_variance   | -3.58e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 45.4        |
# |    n_updates            | 580         |
# |    policy_gradient_loss | 0.0113      |
# |    value_loss           | 98.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 53.2        |
# | time/                   |             |
# |    fps                  | 2963        |
# |    iterations           | 40          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.013191673 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.828      |
# |    explained_variance   | 1.01e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 51.5        |
# |    n_updates            | 590         |
# |    policy_gradient_loss | 0.00693     |
# |    value_loss           | 100         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 50.3       |
# | time/                   |            |
# |    fps                  | 2958       |
# |    iterations           | 41         |
# |    time_elapsed         | 28         |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.01168089 |
# |    clip_fraction        | 0.202      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.849     |
# |    explained_variance   | 1.85e-06   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 45.2       |
# |    n_updates            | 600        |
# |    policy_gradient_loss | 0.0109     |
# |    value_loss           | 102        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 44.7       |
# | time/                   |            |
# |    fps                  | 2939       |
# |    iterations           | 42         |
# |    time_elapsed         | 29         |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.01611515 |
# |    clip_fraction        | 0.177      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.845     |
# |    explained_variance   | 3.58e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 45.8       |
# |    n_updates            | 610        |
# |    policy_gradient_loss | 0.011      |
# |    value_loss           | 93.7       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 40.8        |
# | time/                   |             |
# |    fps                  | 2939        |
# |    iterations           | 43          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.008030185 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.837      |
# |    explained_variance   | 1.64e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 46.6        |
# |    n_updates            | 620         |
# |    policy_gradient_loss | 0.00476     |
# |    value_loss           | 84.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 41.9        |
# | time/                   |             |
# |    fps                  | 2937        |
# |    iterations           | 44          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.013225399 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.834      |
# |    explained_variance   | 0.000383    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 39.3        |
# |    n_updates            | 630         |
# |    policy_gradient_loss | 0.00132     |
# |    value_loss           | 78.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 45.5        |
# | time/                   |             |
# |    fps                  | 2916        |
# |    iterations           | 45          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.009252305 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.812      |
# |    explained_variance   | 0.00093     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.2        |
# |    n_updates            | 640         |
# |    policy_gradient_loss | -0.000407   |
# |    value_loss           | 82.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 48          |
# | time/                   |             |
# |    fps                  | 2917        |
# |    iterations           | 46          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.012042657 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.806      |
# |    explained_variance   | 0.000268    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35.7        |
# |    n_updates            | 650         |
# |    policy_gradient_loss | 0.00735     |
# |    value_loss           | 81.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 49.4        |
# | time/                   |             |
# |    fps                  | 2898        |
# |    iterations           | 47          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.013490453 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.784      |
# |    explained_variance   | 0.0006      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 46.6        |
# |    n_updates            | 660         |
# |    policy_gradient_loss | 0.00701     |
# |    value_loss           | 81.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 52          |
# | time/                   |             |
# |    fps                  | 2876        |
# |    iterations           | 48          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.011316073 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.796      |
# |    explained_variance   | 0.00017     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 54.2        |
# |    n_updates            | 670         |
# |    policy_gradient_loss | 0.013       |
# |    value_loss           | 85.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 53.1        |
# | time/                   |             |
# |    fps                  | 2871        |
# |    iterations           | 49          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.017494293 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.798      |
# |    explained_variance   | 0.000178    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 49.3        |
# |    n_updates            | 680         |
# |    policy_gradient_loss | 0.0126      |
# |    value_loss           | 94.7        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 54.2       |
# | time/                   |            |
# |    fps                  | 2860       |
# |    iterations           | 50         |
# |    time_elapsed         | 35         |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.01842542 |
# |    clip_fraction        | 0.185      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.804     |
# |    explained_variance   | 4.05e-06   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 45.6       |
# |    n_updates            | 690        |
# |    policy_gradient_loss | 0.0141     |
# |    value_loss           | 94.4       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 53.6        |
# | time/                   |             |
# |    fps                  | 2863        |
# |    iterations           | 51          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.018685957 |
# |    clip_fraction        | 0.227       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.814      |
# |    explained_variance   | 1.07e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 66.4        |
# |    n_updates            | 700         |
# |    policy_gradient_loss | 0.014       |
# |    value_loss           | 99.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 54.7        |
# | time/                   |             |
# |    fps                  | 2865        |
# |    iterations           | 52          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.013148107 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.816      |
# |    explained_variance   | -1.73e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 40.6        |
# |    n_updates            | 710         |
# |    policy_gradient_loss | 0.0172      |
# |    value_loss           | 102         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 53.6        |
# | time/                   |             |
# |    fps                  | 2868        |
# |    iterations           | 53          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.018249206 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.851      |
# |    explained_variance   | 1.76e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 49.8        |
# |    n_updates            | 720         |
# |    policy_gradient_loss | 0.0142      |
# |    value_loss           | 107         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 54.1        |
# | time/                   |             |
# |    fps                  | 2870        |
# |    iterations           | 54          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.019372586 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.878      |
# |    explained_variance   | 8.64e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 51.4        |
# |    n_updates            | 730         |
# |    policy_gradient_loss | 0.00922     |
# |    value_loss           | 104         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 53.6        |
# | time/                   |             |
# |    fps                  | 2872        |
# |    iterations           | 55          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.014272503 |
# |    clip_fraction        | 0.232       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.875      |
# |    explained_variance   | 6.2e-06     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 51.2        |
# |    n_updates            | 740         |
# ...
# |    n_updates            | 1970        |
# |    policy_gradient_loss | 0.00808     |
# |    value_loss           | 106         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 49.1        |
# | time/                   |             |
# |    fps                  | 2876        |
# |    iterations           | 179         |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 366592      |
# | train/                  |             |
# |    approx_kl            | 0.013363447 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.488      |
# |    explained_variance   | -6.39e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 56.3        |
# |    n_updates            | 1980        |
# |    policy_gradient_loss | 0.012       |
# |    value_loss           | 95          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 51.1         |
# | time/                   |              |
# |    fps                  | 2876         |
# |    iterations           | 180          |
# |    time_elapsed         | 128          |
# |    total_timesteps      | 368640       |
# | train/                  |              |
# |    approx_kl            | 0.0060323663 |
# |    clip_fraction        | 0.0862       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.456       |
# |    explained_variance   | 2.26e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 55.8         |
# |    n_updates            | 1990         |
# |    policy_gradient_loss | 0.00668      |
# |    value_loss           | 94.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 55.7        |
# | time/                   |             |
# |    fps                  | 2875        |
# |    iterations           | 181         |
# |    time_elapsed         | 128         |
# |    total_timesteps      | 370688      |
# | train/                  |             |
# |    approx_kl            | 0.023394946 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.488      |
# |    explained_variance   | 5.9e-06     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 72.3        |
# |    n_updates            | 2000        |
# |    policy_gradient_loss | 0.0139      |
# |    value_loss           | 102         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 57.7        |
# | time/                   |             |
# |    fps                  | 2874        |
# |    iterations           | 182         |
# |    time_elapsed         | 129         |
# |    total_timesteps      | 372736      |
# | train/                  |             |
# |    approx_kl            | 0.010242749 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.485      |
# |    explained_variance   | -3.93e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 61.1        |
# |    n_updates            | 2010        |
# |    policy_gradient_loss | 0.00888     |
# |    value_loss           | 108         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 56.8        |
# | time/                   |             |
# |    fps                  | 2874        |
# |    iterations           | 183         |
# |    time_elapsed         | 130         |
# |    total_timesteps      | 374784      |
# | train/                  |             |
# |    approx_kl            | 0.012457745 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.497      |
# |    explained_variance   | -1.5e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 51.5        |
# |    n_updates            | 2020        |
# |    policy_gradient_loss | 0.0113      |
# |    value_loss           | 112         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 45.2       |
# | time/                   |            |
# |    fps                  | 2874       |
# |    iterations           | 184        |
# |    time_elapsed         | 131        |
# |    total_timesteps      | 376832     |
# | train/                  |            |
# |    approx_kl            | 0.04440673 |
# |    clip_fraction        | 0.131      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.519     |
# |    explained_variance   | -8.46e-06  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 65.3       |
# |    n_updates            | 2030       |
# |    policy_gradient_loss | 0.0146     |
# |    value_loss           | 112        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 37.9        |
# | time/                   |             |
# |    fps                  | 2874        |
# |    iterations           | 185         |
# |    time_elapsed         | 131         |
# |    total_timesteps      | 378880      |
# | train/                  |             |
# |    approx_kl            | 0.027953284 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.492      |
# |    explained_variance   | -5.21e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 42.9        |
# |    n_updates            | 2040        |
# |    policy_gradient_loss | -0.00694    |
# |    value_loss           | 110         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 37.8        |
# | time/                   |             |
# |    fps                  | 2870        |
# |    iterations           | 186         |
# |    time_elapsed         | 132         |
# |    total_timesteps      | 380928      |
# | train/                  |             |
# |    approx_kl            | 0.025567682 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.482      |
# |    explained_variance   | 0.000791    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 40.5        |
# |    n_updates            | 2050        |
# |    policy_gradient_loss | 0.00423     |
# |    value_loss           | 77.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 49.9        |
# | time/                   |             |
# |    fps                  | 2871        |
# |    iterations           | 187         |
# |    time_elapsed         | 133         |
# |    total_timesteps      | 382976      |
# | train/                  |             |
# |    approx_kl            | 0.012648192 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.478      |
# |    explained_variance   | 0.000139    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27          |
# |    n_updates            | 2060        |
# |    policy_gradient_loss | 0.0125      |
# |    value_loss           | 79.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 56.9        |
# | time/                   |             |
# |    fps                  | 2871        |
# |    iterations           | 188         |
# |    time_elapsed         | 134         |
# |    total_timesteps      | 385024      |
# | train/                  |             |
# |    approx_kl            | 0.017293353 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.478      |
# |    explained_variance   | 0.000254    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.4        |
# |    n_updates            | 2070        |
# |    policy_gradient_loss | 0.0127      |
# |    value_loss           | 91.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 58.3        |
# | time/                   |             |
# |    fps                  | 2872        |
# |    iterations           | 189         |
# |    time_elapsed         | 134         |
# |    total_timesteps      | 387072      |
# | train/                  |             |
# |    approx_kl            | 0.015341062 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.434      |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 52.5        |
# |    n_updates            | 2080        |
# |    policy_gradient_loss | 0.0097      |
# |    value_loss           | 104         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 58.7        |
# | time/                   |             |
# |    fps                  | 2873        |
# |    iterations           | 190         |
# |    time_elapsed         | 135         |
# |    total_timesteps      | 389120      |
# | train/                  |             |
# |    approx_kl            | 0.015523299 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.443      |
# |    explained_variance   | 1.32e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 54.5        |
# |    n_updates            | 2090        |
# |    policy_gradient_loss | 0.00894     |
# |    value_loss           | 110         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 58.6        |
# | time/                   |             |
# |    fps                  | 2873        |
# |    iterations           | 191         |
# |    time_elapsed         | 136         |
# |    total_timesteps      | 391168      |
# | train/                  |             |
# |    approx_kl            | 0.026765132 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.446      |
# |    explained_variance   | 1.31e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 47.2        |
# |    n_updates            | 2100        |
# |    policy_gradient_loss | 0.0113      |
# |    value_loss           | 115         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 58.5        |
# | time/                   |             |
# |    fps                  | 2873        |
# |    iterations           | 192         |
# |    time_elapsed         | 136         |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.011190657 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.492      |
# |    explained_variance   | 6.5e-06     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 50.7        |
# |    n_updates            | 2110        |
# |    policy_gradient_loss | 0.0181      |
# |    value_loss           | 117         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 58.4        |
# | time/                   |             |
# |    fps                  | 2873        |
# |    iterations           | 193         |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 395264      |
# | train/                  |             |
# |    approx_kl            | 0.009208994 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.492      |
# |    explained_variance   | -6.08e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 49          |
# |    n_updates            | 2120        |
# |    policy_gradient_loss | 0.0106      |
# |    value_loss           | 118         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 57.7       |
# | time/                   |            |
# |    fps                  | 2873       |
# |    iterations           | 194        |
# |    time_elapsed         | 138        |
# |    total_timesteps      | 397312     |
# | train/                  |            |
# |    approx_kl            | 0.01410141 |
# |    clip_fraction        | 0.142      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.493     |
# |    explained_variance   | 2.63e-05   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 73.7       |
# |    n_updates            | 2130       |
# |    policy_gradient_loss | 0.0131     |
# |    value_loss           | 121        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 57.7        |
# | time/                   |             |
# |    fps                  | 2874        |
# |    iterations           | 195         |
# |    time_elapsed         | 138         |
# |    total_timesteps      | 399360      |
# | train/                  |             |
# |    approx_kl            | 0.019257994 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.509      |
# |    explained_variance   | -2.88e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 42.3        |
# |    n_updates            | 2140        |
# |    policy_gradient_loss | 0.0103      |
# |    value_loss           | 121         |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 60        |
# |    ep_rew_mean          | 57.8      |
# | time/                   |           |
# |    fps                  | 2874      |
# |    iterations           | 196       |
# |    time_elapsed         | 139       |
# |    total_timesteps      | 401408    |
# | train/                  |           |
# |    approx_kl            | 0.0091295 |
# |    clip_fraction        | 0.128     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.492    |
# |    explained_variance   | -3.04e-05 |
# |    learning_rate        | 0.0003    |
# |    loss                 | 64.7      |
# |    n_updates            | 2150      |
# |    policy_gradient_loss | 0.0116    |
# |    value_loss           | 122       |
# ---------------------------------------

# %% [markdown]
# # 6. Save Model

# %%
save_path = os.path.join('Model', 'PPO')

model.save(save_path)

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=False)
# Out:
# (59.4, 0.9165151389911679)
