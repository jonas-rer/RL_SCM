# %% [markdown]
# **Importing Dependencies**

# %%
# Imports
# Gymnasium imports
import gymnasium as gym 
from gymnasium import Env
from gymnasium.spaces import Discrete, Box, Dict, Tuple, MultiBinary, MultiDiscrete 

import networkx as nx
from networkx.drawing.nx_agraph import graphviz_layout

# Import helpers
import numpy as np
import pandas as pd
import random
import os
import json
import matplotlib.pyplot as plt
import seaborn as sns

from collections import deque

# Import stable baselines
from stable_baselines3 import PPO, A2C
from stable_baselines3.common.vec_env import VecFrameStack, DummyVecEnv
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.evaluation import evaluate_policy

from Environment.env_v6 import *
from Functions.visualization_functions import *

# %% [markdown]
# **Configuration of the Scenario**

# %%
# Configuration of the network
with open('./Config/network_config_v0.json') as file:
    network_config = file.read()

# TODO : Implement configuaration for cost and demand (actual and exptected)

# %% [markdown]
# **Building the environment**

# %%
EP_LENGTH = 30 # Length of the episode

env = SS_Mngmt_Env(network_config=network_config,
                   EP_LENGTH=EP_LENGTH,
                   render_mode="human")

# %%
env.render_network()
# Out:
# Node Attributes:
# Node A: {'type': 'manufacturer', 'I': 30}
# Node B: {'type': 'manufacturer', 'I': 28}
# Node C: {'type': 'manufacturer', 'I': 32}
# Node D: {'type': 'distributor'}
# Node S: {'type': 'source'}

# %%
env.state.shape
# Out:
# (93,)

# %%
from stable_baselines3.common.env_checker import check_env

check_env(env, warn=True)

# %% [markdown]
# **Testng the environment**

# %%
env = SS_Mngmt_Env(network_config=network_config,
                   EP_LENGTH=EP_LENGTH,
                   render_mode="human")

episodes = 1
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        action = env.action_space.sample()
        n_state, reward, done, info, _ = env.step(action)
        score += reward

        env.render()

# 30, 28, 32
# Out:
# Episode Length: 1
# Stock Level: [[30. 28. 32.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [15, 50, 50]
# Order: [0 0 0]
# Reward: 0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 15], maxlen=3),
#     'B': deque([0, 0, 50], maxlen=3),
#     'C': deque([0, 0, 50], maxlen=3)}
#
# Episode Length: 2
# Stock Level: [[22. 28. 18.]]
# Planned Demand: [12.  0. 11.]
# Actual Demand: [ 8.  0. 14.]
# Action: [50, 50, 0]
# Order: [0 0 0]
# Reward: -71.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 15, 50], maxlen=3),
#     'B': deque([0, 50, 50], maxlen=3),
#     'C': deque([0, 50, 0], maxlen=3)}
#
# Episode Length: 3
# Stock Level: [[15. 28. 12.]]
# Planned Demand: [9. 0. 7.]
# Actual Demand: [7. 0. 6.]
# Action: [50, 50, 15]
# Order: [0 0 0]
# Reward: 386.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 50, 50], maxlen=3),
#     'B': deque([50, 50, 50], maxlen=3),
#     'C': deque([50, 0, 15], maxlen=3)}
#
# Episode Length: 4
# Stock Level: [[19. 70. 62.]]
# Planned Demand: [7. 7. 0.]
# Actual Demand: [11.  8.  0.]
# Action: [0, 50, 15]
# Order: [15 50 50]
# Reward: 206.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([50, 50, 0], maxlen=3),
#     'B': deque([50, 50, 50], maxlen=3),
#     'C': deque([0, 15, 15], maxlen=3)}
#
# Episode Length: 5
# Stock Level: [[ 69. 113.  62.]]
# Planned Demand: [ 0. 11.  0.]
# Actual Demand: [0. 7. 0.]
# Action: [50, 0, 0]
# Order: [50 50  0]
# Reward: 288.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([50, 0, 50], maxlen=3),
#     'B': deque([50, 50, 0], maxlen=3),
#     'C': deque([15, 15, 0], maxlen=3)}
#
# Episode Length: 6
# Stock Level: [[114. 163.  68.]]
# Planned Demand: [5. 0. 7.]
# Actual Demand: [5. 0. 9.]
# Action: [50, 15, 0]
# Order: [50 50 15]
# Reward: 8.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 50, 50], maxlen=3),
#     'B': deque([50, 0, 15], maxlen=3),
#     'C': deque([15, 0, 0], maxlen=3)}
#
# Episode Length: 7
# Stock Level: [[107. 206.  83.]]
# Planned Demand: [8. 8. 0.]
# Actual Demand: [7. 7. 0.]
# Action: [15, 0, 15]
# Order: [ 0 50 15]
# Reward: 91.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([50, 50, 15], maxlen=3),
#     'B': deque([0, 15, 0], maxlen=3),
#     'C': deque([0, 0, 15], maxlen=3)}
#
# Episode Length: 8
# Stock Level: [[149. 198.  68.]]
# Planned Demand: [10.  9. 14.]
# Actual Demand: [ 8.  8. 15.]
# Action: [50, 50, 0]
# Order: [50  0  0]
# Reward: 69.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([50, 15, 50], maxlen=3),
#     'B': deque([15, 0, 50], maxlen=3),
#     'C': deque([0, 15, 0], maxlen=3)}
#
# Episode Length: 9
# Stock Level: [[199. 204.  63.]]
# Planned Demand: [ 0. 12.  4.]
# Actual Demand: [0. 9. 5.]
# Action: [50, 0, 15]
# Order: [50 15  0]
# Reward: 392.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 50, 50], maxlen=3),
#     'B': deque([0, 50, 0], maxlen=3),
#     'C': deque([15, 0, 15], maxlen=3)}
#
# Episode Length: 10
# Stock Level: [[205. 194.  71.]]
# Planned Demand: [ 9. 13.  8.]
# Actual Demand: [ 9. 10.  7.]
# Action: [15, 0, 0]
# Order: [15  0 15]
# Reward: 30.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([50, 50, 15], maxlen=3),
#     'B': deque([50, 0, 0], maxlen=3),
#     'C': deque([0, 15, 0], maxlen=3)}
#
# Episode Length: 11
# Stock Level: [[255. 229.  60.]]
# Planned Demand: [ 0. 16. 10.]
# Actual Demand: [ 0. 15. 11.]
# Action: [50, 0, 50]
# Order: [50 50  0]
# Reward: 278.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([50, 15, 50], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([15, 0, 50], maxlen=3)}
#
# Episode Length: 12
# Stock Level: [[305. 220.  75.]]
# Planned Demand: [0. 9. 0.]
# Actual Demand: [0. 9. 0.]
# Action: [0, 15, 0]
# Order: [50  0 15]
# Reward: 228.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 50, 0], maxlen=3),
#     'B': deque([0, 0, 15], maxlen=3),
#     'C': deque([0, 50, 0], maxlen=3)}
#
# Episode Length: 13
# Stock Level: [[311. 220.  67.]]
# Planned Demand: [11.  0.  9.]
# Actual Demand: [9. 0. 8.]
# Action: [0, 15, 15]
# Order: [15  0  0]
# Reward: -126.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([50, 0, 0], maxlen=3),
#     'B': deque([0, 15, 15], maxlen=3),
#     'C': deque([50, 0, 15], maxlen=3)}
#
# Episode Length: 14
# Stock Level: [[361. 215. 117.]]
# Planned Demand: [0. 6. 0.]
# Actual Demand: [0. 5. 0.]
# Action: [50, 0, 15]
# Order: [50  0 50]
# Reward: 28.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 50], maxlen=3),
#     'B': deque([15, 15, 0], maxlen=3),
#     'C': deque([0, 15, 15], maxlen=3)}
#
# Episode Length: 15
# Stock Level: [[353. 222. 117.]]
# Planned Demand: [10.  9.  0.]
# Actual Demand: [8. 8. 0.]
# Action: [0, 50, 0]
# Order: [ 0 15  0]
# Reward: -263.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 50, 0], maxlen=3),
#     'B': deque([15, 0, 50], maxlen=3),
#     'C': deque([15, 15, 0], maxlen=3)}
#
# Episode Length: 16
# Stock Level: [[345. 237. 132.]]
# Planned Demand: [10.  0.  0.]
# Actual Demand: [8. 0. 0.]
# Action: [0, 15, 15]
# Order: [ 0 15 15]
# Reward: -36.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([50, 0, 0], maxlen=3),
#     'B': deque([0, 50, 15], maxlen=3),
#     'C': deque([15, 0, 15], maxlen=3)}
#
# Episode Length: 17
# Stock Level: [[395. 221. 133.]]
# Planned Demand: [ 0. 13. 12.]
# Actual Demand: [ 0. 16. 14.]
# Action: [15, 15, 50]
# Order: [50  0 15]
# Reward: -210.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 15], maxlen=3),
#     'B': deque([50, 15, 15], maxlen=3),
#     'C': deque([0, 15, 50], maxlen=3)}
#
# Episode Length: 18
# Stock Level: [[386. 271. 125.]]
# Planned Demand: [9. 0. 9.]
# Actual Demand: [9. 0. 8.]
# Action: [15, 15, 0]
# Order: [ 0 50  0]
# Reward: 202.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 50, 0], maxlen=3)}
#
# Episode Length: 19
# Stock Level: [[374. 279. 140.]]
# Planned Demand: [10.  9.  0.]
# Actual Demand: [12.  7.  0.]
# Action: [15, 15, 0]
# Order: [ 0 15 15]
# Reward: -64.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([50, 0, 0], maxlen=3)}
#
# Episode Length: 20
# Stock Level: [[383. 286. 180.]]
# Planned Demand: [ 7. 10.  9.]
# Actual Demand: [ 6.  8. 10.]
# Action: [0, 15, 15]
# Order: [15 15 50]
# Reward: -29.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 0], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([0, 0, 15], maxlen=3)}
#
# Episode Length: 21
# Stock Level: [[391. 301. 180.]]
# Planned Demand: [8. 0. 0.]
# Actual Demand: [7. 0. 0.]
# Action: [0, 15, 15]
# Order: [15 15  0]
# Reward: 42.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 0, 0], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([0, 15, 15], maxlen=3)}
#
# Episode Length: 22
# Stock Level: [[399. 316. 167.]]
# Planned Demand: [ 9.  0. 12.]
# Actual Demand: [ 7.  0. 13.]
# Action: [50, 0, 15]
# Order: [15 15  0]
# Reward: -309.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 50], maxlen=3),
#     'B': deque([15, 15, 0], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 23
# Stock Level: [[391. 331. 182.]]
# Planned Demand: [10.  0.  0.]
# Actual Demand: [8. 0. 0.]
# Action: [15, 50, 0]
# Order: [ 0 15 15]
# Reward: -57.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 50, 15], maxlen=3),
#     'B': deque([15, 0, 50], maxlen=3),
#     'C': deque([15, 15, 0], maxlen=3)}
#
# Episode Length: 24
# Stock Level: [[391. 346. 197.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 50, 0]
# Order: [ 0 15 15]
# Reward: -308.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([50, 15, 0], maxlen=3),
#     'B': deque([0, 50, 50], maxlen=3),
#     'C': deque([15, 0, 0], maxlen=3)}
#
# Episode Length: 25
# Stock Level: [[441. 338. 212.]]
# Planned Demand: [0. 6. 0.]
# Actual Demand: [0. 8. 0.]
# Action: [50, 15, 15]
# Order: [50  0 15]
# Reward: -477.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 0, 50], maxlen=3),
#     'B': deque([50, 50, 15], maxlen=3),
#     'C': deque([0, 0, 15], maxlen=3)}
#
# Episode Length: 26
# Stock Level: [[447. 380. 212.]]
# Planned Demand: [8. 8. 0.]
# Actual Demand: [9. 8. 0.]
# Action: [50, 0, 50]
# Order: [15 50  0]
# Reward: -358.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 50, 50], maxlen=3),
#     'B': deque([50, 15, 0], maxlen=3),
#     'C': deque([0, 15, 50], maxlen=3)}
#
# Episode Length: 27
# Stock Level: [[447. 425. 206.]]
# Planned Demand: [0. 7. 8.]
# Actual Demand: [0. 5. 6.]
# Action: [50, 15, 0]
# Order: [ 0 50  0]
# Reward: -199.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([50, 50, 50], maxlen=3),
#     'B': deque([15, 0, 15], maxlen=3),
#     'C': deque([15, 50, 0], maxlen=3)}
#
# Episode Length: 28
# Stock Level: [[497. 440. 212.]]
# Planned Demand: [0. 0. 7.]
# Actual Demand: [0. 0. 9.]
# Action: [0, 50, 50]
# Order: [50 15 15]
# Reward: -335.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([50, 50, 0], maxlen=3),
#     'B': deque([0, 15, 50], maxlen=3),
#     'C': deque([50, 0, 50], maxlen=3)}
#
# Episode Length: 29
# Stock Level: [[536. 425. 252.]]
# Planned Demand: [11. 13. 13.]
# Actual Demand: [11. 15. 10.]
# Action: [50, 15, 0]
# Order: [50  0 50]
# Reward: -414.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([50, 0, 50], maxlen=3),
#     'B': deque([15, 50, 15], maxlen=3),
#     'C': deque([0, 50, 0], maxlen=3)}
#
# Episode Length: 30
# Stock Level: [[586. 440. 252.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 0, 15]
# Order: [50 15  0]
# Reward: 97.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 50, 0], maxlen=3),
#     'B': deque([50, 15, 0], maxlen=3),
#     'C': deque([50, 0, 15], maxlen=3)}

# %%
df = pd.read_csv('./Data/2024-11-06_20_last_environment_data.csv')
plot_data(df)

# %% [markdown]
# **Train Model**

# %%
log_path = os.path.join('Training', 'Logs')
model_path = os.path.join('Training', 'Models', 'PPO')
# model_path = os.path.join('Training', 'Models', 'A2C')

# %%
env = SS_Mngmt_Env(network_config=network_config,
                   EP_LENGTH=EP_LENGTH,
                   render_mode="human")

def make_env():
    # Create a new environment here
    env = SS_Mngmt_Env(network_config=network_config, EP_LENGTH=EP_LENGTH, render_mode="human")
    return env

num_envs = 8

# dummy_env = DummyVecEnv([lambda: env])
vec_env = make_vec_env(make_env, n_envs=num_envs)

# model = PPO("MlpPolicy", 
#             dummy_env,
#             learning_rate = 0.0007, # 0.0003
#             gamma = 0.99, # 0.95
#             verbose=1,
#             tensorboard_log=log_path)

model = A2C("MlpPolicy",
            vec_env,
            learning_rate = 0.0005,
            gamma = 0.99,
            verbose=1,
            tensorboard_log=log_path)

# model = A2C(
#     "MlpPolicy",
#     vec_env,
#     learning_rate=0.0003,           # Lower learning rate for smoother updates
#     gamma=0.95,                      # Slightly lower discount factor for faster convergence on immediate rewards
#     ent_coef=0.01,                   # Add an entropy coefficient to encourage exploration
#     verbose=1,
#     tensorboard_log=log_path,
# )
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=500_000)
# Out:
# Logging to Training/Logs/A2C_15
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 30        |
# |    ep_rew_mean        | -2.03e+03 |
# | time/                 |           |
# |    fps                | 6532      |
# |    iterations         | 100       |
# |    time_elapsed       | 0         |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -3.19     |
# |    explained_variance | 0.00806   |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 99        |
# |    policy_loss        | -180      |
# |    value_loss         | 1.69e+05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | -493     |
# | time/                 |          |
# |    fps                | 6884     |
# |    iterations         | 200      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -3.19    |
# |    explained_variance | 0.000852 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 199      |
# |    policy_loss        | 1.11e+03 |
# |    value_loss         | 6.62e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | -1.79    |
# | time/                 |          |
# |    fps                | 7029     |
# |    iterations         | 300      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -3.03    |
# |    explained_variance | 0.00406  |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 299      |
# |    policy_loss        | -390     |
# |    value_loss         | 1.81e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 260      |
# | time/                 |          |
# |    fps                | 7116     |
# |    iterations         | 400      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -2.96    |
# |    explained_variance | 0.0174   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 399      |
# |    policy_loss        | 919      |
# |    value_loss         | 2.28e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 1.67e+03 |
# | time/                 |          |
# |    fps                | 7170     |
# |    iterations         | 500      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -2.96    |
# |    explained_variance | 6.74e-06 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 499      |
# |    policy_loss        | 1.07e+03 |
# |    value_loss         | 4.91e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 1.57e+03 |
# | time/                 |          |
# |    fps                | 7203     |
# |    iterations         | 600      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -2.73    |
# |    explained_variance | 0.0241   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 599      |
# |    policy_loss        | -3.5     |
# |    value_loss         | 8.75e+04 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 1.73e+03 |
# | time/                 |          |
# |    fps                | 7262     |
# |    iterations         | 700      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -2.72    |
# |    explained_variance | 0.0167   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 699      |
# |    policy_loss        | 954      |
# |    value_loss         | 3.17e+05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 30        |
# |    ep_rew_mean        | 1.37e+03  |
# | time/                 |           |
# |    fps                | 7283      |
# |    iterations         | 800       |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 32000     |
# | train/                |           |
# |    entropy_loss       | -3.04     |
# |    explained_variance | -1.79e-06 |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 799       |
# |    policy_loss        | 405       |
# |    value_loss         | 1.02e+06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 1.02e+03 |
# | time/                 |          |
# |    fps                | 7314     |
# |    iterations         | 900      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 36000    |
# | train/                |          |
# |    entropy_loss       | -2.68    |
# |    explained_variance | 0.061    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 899      |
# |    policy_loss        | 21.7     |
# |    value_loss         | 1.18e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 896      |
# | time/                 |          |
# |    fps                | 7335     |
# |    iterations         | 1000     |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 40000    |
# | train/                |          |
# |    entropy_loss       | -2.76    |
# |    explained_variance | 0.0331   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 999      |
# |    policy_loss        | 571      |
# |    value_loss         | 2.16e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 878      |
# | time/                 |          |
# |    fps                | 7348     |
# |    iterations         | 1100     |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 44000    |
# | train/                |          |
# |    entropy_loss       | -2.99    |
# |    explained_variance | 5.01e-06 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1099     |
# |    policy_loss        | 1.43e+03 |
# |    value_loss         | 5.63e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 1.06e+03 |
# | time/                 |          |
# |    fps                | 6888     |
# |    iterations         | 1200     |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 48000    |
# | train/                |          |
# |    entropy_loss       | -2.6     |
# |    explained_variance | 0.04     |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1199     |
# |    policy_loss        | -165     |
# |    value_loss         | 1.19e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 841      |
# | time/                 |          |
# |    fps                | 6820     |
# |    iterations         | 1300     |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 52000    |
# | train/                |          |
# |    entropy_loss       | -2.75    |
# |    explained_variance | 0.011    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1299     |
# |    policy_loss        | 908      |
# |    value_loss         | 2.75e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 548      |
# | time/                 |          |
# |    fps                | 6810     |
# |    iterations         | 1400     |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 56000    |
# | train/                |          |
# |    entropy_loss       | -2.99    |
# |    explained_variance | 2.19e-05 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1399     |
# |    policy_loss        | 1.51e+03 |
# |    value_loss         | 4.13e+05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 30        |
# |    ep_rew_mean        | 649       |
# | time/                 |           |
# |    fps                | 6798      |
# |    iterations         | 1500      |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 60000     |
# | train/                |           |
# |    entropy_loss       | -2.66     |
# |    explained_variance | -0.0026   |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1499      |
# |    policy_loss        | -1.22e+03 |
# |    value_loss         | 2.6e+05   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | -170     |
# | time/                 |          |
# |    fps                | 6834     |
# |    iterations         | 1600     |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 64000    |
# | train/                |          |
# |    entropy_loss       | -2.75    |
# |    explained_variance | 0.0393   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1599     |
# |    policy_loss        | -315     |
# |    value_loss         | 1.71e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 83       |
# | time/                 |          |
# |    fps                | 6697     |
# |    iterations         | 1700     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 68000    |
# | train/                |          |
# |    entropy_loss       | -2.61    |
# |    explained_variance | 3.22e-06 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1699     |
# |    policy_loss        | 1.43e+03 |
# |    value_loss         | 5.04e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 248      |
# | time/                 |          |
# |    fps                | 6633     |
# |    iterations         | 1800     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 72000    |
# | train/                |          |
# |    entropy_loss       | -2.63    |
# |    explained_variance | 0.0414   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1799     |
# |    policy_loss        | -330     |
# |    value_loss         | 1.63e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | -270     |
# | time/                 |          |
# |    fps                | 6677     |
# |    iterations         | 1900     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 76000    |
# | train/                |          |
# |    entropy_loss       | -2.69    |
# |    explained_variance | -0.0199  |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1899     |
# |    policy_loss        | -762     |
# |    value_loss         | 1.48e+05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 30        |
# |    ep_rew_mean        | -1.12e+03 |
# | time/                 |           |
# |    fps                | 6703      |
# |    iterations         | 2000      |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 80000     |
# | train/                |           |
# |    entropy_loss       | -2.05     |
# |    explained_variance | 2.03e-06  |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1999      |
# |    policy_loss        | 866       |
# |    value_loss         | 3.19e+05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | -210     |
# | time/                 |          |
# |    fps                | 6711     |
# |    iterations         | 2100     |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 84000    |
# | train/                |          |
# |    entropy_loss       | -2.4     |
# |    explained_variance | 0.0196   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 2099     |
# |    policy_loss        | -782     |
# |    value_loss         | 3.03e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 904      |
# | time/                 |          |
# |    fps                | 6748     |
# |    iterations         | 2200     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 88000    |
# | train/                |          |
# |    entropy_loss       | -2.29    |
# |    explained_variance | 0.0749   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 2199     |
# |    policy_loss        | 197      |
# |    value_loss         | 1.06e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 1.14e+03 |
# | time/                 |          |
# |    fps                | 6770     |
# |    iterations         | 2300     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 92000    |
# | train/                |          |
# |    entropy_loss       | -2.4     |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 2299     |
# |    policy_loss        | 1.04e+03 |
# |    value_loss         | 3.84e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 1.57e+03 |
# | time/                 |          |
# |    fps                | 6789     |
# |    iterations         | 2400     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 96000    |
# | train/                |          |
# |    entropy_loss       | -2.02    |
# |    explained_variance | 0.189    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 2399     |
# |    policy_loss        | 123      |
# |    value_loss         | 1.03e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 1.53e+03 |
# | time/                 |          |
# |    fps                | 6821     |
# |    iterations         | 2500     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 100000   |
# | train/                |          |
# |    entropy_loss       | -2.1     |
# |    explained_variance | -0.0153  |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 2499     |
# |    policy_loss        | 712      |
# |    value_loss         | 2.32e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 1.8e+03  |
# | time/                 |          |
# |    fps                | 6846     |
# |    iterations         | 2600     |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 104000   |
# | train/                |          |
# |    entropy_loss       | -2.03    |
# |    explained_variance | 4.77e-07 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 2599     |
# |    policy_loss        | 1.23e+03 |
# |    value_loss         | 4.99e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 1.26e+03 |
# | time/                 |          |
# |    fps                | 6876     |
# |    iterations         | 2700     |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 108000   |
# | train/                |          |
# |    entropy_loss       | -2.17    |
# |    explained_variance | 0.151    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 2699     |
# |    policy_loss        | 39.5     |
# |    value_loss         | 6.18e+04 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 959      |
# | time/                 |          |
# |    fps                | 6899     |
# |    iterations         | 2800     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 112000   |
# | train/                |          |
# |    entropy_loss       | -2.15    |
# |    explained_variance | 0.0672   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 2799     |
# |    policy_loss        | 25.6     |
# |    value_loss         | 6.18e+04 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 1.22e+03 |
# | time/                 |          |
# |    fps                | 6857     |
# |    iterations         | 2900     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 116000   |
# | train/                |          |
# |    entropy_loss       | -1.42    |
# |    explained_variance | 2.98e-07 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 2899     |
# |    policy_loss        | 899      |
# |    value_loss         | 5.97e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 1.24e+03 |
# | time/                 |          |
# |    fps                | 6882     |
# |    iterations         | 3000     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 120000   |
# | train/                |          |
# |    entropy_loss       | -1.95    |
# |    explained_variance | 0.0837   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 2999     |
# |    policy_loss        | 59.1     |
# |    value_loss         | 1.77e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 1.48e+03 |
# | time/                 |          |
# |    fps                | 6901     |
# |    iterations         | 3100     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 124000   |
# | train/                |          |
# |    entropy_loss       | -2.07    |
# |    explained_variance | 0.116    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 3099     |
# |    policy_loss        | 856      |
# |    value_loss         | 3.17e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 1.19e+03 |
# | time/                 |          |
# |    fps                | 6918     |
# |    iterations         | 3200     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 128000   |
# | train/                |          |
# |    entropy_loss       | -1.37    |
# |    explained_variance | 8.94e-07 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 3199     |
# |    policy_loss        | 752      |
# |    value_loss         | 3.83e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 1.93e+03 |
# | time/                 |          |
# |    fps                | 6937     |
# |    iterations         | 3300     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 132000   |
# | train/                |          |
# |    entropy_loss       | -1.98    |
# |    explained_variance | 0.083    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 3299     |
# |    policy_loss        | 133      |
# |    value_loss         | 7.37e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 2.32e+03 |
# | time/                 |          |
# |    fps                | 6953     |
# |    iterations         | 3400     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 136000   |
# | train/                |          |
# |    entropy_loss       | -1.91    |
# |    explained_variance | 0.0537   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 3399     |
# |    policy_loss        | 835      |
# |    value_loss         | 2.77e+05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 30        |
# |    ep_rew_mean        | 1.82e+03  |
# | time/                 |           |
# |    fps                | 6974      |
# |    iterations         | 3500      |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 140000    |
# | train/                |           |
# |    entropy_loss       | -1.36     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 3499      |
# |    policy_loss        | 439       |
# |    value_loss         | 4.49e+05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 2.13e+03 |
# | time/                 |          |
# |    fps                | 6979     |
# |    iterations         | 3600     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 144000   |
# | train/                |          |
# |    entropy_loss       | -1.6     |
# |    explained_variance | 0.0121   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 3599     |
# |    policy_loss        | 443      |
# |    value_loss         | 2.49e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 2.68e+03 |
# | time/                 |          |
# |    fps                | 6996     |
# |    iterations         | 3700     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 148000   |
# | train/                |          |
# |    entropy_loss       | -1.53    |
# |    explained_variance | 1.72e-05 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 3699     |
# |    policy_loss        | 514      |
# |    value_loss         | 1.74e+05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 30        |
# |    ep_rew_mean        | 2.75e+03  |
# | time/                 |           |
# |    fps                | 7005      |
# |    iterations         | 3800      |
# |    time_elapsed       | 21        |
# |    total_timesteps    | 152000    |
# | train/                |           |
# |    entropy_loss       | -1.6      |
# |    explained_variance | -5.96e-07 |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 3799      |
# |    policy_loss        | 709       |
# |    value_loss         | 3.92e+05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 2.94e+03 |
# | time/                 |          |
# |    fps                | 7016     |
# |    iterations         | 3900     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 156000   |
# | train/                |          |
# |    entropy_loss       | -1.53    |
# |    explained_variance | -0.0013  |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 3899     |
# |    policy_loss        | 247      |
# |    value_loss         | 9.79e+04 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 3.15e+03 |
# | time/                 |          |
# |    fps                | 7024     |
# |    iterations         | 4000     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 160000   |
# | train/                |          |
# |    entropy_loss       | -1.52    |
# |    explained_variance | 3.83e-05 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 3999     |
# |    policy_loss        | 500      |
# |    value_loss         | 1.81e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 2.66e+03 |
# | time/                 |          |
# |    fps                | 7036     |
# |    iterations         | 4100     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 164000   |
# | train/                |          |
# |    entropy_loss       | -1.33    |
# |    explained_variance | 3.99e-06 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 4099     |
# |    policy_loss        | 604      |
# |    value_loss         | 5.24e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 3.01e+03 |
# | time/                 |          |
# |    fps                | 7049     |
# |    iterations         | 4200     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 168000   |
# | train/                |          |
# |    entropy_loss       | -1.58    |
# |    explained_variance | 2e-05    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 4199     |
# |    policy_loss        | -426     |
# |    value_loss         | 6.84e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 3.17e+03 |
# | time/                 |          |
# |    fps                | 7064     |
# |    iterations         | 4300     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 172000   |
# | train/                |          |
# |    entropy_loss       | -0.983   |
# |    explained_variance | 8.4e-05  |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 4299     |
# |    policy_loss        | 491      |
# |    value_loss         | 3.52e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 3.06e+03 |
# | time/                 |          |
# |    fps                | 7074     |
# |    iterations         | 4400     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 176000   |
# | train/                |          |
# |    entropy_loss       | -1.15    |
# |    explained_variance | 8.64e-06 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 4399     |
# |    policy_loss        | 716      |
# |    value_loss         | 6.28e+05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 30        |
# |    ep_rew_mean        | 2.5e+03   |
# | time/                 |           |
# |    fps                | 7084      |
# |    iterations         | 4500      |
# |    time_elapsed       | 25        |
# |    total_timesteps    | 180000    |
# | train/                |           |
# |    entropy_loss       | -1.43     |
# |    explained_variance | -0.000126 |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 4499      |
# |    policy_loss        | 789       |
# |    value_loss         | 5.28e+05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 3.01e+03 |
# | time/                 |          |
# |    fps                | 7096     |
# |    iterations         | 4600     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 184000   |
# | train/                |          |
# |    entropy_loss       | -0.909   |
# |    explained_variance | -0.0001  |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 4599     |
# |    policy_loss        | 160      |
# |    value_loss         | 6.47e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 3.2e+03  |
# | time/                 |          |
# |    fps                | 7079     |
# |    iterations         | 4700     |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 188000   |
# | train/                |          |
# |    entropy_loss       | -1.15    |
# |    explained_variance | 3.06e-05 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 4699     |
# |    policy_loss        | 638      |
# |    value_loss         | 8.33e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 3.2e+03  |
# | time/                 |          |
# |    fps                | 7092     |
# |    iterations         | 4800     |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 192000   |
# | train/                |          |
# |    entropy_loss       | -1.7     |
# |    explained_variance | 0.0021   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 4799     |
# |    policy_loss        | 532      |
# |    value_loss         | 4.84e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 3.25e+03 |
# | time/                 |          |
# |    fps                | 7095     |
# |    iterations         | 4900     |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 196000   |
# | train/                |          |
# |    entropy_loss       | -1.43    |
# |    explained_variance | 0.0062   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 4899     |
# |    policy_loss        | 46.6     |
# |    value_loss         | 3.78e+05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 30        |
# |    ep_rew_mean        | 3.6e+03   |
# | time/                 |           |
# |    fps                | 7099      |
# |    iterations         | 5000      |
# |    time_elapsed       | 28        |
# |    total_timesteps    | 200000    |
# | train/                |           |
# |    entropy_loss       | -1.3      |
# |    explained_variance | -3.34e-06 |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 4999      |
# |    policy_loss        | 651       |
# |    value_loss         | 5.05e+05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 4.01e+03 |
# | time/                 |          |
# |    fps                | 7087     |
# |    iterations         | 5100     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 204000   |
# | train/                |          |
# |    entropy_loss       | -1.55    |
# |    explained_variance | 4.43e-05 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 5099     |
# |    policy_loss        | 59.8     |
# |    value_loss         | 2.24e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 3.79e+03 |
# | time/                 |          |
# |    fps                | 7094     |
# |    iterations         | 5200     |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 208000   |
# | train/                |          |
# |    entropy_loss       | -1.24    |
# |    explained_variance | 0.000183 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 5199     |
# |    policy_loss        | 362      |
# |    value_loss         | 2.6e+05  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 3.96e+03 |
# | time/                 |          |
# |    fps                | 7106     |
# |    iterations         | 5300     |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 212000   |
# | train/                |          |
# |    entropy_loss       | -1.66    |
# |    explained_variance | 4.11e-06 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 5299     |
# |    policy_loss        | 900      |
# |    value_loss         | 5.48e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 3.99e+03 |
# | time/                 |          |
# |    fps                | 7095     |
# |    iterations         | 5400     |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 216000   |
# | train/                |          |
# |    entropy_loss       | -1.8     |
# |    explained_variance | 0.0001   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 5399     |
# |    policy_loss        | 643      |
# |    value_loss         | 3.13e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 3.53e+03 |
# | time/                 |          |
# |    fps                | 7094     |
# |    iterations         | 5500     |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 220000   |
# | train/                |          |
# |    entropy_loss       | -1.05    |
# |    explained_variance | 0.000255 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 5499     |
# |    policy_loss        | 488      |
# |    value_loss         | 2.46e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 3.05e+03 |
# | time/                 |          |
# |    fps                | 7093     |
# |    iterations         | 5600     |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 224000   |
# | train/                |          |
# |    entropy_loss       | -1.33    |
# |    explained_variance | -2.5e-06 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 5599     |
# |    policy_loss        | 742      |
# |    value_loss         | 3.64e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 2.94e+03 |
# | time/                 |          |
# |    fps                | 7089     |
# |    iterations         | 5700     |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 228000   |
# | train/                |          |
# |    entropy_loss       | -1.74    |
# |    explained_variance | 0.00175  |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 5699     |
# |    policy_loss        | -118     |
# |    value_loss         | 2.94e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 2.86e+03 |
# | time/                 |          |
# |    fps                | 7086     |
# |    iterations         | 5800     |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 232000   |
# | train/                |          |
# |    entropy_loss       | -1.25    |
# |    explained_variance | 0.0117   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 5799     |
# |    policy_loss        | 558      |
# |    value_loss         | 4.56e+05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 30        |
# |    ep_rew_mean        | 2.44e+03  |
# | time/                 |           |
# |    fps                | 7081      |
# |    iterations         | 5900      |
# |    time_elapsed       | 33        |
# |    total_timesteps    | 236000    |
# | train/                |           |
# |    entropy_loss       | -1.83     |
# |    explained_variance | -1.18e-05 |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 5899      |
# |    policy_loss        | 680       |
# |    value_loss         | 5.23e+05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 3.33e+03 |
# | time/                 |          |
# |    fps                | 7088     |
# |    iterations         | 6000     |
# |    time_elapsed       | 33       |
# |    total_timesteps    | 240000   |
# | train/                |          |
# |    entropy_loss       | -1.34    |
# |    explained_variance | 0.0066   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 5999     |
# |    policy_loss        | 343      |
# |    value_loss         | 3.53e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 3.25e+03 |
# | time/                 |          |
# |    fps                | 7098     |
# |    iterations         | 6100     |
# |    time_elapsed       | 34       |
# |    total_timesteps    | 244000   |
# | train/                |          |
# |    entropy_loss       | -1.4     |
# |    explained_variance | 0.0695   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 6099     |
# |    policy_loss        | 490      |
# |    value_loss         | 3.85e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 4.05e+03 |
# | time/                 |          |
# |    fps                | 7092     |
# |    iterations         | 6200     |
# |    time_elapsed       | 34       |
# |    total_timesteps    | 248000   |
# | train/                |          |
# |    entropy_loss       | -0.871   |
# |    explained_variance | 1.34e-05 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 6199     |
# |    policy_loss        | 621      |
# |    value_loss         | 6.14e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 3.53e+03 |
# | time/                 |          |
# |    fps                | 7101     |
# |    iterations         | 6300     |
# |    time_elapsed       | 35       |
# |    total_timesteps    | 252000   |
# | train/                |          |
# |    entropy_loss       | -1.79    |
# |    explained_variance | 0.0285   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 6299     |
# |    policy_loss        | 42.4     |
# |    value_loss         | 6.04e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 3.53e+03 |
# | time/                 |          |
# |    fps                | 7108     |
# |    iterations         | 6400     |
# |    time_elapsed       | 36       |
# |    total_timesteps    | 256000   |
# | train/                |          |
# |    entropy_loss       | -1.1     |
# |    explained_variance | 0.00532  |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 6399     |
# |    policy_loss        | 220      |
# |    value_loss         | 1.3e+05  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 1.35e+03 |
# | time/                 |          |
# |    fps                | 7115     |
# |    iterations         | 6500     |
# |    time_elapsed       | 36       |
# |    total_timesteps    | 260000   |
# | train/                |          |
# |    entropy_loss       | -1.46    |
# |    explained_variance | 1.73e-05 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 6499     |
# |    policy_loss        | 1.07e+03 |
# |    value_loss         | 6.43e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 1.22e+03 |
# | time/                 |          |
# |    fps                | 7119     |
# |    iterations         | 6600     |
# |    time_elapsed       | 37       |
# |    total_timesteps    | 264000   |
# | train/                |          |
# |    entropy_loss       | -1.48    |
# |    explained_variance | 0.0474   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 6599     |
# |    policy_loss        | 504      |
# |    value_loss         | 1.02e+06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 2.36e+03 |
# | time/                 |          |
# |    fps                | 7111     |
# |    iterations         | 6700     |
# |    time_elapsed       | 37       |
# |    total_timesteps    | 268000   |
# | train/                |          |
# |    entropy_loss       | -1.35    |
# |    explained_variance | 0.0775   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 6699     |
# |    policy_loss        | 256      |
# |    value_loss         | 8.64e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 1.78e+03 |
# | time/                 |          |
# |    fps                | 7118     |
# |    iterations         | 6800     |
# |    time_elapsed       | 38       |
# |    total_timesteps    | 272000   |
# | train/                |          |
# |    entropy_loss       | -1.13    |
# |    explained_variance | 0.000153 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 6799     |
# |    policy_loss        | 640      |
# |    value_loss         | 6.72e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 3.1e+03  |
# | time/                 |          |
# |    fps                | 7114     |
# |    iterations         | 6900     |
# |    time_elapsed       | 38       |
# |    total_timesteps    | 276000   |
# | train/                |          |
# |    entropy_loss       | -1.72    |
# |    explained_variance | -0.109   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 6899     |
# |    policy_loss        | 344      |
# |    value_loss         | 5.25e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 3.15e+03 |
# | time/                 |          |
# |    fps                | 7110     |
# |    iterations         | 7000     |
# |    time_elapsed       | 39       |
# |    total_timesteps    | 280000   |
# | train/                |          |
# |    entropy_loss       | -1.29    |
# |    explained_variance | 1.23e-05 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 6999     |
# |    policy_loss        | 215      |
# |    value_loss         | 3.99e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 2.1e+03  |
# | time/                 |          |
# |    fps                | 7118     |
# |    iterations         | 7100     |
# |    time_elapsed       | 39       |
# |    total_timesteps    | 284000   |
# | train/                |          |
# |    entropy_loss       | -1.09    |
# |    explained_variance | 6.5e-06  |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 7099     |
# |    policy_loss        | 572      |
# |    value_loss         | 5.27e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 3.02e+03 |
# | time/                 |          |
# |    fps                | 7113     |
# |    iterations         | 7200     |
# |    time_elapsed       | 40       |
# |    total_timesteps    | 288000   |
# | train/                |          |
# |    entropy_loss       | -1.53    |
# |    explained_variance | 0.147    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 7199     |
# |    policy_loss        | 358      |
# |    value_loss         | 3.03e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 2.39e+03 |
# | time/                 |          |
# |    fps                | 7111     |
# |    iterations         | 7300     |
# |    time_elapsed       | 41       |
# |    total_timesteps    | 292000   |
# | train/                |          |
# |    entropy_loss       | -1.27    |
# |    explained_variance | 1.13e-06 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 7299     |
# |    policy_loss        | 286      |
# |    value_loss         | 2.77e+05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 30        |
# |    ep_rew_mean        | 2.97e+03  |
# | time/                 |           |
# |    fps                | 7108      |
# |    iterations         | 7400      |
# |    time_elapsed       | 41        |
# |    total_timesteps    | 296000    |
# | train/                |           |
# |    entropy_loss       | -1.06     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 7399      |
# |    policy_loss        | 316       |
# |    value_loss         | 2.89e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 30        |
# |    ep_rew_mean        | 3e+03     |
# | time/                 |           |
# |    fps                | 7105      |
# |    iterations         | 7500      |
# |    time_elapsed       | 42        |
# |    total_timesteps    | 300000    |
# | train/                |           |
# |    entropy_loss       | -1.49     |
# |    explained_variance | -0.000113 |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 7499      |
# |    policy_loss        | 456       |
# |    value_loss         | 1.96e+05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 3.22e+03 |
# | time/                 |          |
# |    fps                | 7108     |
# |    iterations         | 7600     |
# |    time_elapsed       | 42       |
# |    total_timesteps    | 304000   |
# | train/                |          |
# |    entropy_loss       | -1.41    |
# |    explained_variance | 7.15e-05 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 7599     |
# |    policy_loss        | 424      |
# |    value_loss         | 3.38e+05 |
# ...
# |    explained_variance | 4.59e-06 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 9999     |
# |    policy_loss        | 436      |
# |    value_loss         | 3.28e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 3.26e+03 |
# | time/                 |          |
# |    fps                | 7130     |
# |    iterations         | 10100    |
# |    time_elapsed       | 56       |
# |    total_timesteps    | 404000   |
# | train/                |          |
# |    entropy_loss       | -0.515   |
# |    explained_variance | 3.09e-05 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 10099    |
# |    policy_loss        | 179      |
# |    value_loss         | 2.42e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 3.86e+03 |
# | time/                 |          |
# |    fps                | 7124     |
# |    iterations         | 10200    |
# |    time_elapsed       | 57       |
# |    total_timesteps    | 408000   |
# | train/                |          |
# |    entropy_loss       | -1.54    |
# |    explained_variance | -0.0227  |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 10199    |
# |    policy_loss        | 991      |
# |    value_loss         | 7.26e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 3.67e+03 |
# | time/                 |          |
# |    fps                | 7122     |
# |    iterations         | 10300    |
# |    time_elapsed       | 57       |
# |    total_timesteps    | 412000   |
# | train/                |          |
# |    entropy_loss       | -0.985   |
# |    explained_variance | 0.02     |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 10299    |
# |    policy_loss        | 315      |
# |    value_loss         | 1.39e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 3.67e+03 |
# | time/                 |          |
# |    fps                | 7121     |
# |    iterations         | 10400    |
# |    time_elapsed       | 58       |
# |    total_timesteps    | 416000   |
# | train/                |          |
# |    entropy_loss       | -0.4     |
# |    explained_variance | 5.07e-06 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 10399    |
# |    policy_loss        | 386      |
# |    value_loss         | 5.23e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 4.37e+03 |
# | time/                 |          |
# |    fps                | 7117     |
# |    iterations         | 10500    |
# |    time_elapsed       | 59       |
# |    total_timesteps    | 420000   |
# | train/                |          |
# |    entropy_loss       | -1.65    |
# |    explained_variance | 0.1      |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 10499    |
# |    policy_loss        | 544      |
# |    value_loss         | 2.12e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 4.27e+03 |
# | time/                 |          |
# |    fps                | 7121     |
# |    iterations         | 10600    |
# |    time_elapsed       | 59       |
# |    total_timesteps    | 424000   |
# | train/                |          |
# |    entropy_loss       | -1.08    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 10599    |
# |    policy_loss        | 452      |
# |    value_loss         | 4.24e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 4.1e+03  |
# | time/                 |          |
# |    fps                | 7120     |
# |    iterations         | 10700    |
# |    time_elapsed       | 60       |
# |    total_timesteps    | 428000   |
# | train/                |          |
# |    entropy_loss       | -0.157   |
# |    explained_variance | 1.79e-07 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 10699    |
# |    policy_loss        | 14       |
# |    value_loss         | 4.88e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 4.26e+03 |
# | time/                 |          |
# |    fps                | 7117     |
# |    iterations         | 10800    |
# |    time_elapsed       | 60       |
# |    total_timesteps    | 432000   |
# | train/                |          |
# |    entropy_loss       | -1.21    |
# |    explained_variance | 3.58e-07 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 10799    |
# |    policy_loss        | 282      |
# |    value_loss         | 8.89e+05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 30        |
# |    ep_rew_mean        | 4.37e+03  |
# | time/                 |           |
# |    fps                | 7112      |
# |    iterations         | 10900     |
# |    time_elapsed       | 61        |
# |    total_timesteps    | 436000    |
# | train/                |           |
# |    entropy_loss       | -0.575    |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 10899     |
# |    policy_loss        | 43.5      |
# |    value_loss         | 3.13e+05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 4.21e+03 |
# | time/                 |          |
# |    fps                | 7109     |
# |    iterations         | 11000    |
# |    time_elapsed       | 61       |
# |    total_timesteps    | 440000   |
# | train/                |          |
# |    entropy_loss       | -0.607   |
# |    explained_variance | 9.24e-06 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 10999    |
# |    policy_loss        | 230      |
# |    value_loss         | 2.99e+05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 30        |
# |    ep_rew_mean        | 3.67e+03  |
# | time/                 |           |
# |    fps                | 7103      |
# |    iterations         | 11100     |
# |    time_elapsed       | 62        |
# |    total_timesteps    | 444000    |
# | train/                |           |
# |    entropy_loss       | -1.06     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 11099     |
# |    policy_loss        | 596       |
# |    value_loss         | 5.18e+05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 4.29e+03 |
# | time/                 |          |
# |    fps                | 7101     |
# |    iterations         | 11200    |
# |    time_elapsed       | 63       |
# |    total_timesteps    | 448000   |
# | train/                |          |
# |    entropy_loss       | -0.491   |
# |    explained_variance | 4.77e-07 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 11199    |
# |    policy_loss        | 290      |
# |    value_loss         | 3.91e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 4.54e+03 |
# | time/                 |          |
# |    fps                | 7099     |
# |    iterations         | 11300    |
# |    time_elapsed       | 63       |
# |    total_timesteps    | 452000   |
# | train/                |          |
# |    entropy_loss       | -0.214   |
# |    explained_variance | 8.34e-07 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 11299    |
# |    policy_loss        | 20.5     |
# |    value_loss         | 4.14e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 4.15e+03 |
# | time/                 |          |
# |    fps                | 7094     |
# |    iterations         | 11400    |
# |    time_elapsed       | 64       |
# |    total_timesteps    | 456000   |
# | train/                |          |
# |    entropy_loss       | -1.12    |
# |    explained_variance | 4.72e-05 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 11399    |
# |    policy_loss        | 498      |
# |    value_loss         | 5.32e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 4.35e+03 |
# | time/                 |          |
# |    fps                | 7098     |
# |    iterations         | 11500    |
# |    time_elapsed       | 64       |
# |    total_timesteps    | 460000   |
# | train/                |          |
# |    entropy_loss       | -0.551   |
# |    explained_variance | 1.79e-07 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 11499    |
# |    policy_loss        | 364      |
# |    value_loss         | 3.82e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 4.25e+03 |
# | time/                 |          |
# |    fps                | 7102     |
# |    iterations         | 11600    |
# |    time_elapsed       | 65       |
# |    total_timesteps    | 464000   |
# | train/                |          |
# |    entropy_loss       | -0.227   |
# |    explained_variance | 2.98e-07 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 11599    |
# |    policy_loss        | 88.3     |
# |    value_loss         | 4.78e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 4.31e+03 |
# | time/                 |          |
# |    fps                | 7106     |
# |    iterations         | 11700    |
# |    time_elapsed       | 65       |
# |    total_timesteps    | 468000   |
# | train/                |          |
# |    entropy_loss       | -0.922   |
# |    explained_variance | 0.0924   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 11699    |
# |    policy_loss        | 447      |
# |    value_loss         | 3.37e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 4.37e+03 |
# | time/                 |          |
# |    fps                | 7109     |
# |    iterations         | 11800    |
# |    time_elapsed       | 66       |
# |    total_timesteps    | 472000   |
# | train/                |          |
# |    entropy_loss       | -0.173   |
# |    explained_variance | 8.94e-07 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 11799    |
# |    policy_loss        | 19.5     |
# |    value_loss         | 5.37e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 4.68e+03 |
# | time/                 |          |
# |    fps                | 7107     |
# |    iterations         | 11900    |
# |    time_elapsed       | 66       |
# |    total_timesteps    | 476000   |
# | train/                |          |
# |    entropy_loss       | -0.603   |
# |    explained_variance | 0.000243 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 11899    |
# |    policy_loss        | -37.1    |
# |    value_loss         | 5.21e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 4.68e+03 |
# | time/                 |          |
# |    fps                | 7111     |
# |    iterations         | 12000    |
# |    time_elapsed       | 67       |
# |    total_timesteps    | 480000   |
# | train/                |          |
# |    entropy_loss       | -1.03    |
# |    explained_variance | 0.000187 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 11999    |
# |    policy_loss        | 518      |
# |    value_loss         | 3.93e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 4.49e+03 |
# | time/                 |          |
# |    fps                | 7109     |
# |    iterations         | 12100    |
# |    time_elapsed       | 68       |
# |    total_timesteps    | 484000   |
# | train/                |          |
# |    entropy_loss       | -0.489   |
# |    explained_variance | 9.36e-06 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 12099    |
# |    policy_loss        | 378      |
# |    value_loss         | 5.69e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 4.86e+03 |
# | time/                 |          |
# |    fps                | 7111     |
# |    iterations         | 12200    |
# |    time_elapsed       | 68       |
# |    total_timesteps    | 488000   |
# | train/                |          |
# |    entropy_loss       | -0.462   |
# |    explained_variance | 4.17e-07 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 12199    |
# |    policy_loss        | 74.5     |
# |    value_loss         | 4.29e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 4.93e+03 |
# | time/                 |          |
# |    fps                | 7104     |
# |    iterations         | 12300    |
# |    time_elapsed       | 69       |
# |    total_timesteps    | 492000   |
# | train/                |          |
# |    entropy_loss       | -0.97    |
# |    explained_variance | 7.57e-06 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 12299    |
# |    policy_loss        | 437      |
# |    value_loss         | 4.69e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 4.7e+03  |
# | time/                 |          |
# |    fps                | 7104     |
# |    iterations         | 12400    |
# |    time_elapsed       | 69       |
# |    total_timesteps    | 496000   |
# | train/                |          |
# |    entropy_loss       | -0.25    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 12399    |
# |    policy_loss        | 32.9     |
# |    value_loss         | 3.94e+05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 4.69e+03 |
# | time/                 |          |
# |    fps                | 7107     |
# |    iterations         | 12500    |
# |    time_elapsed       | 70       |
# |    total_timesteps    | 500000   |
# | train/                |          |
# |    entropy_loss       | -0.205   |
# |    explained_variance | 4.77e-07 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 12499    |
# |    policy_loss        | 19.8     |
# |    value_loss         | 2.73e+05 |
# ------------------------------------

# %%
model.save(model_path)
model.load(model_path)

evaluate_policy(model, vec_env, n_eval_episodes=1, render=True, return_episode_rewards=True)
# evaluate_policy(model, dummy_env, n_eval_episodes=1, render=True, return_episode_rewards=True)
# Out:
# Episode Length: 1
# Stock Level: [[30. 18. 32.]]
# Planned Demand: [0. 9. 0.]
# Actual Demand: [ 0. 10.  0.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 15], maxlen=3),
#     'B': deque([0, 0, 15], maxlen=3),
#     'C': deque([0, 0, 15], maxlen=3)}
#
# Episode Length: 1
# Stock Level: [[30. 28. 26.]]
# Planned Demand: [0. 0. 9.]
# Actual Demand: [0. 0. 6.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 15], maxlen=3),
#     'B': deque([0, 0, 15], maxlen=3),
#     'C': deque([0, 0, 15], maxlen=3)}
#
# Episode Length: 1
# Stock Level: [[25. 28. 32.]]
# Planned Demand: [6. 0. 0.]
# Actual Demand: [5. 0. 0.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 15], maxlen=3),
#     'B': deque([0, 0, 15], maxlen=3),
#     'C': deque([0, 0, 15], maxlen=3)}
#
# Episode Length: 1
# Stock Level: [[17. 19. 27.]]
# Planned Demand: [12.  7.  8.]
# Actual Demand: [13.  9.  5.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 15], maxlen=3),
#     'B': deque([0, 0, 15], maxlen=3),
#     'C': deque([0, 0, 15], maxlen=3)}
#
# Episode Length: 1
# Stock Level: [[30. 21. 32.]]
# Planned Demand: [0. 8. 0.]
# Actual Demand: [0. 7. 0.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 15], maxlen=3),
#     'B': deque([0, 0, 15], maxlen=3),
#     'C': deque([0, 0, 15], maxlen=3)}
#
# Episode Length: 1
# Stock Level: [[22. 28. 20.]]
# Planned Demand: [11.  0. 14.]
# Actual Demand: [ 8.  0. 12.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 15], maxlen=3),
#     'B': deque([0, 0, 15], maxlen=3),
#     'C': deque([0, 0, 15], maxlen=3)}
#
# Episode Length: 1
# Stock Level: [[22. 28. 20.]]
# Planned Demand: [ 8.  0. 10.]
# Actual Demand: [ 8.  0. 12.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 15], maxlen=3),
#     'B': deque([0, 0, 15], maxlen=3),
#     'C': deque([0, 0, 15], maxlen=3)}
#
# Episode Length: 1
# Stock Level: [[20. 18. 29.]]
# Planned Demand: [ 9. 10.  6.]
# Actual Demand: [10. 10.  3.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 15], maxlen=3),
#     'B': deque([0, 0, 15], maxlen=3),
#     'C': deque([0, 0, 15], maxlen=3)}
#
# Episode Length: 2
# Stock Level: [[22.  7. 32.]]
# Planned Demand: [11. 12.  0.]
# Actual Demand: [ 8. 11.  0.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 140.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 15, 15], maxlen=3),
#     'B': deque([0, 15, 15], maxlen=3),
#     'C': deque([0, 15, 15], maxlen=3)}
#
# Episode Length: 2
# Stock Level: [[30. 21. 22.]]
# Planned Demand: [0. 9. 2.]
# Actual Demand: [0. 7. 4.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 58.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 15, 15], maxlen=3),
#     'B': deque([0, 15, 15], maxlen=3),
#     'C': deque([0, 15, 15], maxlen=3)}
#
# Episode Length: 2
# Stock Level: [[20. 13. 26.]]
# Planned Demand: [ 8. 11.  9.]
# Actual Demand: [ 5. 15.  6.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 38.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 15, 15], maxlen=3),
#     'B': deque([0, 15, 15], maxlen=3),
#     'C': deque([0, 15, 15], maxlen=3)}
#
# Episode Length: 2
# Stock Level: [[17. 19. 27.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 489.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 15, 15], maxlen=3),
#     'B': deque([0, 15, 15], maxlen=3),
#     'C': deque([0, 15, 15], maxlen=3)}
#
# Episode Length: 2
# Stock Level: [[23. 21. 32.]]
# Planned Demand: [6. 0. 0.]
# Actual Demand: [7. 0. 0.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 79.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 15, 15], maxlen=3),
#     'B': deque([0, 15, 15], maxlen=3),
#     'C': deque([0, 15, 15], maxlen=3)}
#
# Episode Length: 2
# Stock Level: [[19. 28. 20.]]
# Planned Demand: [7. 0. 0.]
# Actual Demand: [3. 0. 0.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 345.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 15, 15], maxlen=3),
#     'B': deque([0, 15, 15], maxlen=3),
#     'C': deque([0, 15, 15], maxlen=3)}
#
# Episode Length: 2
# Stock Level: [[11. 19. 20.]]
# Planned Demand: [11.  9.  0.]
# Actual Demand: [11.  9.  0.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 345.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 15, 15], maxlen=3),
#     'B': deque([0, 15, 15], maxlen=3),
#     'C': deque([0, 15, 15], maxlen=3)}
#
# Episode Length: 2
# Stock Level: [[15. 10. 20.]]
# Planned Demand: [ 8. 10. 11.]
# Actual Demand: [5. 8. 9.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 407.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 15, 15], maxlen=3),
#     'B': deque([0, 15, 15], maxlen=3),
#     'C': deque([0, 15, 15], maxlen=3)}
#
# Episode Length: 3
# Stock Level: [[22.  0. 32.]]
# Planned Demand: [0. 9. 0.]
# Actual Demand: [0. 7. 0.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 330.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 3
# Stock Level: [[30. 21. 22.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 164.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 3
# Stock Level: [[20. 13. 26.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 471.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 3
# Stock Level: [[10. 19. 17.]]
# Planned Demand: [10.  0.  9.]
# Actual Demand: [ 7.  0. 10.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: -51.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 3
# Stock Level: [[13. 14. 32.]]
# Planned Demand: [10.  6.  0.]
# Actual Demand: [10.  7.  0.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 82.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 3
# Stock Level: [[ 5. 17. 20.]]
# Planned Demand: [ 9. 11.  0.]
# Actual Demand: [14. 11.  0.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 7.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 3
# Stock Level: [[11.  8. 20.]]
# Planned Demand: [ 0. 11.  0.]
# Actual Demand: [ 0. 11.  0.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 355.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 3
# Stock Level: [[15. 10. 20.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 398.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 4
# Stock Level: [[27. 13. 47.]]
# Planned Demand: [11.  4.  0.]
# Actual Demand: [10.  2.  0.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: 93.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 4
# Stock Level: [[45. 36. 37.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: -56.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 4
# Stock Level: [[24. 10. 41.]]
# Planned Demand: [10. 18.  0.]
# Actual Demand: [11. 18.  0.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: -49.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 4
# Stock Level: [[18. 22. 32.]]
# Planned Demand: [ 7. 15.  0.]
# Actual Demand: [ 7. 12.  0.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: 297.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 4
# Stock Level: [[16. 15. 47.]]
# Planned Demand: [12. 11.  0.]
# Actual Demand: [12. 14.  0.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: 291.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 4
# Stock Level: [[20. 32. 23.]]
# Planned Demand: [ 0.  0. 10.]
# Actual Demand: [ 0.  0. 12.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: 459.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 4
# Stock Level: [[26. 20. 35.]]
# Planned Demand: [0. 5. 0.]
# Actual Demand: [0. 3. 0.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: 181.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 4
# Stock Level: [[23. 25. 33.]]
# Planned Demand: [8. 0. 4.]
# Actual Demand: [7. 0. 2.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: -42.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 5
# Stock Level: [[42. 15. 62.]]
# Planned Demand: [ 0. 13.  0.]
# Actual Demand: [ 0. 13.  0.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: 177.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 5
# Stock Level: [[60. 43. 52.]]
# Planned Demand: [ 0. 10.  0.]
# Actual Demand: [0. 8. 0.]
# Action: [15, 0, 15]
# Order: [15 15 15]
# Reward: -78.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 0], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 5
# Stock Level: [[39. 25. 45.]]
# Planned Demand: [0. 0. 6.]
# Actual Demand: [ 0.  0. 11.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: 523.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 5
# Stock Level: [[20. 37. 44.]]
# Planned Demand: [12.  0.  3.]
# Actual Demand: [13.  0.  3.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: 324.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 5
# Stock Level: [[31. 11. 62.]]
# Planned Demand: [ 0. 16.  0.]
# Actual Demand: [ 0. 19.  0.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: 461.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 5
# Stock Level: [[35. 42. 38.]]
# Planned Demand: [0. 6. 0.]
# Actual Demand: [0. 5. 0.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: 183.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 5
# Stock Level: [[33. 35. 40.]]
# Planned Demand: [ 8.  0. 11.]
# Actual Demand: [ 8.  0. 10.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: 0.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 5
# Stock Level: [[38. 40. 45.]]
# Planned Demand: [0. 0. 3.]
# Actual Demand: [0. 0. 3.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: 120.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 6
# Stock Level: [[48. 30. 66.]]
# Planned Demand: [10.  0. 10.]
# Actual Demand: [ 9.  0. 11.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: 181.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 6
# Stock Level: [[66. 54. 67.]]
# Planned Demand: [8. 8. 0.]
# Actual Demand: [9. 4. 0.]
# Action: [0, 0, 0]
# Order: [15 15 15]
# Reward: 69.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 0], maxlen=3),
#     'B': deque([15, 0, 0], maxlen=3),
#     'C': deque([15, 15, 0], maxlen=3)}
#
# Episode Length: 6
# Stock Level: [[54. 40. 60.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: 146.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 6
# Stock Level: [[25. 37. 59.]]
# Planned Demand: [11. 10.  0.]
# Actual Demand: [10. 15.  0.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: 250.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 6
# Stock Level: [[46. 26. 66.]]
# Planned Demand: [ 0.  0. 10.]
# Actual Demand: [ 0.  0. 11.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: 308.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 6
# Stock Level: [[42. 57. 53.]]
# Planned Demand: [9. 0. 0.]
# Actual Demand: [8. 0. 0.]
# Action: [0, 0, 0]
# Order: [15 15 15]
# Reward: 23.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 0], maxlen=3),
#     'B': deque([15, 15, 0], maxlen=3),
#     'C': deque([15, 15, 0], maxlen=3)}
#
# Episode Length: 6
# Stock Level: [[48. 50. 55.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: 286.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 6
# Stock Level: [[39. 55. 52.]]
# Planned Demand: [14.  0.  9.]
# Actual Demand: [14.  0.  8.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: -21.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 7
# Stock Level: [[50. 29. 70.]]
# Planned Demand: [14. 15. 11.]
# Actual Demand: [13. 16. 11.]
# Action: [15, 0, 0]
# Order: [15 15 15]
# Reward: 308.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 0], maxlen=3),
#     'C': deque([15, 15, 0], maxlen=3)}
#
# Episode Length: 7
# Stock Level: [[81. 69. 76.]]
# Planned Demand: [0. 0. 6.]
# Actual Demand: [0. 0. 6.]
# Action: [0, 0, 0]
# Order: [15 15 15]
# Reward: 166.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([15, 0, 0], maxlen=3)}
#
# Episode Length: 7
# Stock Level: [[69. 55. 69.]]
# Planned Demand: [0. 0. 9.]
# Actual Demand: [0. 0. 6.]
# Action: [0, 0, 0]
# Order: [15 15 15]
# Reward: -96.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 0], maxlen=3),
#     'B': deque([15, 15, 0], maxlen=3),
#     'C': deque([15, 15, 0], maxlen=3)}
#
# Episode Length: 7
# Stock Level: [[40. 52. 74.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: 420.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 7
# Stock Level: [[61. 30. 70.]]
# Planned Demand: [ 0. 10.  6.]
# Actual Demand: [ 0. 11. 11.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: 131.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 7
# Stock Level: [[49. 62. 67.]]
# Planned Demand: [13. 13.  4.]
# Actual Demand: [ 8. 10.  1.]
# Action: [0, 0, 0]
# Order: [15 15 15]
# Reward: 84.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 0, 0], maxlen=3),
#     'B': deque([15, 0, 0], maxlen=3),
#     'C': deque([15, 0, 0], maxlen=3)}
#
# Episode Length: 7
# Stock Level: [[63. 65. 65.]]
# Planned Demand: [0. 0. 4.]
# Actual Demand: [0. 0. 5.]
# Action: [0, 0, 0]
# Order: [15 15 15]
# Reward: -96.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 0], maxlen=3),
#     'B': deque([15, 15, 0], maxlen=3),
#     'C': deque([15, 15, 0], maxlen=3)}
#
# Episode Length: 7
# Stock Level: [[47. 70. 59.]]
# Planned Demand: [10.  0. 10.]
# Actual Demand: [7. 0. 8.]
# Action: [0, 0, 0]
# Order: [15 15 15]
# Reward: 347.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 0], maxlen=3),
#     'B': deque([15, 15, 0], maxlen=3),
#     'C': deque([15, 15, 0], maxlen=3)}
#
# Episode Length: 8
# Stock Level: [[55. 44. 77.]]
# Planned Demand: [ 8.  0. 12.]
# Actual Demand: [10.  0.  8.]
# Action: [15, 0, 0]
# Order: [15 15 15]
# Reward: 719.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 0, 0], maxlen=3),
#     'C': deque([15, 0, 0], maxlen=3)}
#
# Episode Length: 8
# Stock Level: [[89. 63. 91.]]
# Planned Demand: [11.  7.  0.]
# Actual Demand: [7. 6. 0.]
# Action: [0, 0, 0]
# Order: [15  0 15]
# Reward: 7.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 8
# Stock Level: [[84. 64. 78.]]
# Planned Demand: [ 0. 10.  7.]
# Actual Demand: [0. 6. 6.]
# Action: [0, 0, 0]
# Order: [15 15 15]
# Reward: 23.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 0, 0], maxlen=3),
#     'B': deque([15, 0, 0], maxlen=3),
#     'C': deque([15, 0, 0], maxlen=3)}
#
# Episode Length: 8
# Stock Level: [[48. 60. 89.]]
# Planned Demand: [8. 9. 0.]
# Actual Demand: [7. 7. 0.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: -102.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 8
# Stock Level: [[71. 38. 70.]]
# Planned Demand: [10.  7. 14.]
# Actual Demand: [ 5.  7. 15.]
# Action: [0, 0, 0]
# Order: [15 15 15]
# Reward: 340.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 0], maxlen=3),
#     'B': deque([15, 15, 0], maxlen=3),
#     'C': deque([15, 15, 0], maxlen=3)}
#
# Episode Length: 8
# Stock Level: [[64. 72. 70.]]
# Planned Demand: [ 0.  9. 14.]
# Actual Demand: [ 0.  5. 12.]
# Action: [0, 0, 0]
# Order: [15 15 15]
# Reward: 291.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 8
# Stock Level: [[78. 80. 80.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 0, 0]
# Order: [15 15 15]
# Reward: 3.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 0, 0], maxlen=3),
#     'B': deque([15, 0, 0], maxlen=3),
#     'C': deque([15, 0, 0], maxlen=3)}
#
# Episode Length: 8
# Stock Level: [[62. 74. 68.]]
# Planned Demand: [0. 8. 9.]
# Actual Demand: [ 0. 11.  6.]
# Action: [0, 0, 0]
# Order: [15 15 15]
# Reward: 212.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 0, 0], maxlen=3),
#     'B': deque([15, 0, 0], maxlen=3),
#     'C': deque([15, 0, 0], maxlen=3)}
#
# Episode Length: 9
# Stock Level: [[70. 55. 85.]]
# Planned Demand: [0. 7. 7.]
# Actual Demand: [0. 4. 7.]
# Action: [0, 0, 0]
# Order: [15 15 15]
# Reward: 265.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 9
# Stock Level: [[78. 63. 76.]]
# Planned Demand: [10.  0. 10.]
# Actual Demand: [11.  0. 15.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 138.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 9
# Stock Level: [[99. 79. 80.]]
# Planned Demand: [ 0.  0. 12.]
# Actual Demand: [ 0.  0. 13.]
# Action: [0, 0, 0]
# Order: [15 15 15]
# Reward: 127.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 9
# Stock Level: [[63. 63. 92.]]
# Planned Demand: [ 0. 13. 12.]
# Actual Demand: [ 0. 12. 12.]
# Action: [0, 0, 0]
# Order: [15 15 15]
# Reward: 162.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 0], maxlen=3),
#     'B': deque([15, 15, 0], maxlen=3),
#     'C': deque([15, 15, 0], maxlen=3)}
#
# Episode Length: 9
# Stock Level: [[73. 47. 73.]]
# Planned Demand: [13.  8. 11.]
# Actual Demand: [13.  6. 12.]
# Action: [0, 0, 0]
# Order: [15 15 15]
# Reward: 450.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 0, 0], maxlen=3),
#     'B': deque([15, 0, 0], maxlen=3),
#     'C': deque([15, 0, 0], maxlen=3)}
#
# Episode Length: 9
# Stock Level: [[52. 59. 60.]]
# Planned Demand: [12. 14. 11.]
# Actual Demand: [12. 13. 10.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 237.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 9
# Stock Level: [[93. 82. 89.]]
# Planned Demand: [ 0. 15.  7.]
# Actual Demand: [ 0. 13.  6.]
# Action: [0, 0, 0]
# Order: [15 15 15]
# Reward: -119.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 9
# Stock Level: [[77. 89. 76.]]
# Planned Demand: [0. 0. 7.]
# Actual Demand: [0. 0. 7.]
# Action: [0, 0, 0]
# Order: [15 15 15]
# Reward: 238.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 10
# Stock Level: [[85. 55. 74.]]
# Planned Demand: [ 0.  0. 11.]
# Actual Demand: [ 0.  0. 11.]
# Action: [0, 0, 0]
# Order: [15  0  0]
# Reward: 115.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 10
# Stock Level: [[78. 63. 76.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 411.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 10
# Stock Level: [[99. 64. 76.]]
# Planned Demand: [ 0. 12.  8.]
# Actual Demand: [ 0. 15.  4.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 131.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 10
# Stock Level: [[66. 78. 99.]]
# Planned Demand: [14.  2. 11.]
# Actual Demand: [12.  0.  8.]
# Action: [0, 0, 0]
# Order: [15 15 15]
# Reward: 371.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 0, 0], maxlen=3),
#     'B': deque([15, 0, 0], maxlen=3),
#     'C': deque([15, 0, 0], maxlen=3)}
#
# Episode Length: 10
# Stock Level: [[88. 62. 80.]]
# Planned Demand: [0. 0. 9.]
# Actual Demand: [0. 0. 8.]
# Action: [0, 0, 0]
# Order: [15 15 15]
# Reward: 523.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 10
# Stock Level: [[52. 49. 49.]]
# Planned Demand: [ 0. 10. 10.]
# Actual Demand: [ 0. 10. 11.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 614.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 10
# Stock Level: [[83. 82. 89.]]
# Planned Demand: [9. 0. 0.]
# Actual Demand: [10.  0.  0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 248.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 10
# Stock Level: [[70. 89. 76.]]
# Planned Demand: [8. 0. 0.]
# Actual Demand: [7. 0. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 19.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 11
# Stock Level: [[92. 55. 62.]]
# Planned Demand: [ 9.  0. 13.]
# Actual Demand: [ 8.  0. 12.]
# Action: [0, 0, 0]
# Order: [15  0  0]
# Reward: 113.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 11
# Stock Level: [[71. 47. 76.]]
# Planned Demand: [ 7. 13.  0.]
# Actual Demand: [ 7. 16.  0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: -108.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 11
# Stock Level: [[99. 54. 73.]]
# Planned Demand: [ 0. 10.  4.]
# Actual Demand: [ 0. 10.  3.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 260.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 11
# Stock Level: [[ 81.  93. 114.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 0, 0]
# Order: [15 15 15]
# Reward: 278.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 11
# Stock Level: [[82. 62. 67.]]
# Planned Demand: [ 7.  0. 11.]
# Actual Demand: [ 6.  0. 13.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 45.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 11
# Stock Level: [[41. 38. 33.]]
# Planned Demand: [12. 11. 15.]
# Actual Demand: [11. 11. 16.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 345.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 11
# Stock Level: [[83. 73. 83.]]
# Planned Demand: [ 0. 10.  9.]
# Actual Demand: [0. 9. 6.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 73.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 11
# Stock Level: [[62. 78. 76.]]
# Planned Demand: [ 8. 11.  0.]
# Actual Demand: [ 8. 11.  0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 22.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 12
# Stock Level: [[92. 55. 62.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 295.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 12
# Stock Level: [[71. 31. 68.]]
# Planned Demand: [ 0. 12. 10.]
# Actual Demand: [ 0. 16.  8.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 363.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 12
# Stock Level: [[99. 54. 69.]]
# Planned Demand: [ 0.  0. 10.]
# Actual Demand: [0. 0. 4.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 147.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 12
# Stock Level: [[ 81.  85. 107.]]
# Planned Demand: [0. 8. 8.]
# Actual Demand: [0. 8. 7.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: -144.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 12
# Stock Level: [[68. 52. 67.]]
# Planned Demand: [14. 10.  0.]
# Actual Demand: [14. 10.  0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 274.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 12
# Stock Level: [[37. 28. 26.]]
# Planned Demand: [ 8. 10.  6.]
# Actual Demand: [ 4. 10.  7.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 704.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 15], maxlen=3),
#     'B': deque([0, 0, 15], maxlen=3),
#     'C': deque([0, 0, 15], maxlen=3)}
#
# Episode Length: 12
# Stock Level: [[77. 73. 83.]]
# Planned Demand: [6. 0. 0.]
# Actual Demand: [6. 0. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 180.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 12
# Stock Level: [[62. 66. 76.]]
# Planned Demand: [ 0. 10.  0.]
# Actual Demand: [ 0. 12.  0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 272.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 13
# Stock Level: [[81. 41. 62.]]
# Planned Demand: [12. 12.  0.]
# Actual Demand: [11. 14.  0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: -104.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 13
# Stock Level: [[58. 25. 65.]]
# Planned Demand: [12.  5.  1.]
# Actual Demand: [13.  6.  3.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 395.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 15], maxlen=3),
#     'B': deque([0, 0, 15], maxlen=3),
#     'C': deque([0, 0, 15], maxlen=3)}
#
# Episode Length: 13
# Stock Level: [[99. 54. 69.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: -31.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 13
# Stock Level: [[ 66.  72. 107.]]
# Planned Demand: [14. 14.  0.]
# Actual Demand: [15. 13.  0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 163.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 13
# Stock Level: [[68. 50. 64.]]
# Planned Demand: [0. 7. 7.]
# Actual Demand: [0. 2. 3.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 386.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 13
# Stock Level: [[37. 28. 17.]]
# Planned Demand: [ 0.  0. 10.]
# Actual Demand: [0. 0. 9.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 355.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 15, 15], maxlen=3),
#     'B': deque([0, 15, 15], maxlen=3),
#     'C': deque([0, 15, 15], maxlen=3)}
#
# Episode Length: 13
# Stock Level: [[67. 73. 83.]]
# Planned Demand: [11.  0.  0.]
# Actual Demand: [10.  0.  0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 3.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 13
# Stock Level: [[62. 66. 68.]]
# Planned Demand: [ 0.  0. 10.]
# Actual Demand: [0. 0. 8.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 138.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 14
# Stock Level: [[81. 28. 50.]]
# Planned Demand: [ 0. 11. 10.]
# Actual Demand: [ 0. 13. 12.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 408.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 14
# Stock Level: [[48. 20. 61.]]
# Planned Demand: [ 8. 10.  7.]
# Actual Demand: [10.  5.  4.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 346.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 15, 15], maxlen=3),
#     'B': deque([0, 15, 15], maxlen=3),
#     'C': deque([0, 15, 15], maxlen=3)}
#
# Episode Length: 14
# Stock Level: [[99. 54. 69.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: -111.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 14
# Stock Level: [[53. 60. 97.]]
# Planned Demand: [15. 12.  9.]
# Actual Demand: [13. 12. 10.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 437.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 14
# Stock Level: [[68. 50. 64.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 9.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 14
# Stock Level: [[37. 28. 17.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 119.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 14
# Stock Level: [[52. 69. 83.]]
# Planned Demand: [15.  4.  0.]
# Actual Demand: [15.  4.  0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 88.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 14
# Stock Level: [[55. 57. 68.]]
# Planned Demand: [ 4. 12.  0.]
# Actual Demand: [7. 9. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 62.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 15
# Stock Level: [[69. 28. 40.]]
# Planned Demand: [12.  0. 11.]
# Actual Demand: [12.  0. 10.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 420.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 15
# Stock Level: [[48.  7. 51.]]
# Planned Demand: [ 0. 10. 11.]
# Actual Demand: [ 0. 13. 10.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 296.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 15
# Stock Level: [[90. 46. 65.]]
# Planned Demand: [ 8. 10.  5.]
# Actual Demand: [9. 8. 4.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: -111.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 15
# Stock Level: [[49. 60. 97.]]
# Planned Demand: [7. 0. 0.]
# Actual Demand: [4. 0. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 595.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 15
# Stock Level: [[68. 45. 55.]]
# Planned Demand: [ 0.  8. 13.]
# Actual Demand: [0. 5. 9.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: -91.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 15
# Stock Level: [[52. 33. 32.]]
# Planned Demand: [ 0. 11.  0.]
# Actual Demand: [ 0. 10.  0.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: -60.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 15
# Stock Level: [[52. 69. 79.]]
# Planned Demand: [0. 0. 6.]
# Actual Demand: [0. 0. 4.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 278.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 15
# Stock Level: [[55. 56. 61.]]
# Planned Demand: [0. 1. 7.]
# Actual Demand: [0. 1. 7.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 230.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 16
# Stock Level: [[64. 23. 40.]]
# Planned Demand: [8. 8. 0.]
# Actual Demand: [5. 5. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 371.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 16
# Stock Level: [[56. 22. 57.]]
# Planned Demand: [ 6.  0. 10.]
# Actual Demand: [7. 0. 9.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: 387.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 16
# Stock Level: [[90. 46. 65.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 319.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 16
# Stock Level: [[41. 54. 88.]]
# Planned Demand: [ 7.  9. 10.]
# Actual Demand: [8. 6. 9.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: -23.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 16
# Stock Level: [[68. 45. 39.]]
# Planned Demand: [ 0.  0. 15.]
# Actual Demand: [ 0.  0. 16.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 196.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 16
# Stock Level: [[54. 35. 47.]]
# Planned Demand: [15. 12.  0.]
# Actual Demand: [13. 13.  0.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: 122.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 16
# Stock Level: [[41. 69. 67.]]
# Planned Demand: [10.  0. 13.]
# Actual Demand: [11.  0. 12.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: -20.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 16
# Stock Level: [[55. 46. 49.]]
# Planned Demand: [ 0.  7. 11.]
# Actual Demand: [ 0. 10. 12.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 74.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 17
# Stock Level: [[57. 14. 40.]]
# Planned Demand: [ 8. 10.  0.]
# Actual Demand: [7. 9. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 136.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 17
# Stock Level: [[66. 26. 72.]]
# Planned Demand: [ 9. 11.  0.]
# Actual Demand: [ 5. 11.  0.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: 233.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 17
# Stock Level: [[85. 46. 65.]]
# Planned Demand: [8. 0. 0.]
# Actual Demand: [5. 0. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: -100.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 17
# Stock Level: [[30. 46. 88.]]
# Planned Demand: [9. 7. 0.]
# Actual Demand: [11.  8.  0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 368.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 17
# Stock Level: [[59. 41. 39.]]
# Planned Demand: [6. 6. 0.]
# Actual Demand: [9. 4. 0.]
# Action: [0, 15, 15]
# Order: [0 0 0]
# Reward: 244.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 15], maxlen=3),
#     'C': deque([0, 0, 15], maxlen=3)}
#
# Episode Length: 17
# Stock Level: [[59. 50. 62.]]
# Planned Demand: [10.  0.  0.]
# Actual Demand: [10.  0.  0.]
# Action: [15, 0, 15]
# Order: [15 15 15]
# Reward: 432.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 0], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 17
# Stock Level: [[41. 69. 67.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 371.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 17
# Stock Level: [[44. 39. 47.]]
# Planned Demand: [12.  9.  2.]
# Actual Demand: [11.  7.  2.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 365.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 18
# Stock Level: [[57.  9. 33.]]
# Planned Demand: [0. 6. 8.]
# Actual Demand: [0. 5. 7.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 264.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 15], maxlen=3),
#     'B': deque([0, 0, 15], maxlen=3),
#     'C': deque([0, 0, 15], maxlen=3)}
#
# Episode Length: 18
# Stock Level: [[81. 41. 81.]]
# Planned Demand: [0. 0. 7.]
# Actual Demand: [0. 0. 6.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: 218.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 18
# Stock Level: [[74. 35. 65.]]
# Planned Demand: [ 8. 11.  0.]
# Actual Demand: [11. 11.  0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 2.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 18
# Stock Level: [[30. 46. 88.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [15, 0, 0]
# Order: [0 0 0]
# Reward: 298.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 15], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 18
# Stock Level: [[59. 41. 39.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 177.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 15], maxlen=3),
# ...
# {   'A': deque([15, 0, 0], maxlen=3),
#     'B': deque([15, 0, 0], maxlen=3),
#     'C': deque([15, 0, 0], maxlen=3)}
#
# Episode Length: 25
# Stock Level: [[90. 46. 72.]]
# Planned Demand: [ 9.  0. 11.]
# Actual Demand: [ 6.  0. 12.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 167.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 25
# Stock Level: [[94. 46. 79.]]
# Planned Demand: [8. 0. 6.]
# Actual Demand: [7. 0. 4.]
# Action: [0, 0, 0]
# Order: [15 15 15]
# Reward: -112.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 0], maxlen=3),
#     'B': deque([15, 15, 0], maxlen=3),
#     'C': deque([15, 15, 0], maxlen=3)}
#
# Episode Length: 25
# Stock Level: [[57. 52. 81.]]
# Planned Demand: [ 9.  0. 17.]
# Actual Demand: [13.  0. 16.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: 173.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 25
# Stock Level: [[ 46. 104.  96.]]
# Planned Demand: [17.  0.  9.]
# Actual Demand: [16.  0.  7.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: -134.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 25
# Stock Level: [[68. 49. 58.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: -87.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 25
# Stock Level: [[40. 42. 53.]]
# Planned Demand: [ 8.  6. 12.]
# Actual Demand: [ 5.  6. 10.]
# Action: [15, 15, 15]
# Order: [15  0 15]
# Reward: 437.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([0, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 25
# Stock Level: [[ 89.  73. 106.]]
# Planned Demand: [6. 6. 6.]
# Actual Demand: [7. 5. 6.]
# Action: [0, 0, 0]
# Order: [15 15 15]
# Reward: -100.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 26
# Stock Level: [[140.  54.  68.]]
# Planned Demand: [ 0.  0. 11.]
# Actual Demand: [ 0.  0. 13.]
# Action: [0, 0, 0]
# Order: [15 15 15]
# Reward: -55.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 26
# Stock Level: [[86. 46. 72.]]
# Planned Demand: [7. 0. 0.]
# Actual Demand: [4. 0. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 256.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 26
# Stock Level: [[109.  55.  89.]]
# Planned Demand: [0. 9. 6.]
# Actual Demand: [0. 6. 5.]
# Action: [0, 0, 0]
# Order: [15 15 15]
# Reward: 110.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 0, 0], maxlen=3),
#     'B': deque([15, 0, 0], maxlen=3),
#     'C': deque([15, 0, 0], maxlen=3)}
#
# Episode Length: 26
# Stock Level: [[72. 67. 96.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 0, 0]
# Order: [15 15 15]
# Reward: 465.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 0], maxlen=3),
#     'B': deque([15, 15, 0], maxlen=3),
#     'C': deque([15, 15, 0], maxlen=3)}
#
# Episode Length: 26
# Stock Level: [[ 46. 104.  86.]]
# Planned Demand: [ 0.  0. 10.]
# Actual Demand: [ 0.  0. 10.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 337.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 26
# Stock Level: [[68. 35. 45.]]
# Planned Demand: [ 0. 12. 13.]
# Actual Demand: [ 0. 14. 13.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: -87.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 26
# Stock Level: [[44. 25. 68.]]
# Planned Demand: [11. 14.  0.]
# Actual Demand: [11. 17.  0.]
# Action: [15, 0, 15]
# Order: [15  0 15]
# Reward: 333.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 0], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 26
# Stock Level: [[89. 73. 94.]]
# Planned Demand: [ 0.  0. 12.]
# Actual Demand: [ 0.  0. 12.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 226.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 27
# Stock Level: [[140.  54.  68.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 129.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 27
# Stock Level: [[76. 46. 72.]]
# Planned Demand: [9. 0. 0.]
# Actual Demand: [10.  0.  0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: -22.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 27
# Stock Level: [[113.  61. 104.]]
# Planned Demand: [ 8. 11.  0.]
# Actual Demand: [11.  9.  0.]
# Action: [0, 0, 0]
# Order: [15 15 15]
# Reward: 93.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 27
# Stock Level: [[ 81.  82. 111.]]
# Planned Demand: [9. 0. 0.]
# Actual Demand: [6. 0. 0.]
# Action: [0, 0, 0]
# Order: [15 15 15]
# Reward: -117.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 0, 0], maxlen=3),
#     'B': deque([15, 0, 0], maxlen=3),
#     'C': deque([15, 0, 0], maxlen=3)}
#
# Episode Length: 27
# Stock Level: [[46. 95. 81.]]
# Planned Demand: [0. 9. 6.]
# Actual Demand: [0. 9. 5.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 82.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 27
# Stock Level: [[68. 35. 45.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 466.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 27
# Stock Level: [[54. 40. 70.]]
# Planned Demand: [ 3.  0. 11.]
# Actual Demand: [ 5.  0. 13.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: 478.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 0, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 27
# Stock Level: [[89. 73. 86.]]
# Planned Demand: [0. 0. 7.]
# Actual Demand: [0. 0. 8.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 112.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 28
# Stock Level: [[140.  54.  61.]]
# Planned Demand: [0. 0. 8.]
# Actual Demand: [0. 0. 7.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: -131.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 28
# Stock Level: [[71. 46. 66.]]
# Planned Demand: [9. 0. 7.]
# Actual Demand: [5. 0. 6.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 103.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 28
# Stock Level: [[113.  46. 104.]]
# Planned Demand: [ 0. 14.  0.]
# Actual Demand: [ 0. 15.  0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 261.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 28
# Stock Level: [[ 96.  97. 126.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 0, 0]
# Order: [15 15 15]
# Reward: -17.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 28
# Stock Level: [[42. 78. 81.]]
# Planned Demand: [ 8. 13.  0.]
# Actual Demand: [ 4. 17.  0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 169.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 28
# Stock Level: [[68. 26. 45.]]
# Planned Demand: [ 0. 10.  0.]
# Actual Demand: [0. 9. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: -74.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 28
# Stock Level: [[54. 38. 85.]]
# Planned Demand: [14. 16.  0.]
# Actual Demand: [15. 17.  0.]
# Action: [15, 0, 0]
# Order: [15 15 15]
# Reward: 258.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([0, 15, 0], maxlen=3),
#     'C': deque([15, 15, 0], maxlen=3)}
#
# Episode Length: 28
# Stock Level: [[81. 73. 86.]]
# Planned Demand: [10.  0.  0.]
# Actual Demand: [8. 0. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 36.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 29
# Stock Level: [[140.  43.  61.]]
# Planned Demand: [ 0. 14.  0.]
# Actual Demand: [ 0. 11.  0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 12.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 29
# Stock Level: [[57. 37. 66.]]
# Planned Demand: [15. 10.  0.]
# Actual Demand: [14.  9.  0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 128.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 29
# Stock Level: [[103.  46.  90.]]
# Planned Demand: [11.  0. 12.]
# Actual Demand: [10.  0. 14.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 168.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 29
# Stock Level: [[ 96.  97. 123.]]
# Planned Demand: [0. 0. 7.]
# Actual Demand: [0. 0. 3.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: -159.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 29
# Stock Level: [[42. 75. 81.]]
# Planned Demand: [0. 6. 0.]
# Actual Demand: [0. 3. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 319.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 29
# Stock Level: [[68. 26. 36.]]
# Planned Demand: [0. 0. 8.]
# Actual Demand: [0. 0. 9.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 110.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 15], maxlen=3),
#     'B': deque([0, 0, 15], maxlen=3),
#     'C': deque([0, 0, 15], maxlen=3)}
#
# Episode Length: 29
# Stock Level: [[ 60.  38. 100.]]
# Planned Demand: [10.  0.  0.]
# Actual Demand: [9. 0. 0.]
# Action: [0, 0, 0]
# Order: [15  0 15]
# Reward: 545.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 0], maxlen=3),
#     'B': deque([15, 0, 0], maxlen=3),
#     'C': deque([15, 0, 0], maxlen=3)}
#
# Episode Length: 29
# Stock Level: [[81. 73. 86.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 40.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 0
# Stock Level: [[30 28 32]]
# Planned Demand: [0. 0. 6.]
# Actual Demand: [ 7. 10.  9.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Episode Length: 0
# Stock Level: [[30 28 32]]
# Planned Demand: [12.  6.  8.]
# Actual Demand: [11.  0.  6.]
# Action: [15, 0, 15]
# Order: [0 0 0]
# Reward: 0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Episode Length: 0
# Stock Level: [[30 28 32]]
# Planned Demand: [ 0.  6. 14.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Episode Length: 0
# Stock Level: [[30 28 32]]
# Planned Demand: [15.  4. 12.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Episode Length: 0
# Stock Level: [[30 28 32]]
# Planned Demand: [9. 0. 5.]
# Actual Demand: [ 0. 14.  7.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Episode Length: 0
# Stock Level: [[30 28 32]]
# Planned Demand: [ 0.  7. 11.]
# Actual Demand: [9. 0. 9.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Episode Length: 0
# Stock Level: [[30 28 32]]
# Planned Demand: [10. 16.  0.]
# Actual Demand: [0. 0. 4.]
# Action: [0, 0, 0]
# Order: [15 15 15]
# Reward: 0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Episode Length: 0
# Stock Level: [[30 28 32]]
# Planned Demand: [6. 0. 7.]
# Actual Demand: [0. 0. 3.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
# ([4144.5], [30])

# %%
file = './Data/2024-11-06_21_last_environment_data.csv'
df = pd.read_csv(file)

# %%
plot_data(df)
