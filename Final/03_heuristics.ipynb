# %%
# Imports
# Gymnasium imports
import gymnasium as gym 
from gymnasium import Env
from gymnasium.spaces import Discrete, Box, Dict, Tuple, MultiBinary, MultiDiscrete 

import networkx as nx
from networkx.drawing.nx_agraph import graphviz_layout

# Import helpers
import numpy as np
import pandas as pd
import random
import os
import json
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm

from collections import deque

# Import stable baselines
from stable_baselines3 import PPO, A2C
from stable_baselines3.common.vec_env import VecFrameStack, DummyVecEnv
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_checker import check_env

# Import tensorflow
import tensorflow as tf
from tensorflow.keras import layers, models

# Import custom classes
from Environment.env_v8 import *
from Functions.visualization_functions import *

# Import custom functions
from Functions.deep_q_learning import *

# %%
# Configuration of the network
with open('./Config/network_config_v1.json') as file:
    network_config = file.read()

EP_LENGTH = 100 # Length of the episode

# %%
def load_config(config_file):

    with open(config_file, "r") as f:
        config = json.load(f)
    return config

def make_env(config_file="config.json"):

    config = load_config(config_file)

    env = SS_Mngmt_Env(
        network_config=network_config,
        EP_LENGTH=EP_LENGTH,
        render_mode="human",
        model_type="heuristics",
        stockout_cost=config["stockout_cost"],
        order_cost=config["order_cost"],
        item_cost=config["item_cost"],
        stock_cost=config["stock_cost"],
        item_prize=config["item_prize"],
        progressive_stock_cost=config["progressive_stock_cost"],
        stock_out_max=1000,
        order_quantities=config["order_quantities"],
        demand_mean=config["demand_mean"],
        demand_std=config["demand_std"],
        demand_noise=config["demand_noise"],
        demand_noise_std=config["demand_noise_std"],
        demand_prob=config["demand_prob"],
    )

    return env

env = make_env("./Config/env_config_v0.json")

check_env(env, warn=True)

env.render_network()
# Out:
# Node Attributes:
# Node A: {'type': 'manufacturer', 'I': 30}
# Node B: {'type': 'manufacturer', 'I': 30}
# Node C: {'type': 'manufacturer', 'I': 30}
# Node D: {'type': 'distributor'}
# Node S: {'type': 'source'}
# /Users/jonasrenfer/miniconda3/envs/rl-scm/lib/python3.12/site-packages/stable_baselines3/common/env_checker.py:263: UserWarning: Your observation order_queues has an unconventional shape (neither an image, nor a 1D vector). We recommend you to flatten the observation to have only a 1D vector or use a custom policy to properly process the data.
#   warnings.warn(

# %%
def compute_safety_stock(env, service_level=0.95):
    lead_time = {}
    for node in env.graph.nodes:
        if node not in ["S", "D"]:
            in_edges = list(env.graph.in_edges(node, data=True))
            if in_edges:
                lead_time[node] = in_edges[0][2]["L"]

    safety_stock = {}
    for node in env.graph.nodes:
        if node not in ["S", "D"]:
            z_score = norm.ppf(service_level)
            node_lead_time = lead_time.get(node, 0)
            safety_stock[node] = env.demand_mean + z_score * env.demand_std * np.sqrt(node_lead_time)

    return safety_stock

compute_safety_stock(env, service_level=0.95)
# Out:
# {'A': 15.697940105787787, 'B': 15.697940105787787, 'C': 15.697940105787787}

# %%
# Main simulation loop
episodes = 1
service_level = 0.95

# Compute safety stock for each node
safety_stock = compute_safety_stock(env, service_level)

for episode in range(1, episodes + 1):
    state = env.reset()[0]
    done = False
    score = 0 

    while not done:
        # Get current stock levels
        stock = state["inventory_levels"]
        action = [0] * len(stock)  # Initialize actions

        for i, node in enumerate(env.graph.nodes):
            if node not in ["S", "D"]:  # Ignore source and destination nodes
                # Determine safety stock level for the node
                node_safety_stock = safety_stock.get(node, 0)

                # Policy to avoid stockouts based on safety stock
                if stock[i] > node_safety_stock:
                    action[i] = 0  # No action, stock is above safety level
                elif stock[i] <= node_safety_stock:
                    action[i] = 2  # Order more stock to replenish above safety level

        # Take action and update environment
        n_state, reward, done, info, _ = env.step(action)
        score += reward

        # Optionally render the environment
        env.render()

        # Update state
        state = n_state

    print(f"Episode {episode} Score: {score}")
# Out:
# **************************************************
#
# Episode Information
# Episode Length: 1
# Stock Level (Previous Timestep): [30.0, 30.0, 30.0]
# Stock Level: [34. 45. 45.]
# Planned Demand: [9. 0. 0.]
# Actual Demand: [11.  0.  0.]
# Action: [0, 0, 0]
# Deliveries: [15 15 15]
# Step Reward: -150.3
# Total Reward: -150.3
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 2
# Stock Level (Previous Timestep): [34.0, 45.0, 45.0]
# Stock Level: [34. 45. 35.]
# Planned Demand: [0. 0. 7.]
# Actual Demand: [ 0.  0. 10.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -120.30000000000001
# Total Reward: -270.6
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 3
# Stock Level (Previous Timestep): [34.0, 45.0, 35.0]
# Stock Level: [25. 34. 35.]
# Planned Demand: [9. 9. 0.]
# Actual Demand: [ 9. 11.  0.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: 49.69999999999999
# Total Reward: -220.90000000000003
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 4
# Stock Level (Previous Timestep): [25.0, 34.0, 35.0]
# Stock Level: [25. 34. 23.]
# Planned Demand: [0. 0. 9.]
# Actual Demand: [ 0.  0. 12.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: 4.499999999999986
# Total Reward: -216.40000000000003
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 5
# Stock Level (Previous Timestep): [25.0, 34.0, 23.0]
# Stock Level: [25. 34. 23.]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -115.50000000000001
# Total Reward: -331.90000000000003
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 6
# Stock Level (Previous Timestep): [25.0, 34.0, 23.0]
# Stock Level: [25. 34. 23.]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -115.50000000000001
# Total Reward: -447.40000000000003
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 7
# Stock Level (Previous Timestep): [25.0, 34.0, 23.0]
# Stock Level: [15. 34. 23.]
# Planned Demand: [8. 0. 0.]
# Actual Demand: [10.  0.  0.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: 4.499999999999986
# Total Reward: -442.90000000000003
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 8
# Stock Level (Previous Timestep): [15.0, 34.0, 23.0]
# Stock Level: [15. 34. 10.]
# Planned Demand: [ 0.  0. 12.]
# Actual Demand: [ 0.  0. 13.]
# Action: [50, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: 10.949999999999989
# Total Reward: -431.95000000000005
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 50], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 9
# Stock Level (Previous Timestep): [15.0, 34.0, 10.0]
# Stock Level: [15. 30. 10.]
# Planned Demand: [0. 7. 0.]
# Actual Demand: [0. 4. 0.]
# Action: [50, 0, 50]
# Deliveries: [0 0 0]
# Step Reward: -111.25
# Total Reward: -543.2
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 50, 50], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 50], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 10
# Stock Level (Previous Timestep): [15.0, 30.0, 10.0]
# Stock Level: [15. 30. 10.]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [50, 0, 50]
# Deliveries: [0 0 0]
# Step Reward: -151.25
# Total Reward: -694.45
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([50, 50, 50], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 50, 50], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 11
# Stock Level (Previous Timestep): [15.0, 30.0, 10.0]
# Stock Level: [65. 16. 10.]
# Planned Demand: [ 0. 11.  0.]
# Actual Demand: [ 0. 14.  0.]
# Action: [50, 0, 50]
# Deliveries: [50  0  0]
# Step Reward: -179.05
# Total Reward: -873.5
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([50, 50, 50], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([50, 50, 50], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 12
# Stock Level (Previous Timestep): [65.0, 16.0, 10.0]
# Stock Level: [115.  16.  60.]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 0, 50]
# Deliveries: [50  0 50]
# Step Reward: -899.05
# Total Reward: -1772.55
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([50, 50, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([50, 50, 50], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 13
# Stock Level (Previous Timestep): [115.0, 16.0, 60.0]
# Stock Level: [155.  16. 100.]
# Planned Demand: [ 9.  0. 10.]
# Actual Demand: [10.  0. 10.]
# Action: [0, 0, 0]
# Deliveries: [50  0 50]
# Step Reward: -1514.05
# Total Reward: -3286.6
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([50, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([50, 50, 0], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 14
# Stock Level (Previous Timestep): [155.0, 16.0, 100.0]
# Stock Level: [205.  16. 150.]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 0, 0]
# Deliveries: [50  0 50]
# Step Reward: -3239.05
# Total Reward: -6525.65
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([50, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 15
# Stock Level (Previous Timestep): [205.0, 16.0, 150.0]
# Stock Level: [205.  16. 187.]
# Planned Demand: [ 0.  0. 10.]
# Actual Demand: [ 0.  0. 13.]
# Action: [0, 0, 0]
# Deliveries: [ 0  0 50]
# Step Reward: -3732.5
# Total Reward: -10258.15
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 16
# Stock Level (Previous Timestep): [205.0, 16.0, 187.0]
# Stock Level: [205.  16. 177.]
# Planned Demand: [0. 0. 9.]
# Actual Demand: [ 0.  0. 10.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -3580.5
# Total Reward: -13838.65
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 17
# Stock Level (Previous Timestep): [205.0, 16.0, 177.0]
# Stock Level: [196.  16. 177.]
# Planned Demand: [9. 0. 0.]
# Actual Demand: [9. 0. 0.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -3410.05
# Total Reward: -17248.7
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 18
# Stock Level (Previous Timestep): [196.0, 16.0, 177.0]
# Stock Level: [182.   5. 165.]
# Planned Demand: [ 9.  9. 11.]
# Actual Demand: [14. 11. 12.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -2648.7
# Total Reward: -19897.4
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 19
# Stock Level (Previous Timestep): [182.0, 5.0, 165.0]
# Stock Level: [182.   5. 165.]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 50, 0]
# Deliveries: [0 0 0]
# Step Reward: -3063.7
# Total Reward: -22961.100000000002
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 50], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 20
# Stock Level (Previous Timestep): [182.0, 5.0, 165.0]
# Stock Level: [182.   5. 154.]
# Planned Demand: [ 0.  0. 11.]
# Actual Demand: [ 0.  0. 11.]
# Action: [0, 50, 0]
# Deliveries: [0 0 0]
# Step Reward: -2778.25
# Total Reward: -25739.350000000002
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 50, 50], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 21
# Stock Level (Previous Timestep): [182.0, 5.0, 154.0]
# Stock Level: [182.   5. 154.]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 50, 0]
# Deliveries: [0 0 0]
# Step Reward: -2888.25
# Total Reward: -28627.600000000002
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([50, 50, 50], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 22
# Stock Level (Previous Timestep): [182.0, 5.0, 154.0]
# Stock Level: [165.  45. 145.]
# Planned Demand: [14.  9.  8.]
# Actual Demand: [17. 10.  9.]
# Action: [0, 50, 0]
# Deliveries: [ 0 50  0]
# Step Reward: -2198.75
# Total Reward: -30826.350000000002
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([50, 50, 50], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 23
# Stock Level (Previous Timestep): [165.0, 45.0, 145.0]
# Stock Level: [165.  95. 141.]
# Planned Demand: [0. 0. 7.]
# Actual Demand: [0. 0. 4.]
# Action: [0, 0, 0]
# Deliveries: [ 0 50  0]
# Step Reward: -2766.55
# Total Reward: -33592.9
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([50, 50, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 24
# Stock Level (Previous Timestep): [165.0, 95.0, 141.0]
# Stock Level: [165. 145. 131.]
# Planned Demand: [ 0.  0. 11.]
# Actual Demand: [ 0.  0. 10.]
# Action: [0, 0, 0]
# Deliveries: [ 0 50  0]
# Step Reward: -3170.55
# Total Reward: -36763.450000000004
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([50, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 25
# Stock Level (Previous Timestep): [165.0, 145.0, 131.0]
# Stock Level: [165. 195. 131.]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 0, 0]
# Deliveries: [ 0 50  0]
# Step Reward: -4120.55
# Total Reward: -40884.00000000001
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 26
# Stock Level (Previous Timestep): [165.0, 195.0, 131.0]
# Stock Level: [165. 195. 131.]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -4120.55
# Total Reward: -45004.55000000001
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 27
# Stock Level (Previous Timestep): [165.0, 195.0, 131.0]
# Stock Level: [165. 195. 120.]
# Planned Demand: [0. 0. 8.]
# Actual Demand: [ 0.  0. 11.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -3872.5
# Total Reward: -48877.05000000001
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 28
# Stock Level (Previous Timestep): [165.0, 195.0, 120.0]
# Stock Level: [165. 184. 107.]
# Planned Demand: [ 0.  9. 11.]
# Actual Demand: [ 0. 11. 13.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -3386.5
# Total Reward: -52263.55000000001
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 29
# Stock Level (Previous Timestep): [165.0, 184.0, 107.0]
# Stock Level: [165. 169. 107.]
# Planned Demand: [ 0. 13.  0.]
# Actual Demand: [ 0. 15.  0.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -3211.75
# Total Reward: -55475.30000000001
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 30
# Stock Level (Previous Timestep): [165.0, 169.0, 107.0]
# Stock Level: [165. 169. 107.]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -3361.75
# Total Reward: -58837.05000000001
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 31
# Stock Level (Previous Timestep): [165.0, 169.0, 107.0]
# Stock Level: [155. 169.  96.]
# Planned Demand: [ 9.  0. 10.]
# Actual Demand: [10.  0. 11.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -2880.1000000000004
# Total Reward: -61717.15000000001
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 32
# Stock Level (Previous Timestep): [155.0, 169.0, 96.0]
# Stock Level: [155. 169.  96.]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -3090.1000000000004
# Total Reward: -64807.25000000001
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 33
# Stock Level (Previous Timestep): [155.0, 169.0, 96.0]
# Stock Level: [145. 169.  96.]
# Planned Demand: [9. 0. 0.]
# Actual Demand: [10.  0.  0.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -2840.1000000000004
# Total Reward: -67647.35
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 34
# Stock Level (Previous Timestep): [145.0, 169.0, 96.0]
# Stock Level: [145. 152.  83.]
# Planned Demand: [ 0. 11. 10.]
# Actual Demand: [ 0. 17. 13.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -2250.8999999999996
# Total Reward: -69898.25
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 35
# Stock Level (Previous Timestep): [145.0, 152.0, 83.0]
# Stock Level: [136. 152.  71.]
# Planned Demand: [ 8.  0. 11.]
# Actual Demand: [ 9.  0. 12.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -2122.05
# Total Reward: -72020.3
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 36
# Stock Level (Previous Timestep): [136.0, 152.0, 71.0]
# Stock Level: [136. 140.  58.]
# Planned Demand: [ 0. 12. 12.]
# Actual Demand: [ 0. 12. 13.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -1823.0
# Total Reward: -73843.3
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 37
# Stock Level (Previous Timestep): [136.0, 140.0, 58.0]
# Stock Level: [132. 131.  45.]
# Planned Demand: [ 6.  9. 11.]
# Actual Demand: [ 4.  9. 13.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -1570.5
# Total Reward: -75413.8
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 38
# Stock Level (Previous Timestep): [132.0, 131.0, 45.0]
# Stock Level: [124. 118.  45.]
# Planned Demand: [10.  9.  0.]
# Actual Demand: [ 8. 13.  0.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -1356.25
# Total Reward: -76770.05
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 39
# Stock Level (Previous Timestep): [124.0, 118.0, 45.0]
# Stock Level: [124. 110.  35.]
# Planned Demand: [ 0. 10.  9.]
# Actual Demand: [ 0.  8. 10.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -1255.0500000000002
# Total Reward: -78025.1
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 40
# Stock Level (Previous Timestep): [124.0, 110.0, 35.0]
# Stock Level: [115.  99.  27.]
# Planned Demand: [ 9. 11.  9.]
# Actual Demand: [ 9. 11.  8.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -907.75
# Total Reward: -78932.85
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 41
# Stock Level (Previous Timestep): [115.0, 99.0, 27.0]
# Stock Level: [107.  99.  27.]
# Planned Demand: [8. 0. 0.]
# Actual Demand: [8. 0. 0.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -1018.95
# Total Reward: -79951.8
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 42
# Stock Level (Previous Timestep): [107.0, 99.0, 27.0]
# Stock Level: [94. 87. 14.]
# Planned Demand: [ 9. 10. 10.]
# Actual Demand: [13. 12. 13.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -450.04999999999995
# Total Reward: -80401.85
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 43
# Stock Level (Previous Timestep): [94.0, 87.0, 14.0]
# Stock Level: [94. 77. 14.]
# Planned Demand: [0. 9. 0.]
# Actual Demand: [ 0. 10.  0.]
# Action: [0, 0, 50]
# Deliveries: [0 0 0]
# Step Reward: -693.05
# Total Reward: -81094.90000000001
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 50], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 44
# Stock Level (Previous Timestep): [94.0, 77.0, 14.0]
# Stock Level: [94. 66. 14.]
# Planned Demand: [0. 8. 0.]
# Actual Demand: [ 0. 11.  0.]
# Action: [0, 0, 50]
# Deliveries: [0 0 0]
# Step Reward: -604.4
# Total Reward: -81699.3
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 50, 50], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 45
# Stock Level (Previous Timestep): [94.0, 66.0, 14.0]
# Stock Level: [84. 57. 14.]
# Planned Demand: [5. 8. 0.]
# Actual Demand: [10.  9.  0.]
# Action: [0, 0, 50]
# Deliveries: [0 0 0]
# Step Reward: -380.04999999999995
# Total Reward: -82079.35
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([50, 50, 50], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 46
# Stock Level (Previous Timestep): [84.0, 57.0, 14.0]
# Stock Level: [70. 57. 64.]
# Planned Demand: [11.  0.  0.]
# Actual Demand: [14.  0.  0.]
# Action: [0, 0, 50]
# Deliveries: [ 0  0 50]
# Step Reward: -517.25
# Total Reward: -82596.6
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([50, 50, 50], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 47
# Stock Level (Previous Timestep): [70.0, 57.0, 64.0]
# Stock Level: [ 57.  57. 114.]
# Planned Demand: [12.  0.  0.]
# Actual Demand: [13.  0.  0.]
# Action: [0, 0, 0]
# Deliveries: [ 0  0 50]
# Step Reward: -844.7
# Total Reward: -83441.3
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([50, 50, 0], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 48
# Stock Level (Previous Timestep): [57.0, 57.0, 114.0]
# Stock Level: [ 57.  41. 164.]
# Planned Demand: [ 0. 13.  0.]
# Actual Demand: [ 0. 16.  0.]
# Action: [0, 0, 0]
# Deliveries: [ 0  0 50]
# Step Reward: -1431.3000000000002
# Total Reward: -84872.6
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([50, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 49
# Stock Level (Previous Timestep): [57.0, 41.0, 164.0]
# Stock Level: [ 50.  30. 214.]
# Planned Demand: [ 8. 10.  0.]
# Actual Demand: [ 7. 11.  0.]
# Action: [0, 0, 0]
# Deliveries: [ 0  0 50]
# Step Reward: -2279.8
# Total Reward: -87152.40000000001
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 50
# Stock Level (Previous Timestep): [50.0, 30.0, 214.0]
# Stock Level: [ 50.  30. 214.]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -2459.8
# Total Reward: -89612.20000000001
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 51
# Stock Level (Previous Timestep): [50.0, 30.0, 214.0]
# Stock Level: [ 39.  30. 214.]
# Planned Demand: [12.  0.  0.]
# Actual Demand: [11.  0.  0.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -2300.8500000000004
# Total Reward: -91913.05000000002
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 52
# Stock Level (Previous Timestep): [39.0, 30.0, 214.0]
# Stock Level: [ 39.  17. 201.]
# Planned Demand: [ 0. 11. 12.]
# Actual Demand: [ 0. 13. 13.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -1850.5500000000002
# Total Reward: -93763.60000000002
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 53
# Stock Level (Previous Timestep): [39.0, 17.0, 201.0]
# Stock Level: [ 39.   7. 201.]
# Planned Demand: [0. 8. 0.]
# Actual Demand: [ 0. 10.  0.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -1998.5500000000002
# Total Reward: -95762.15000000002
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 54
# Stock Level (Previous Timestep): [39.0, 7.0, 201.0]
# Stock Level: [ 39.   7. 201.]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 50, 0]
# Deliveries: [0 0 0]
# Step Reward: -2143.55
# Total Reward: -97905.70000000003
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 50], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 55
# Stock Level (Previous Timestep): [39.0, 7.0, 201.0]
# Stock Level: [ 39.   7. 201.]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 50, 0]
# Deliveries: [0 0 0]
# Step Reward: -2143.55
# Total Reward: -100049.25000000003
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 50, 50], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  0
# **************************************************
#
# Episode Information
# Episode Length: 56
# Stock Level (Previous Timestep): [39.0, 7.0, 201.0]
# Stock Level: [ 28.   0. 201.]
# Planned Demand: [ 8. 11.  0.]
# Actual Demand: [11. 13.  0.]
# Action: [0, 50, 0]
# Deliveries: [0 0 0]
# Step Reward: -3324.25
# Total Reward: -103373.50000000003
#
# Backlog:
# [False, True, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([50, 50, 50], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  1
# **************************************************
#
# Episode Information
# Episode Length: 57
# Stock Level (Previous Timestep): [28.0, 0.0, 201.0]
# Stock Level: [ 14.  44. 201.]
# Planned Demand: [9. 0. 0.]
# Actual Demand: [14.  0.  0.]
# Action: [0, 50, 0]
# Deliveries: [ 0 50  0]
# Step Reward: -1971.65
# Total Reward: -105345.15000000002
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([50, 50, 50], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  1
# **************************************************
#
# Episode Information
# Episode Length: 58
# Stock Level (Previous Timestep): [14.0, 44.0, 201.0]
# Stock Level: [ 14.  94. 201.]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [50, 0, 0]
# Deliveries: [ 0 50  0]
# Step Reward: -2516.65
# Total Reward: -107861.80000000002
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 50], maxlen=3),
#     'B': deque([50, 50, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  1
# **************************************************
#
# Episode Information
# Episode Length: 59
# Stock Level (Previous Timestep): [14.0, 94.0, 201.0]
# Stock Level: [ 14. 144. 201.]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [50, 0, 0]
# Deliveries: [ 0 50  0]
# Step Reward: -3111.65
# Total Reward: -110973.45000000001
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 50, 50], maxlen=3),
#     'B': deque([50, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  1
# **************************************************
#
# Episode Information
# Episode Length: 60
# Stock Level (Previous Timestep): [14.0, 144.0, 201.0]
# Stock Level: [  4. 194. 201.]
# Planned Demand: [8. 0. 0.]
# Actual Demand: [10.  0.  0.]
# Action: [50, 0, 0]
# Deliveries: [ 0 50  0]
# Step Reward: -3847.6500000000005
# Total Reward: -114821.1
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([50, 50, 50], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  1
# **************************************************
#
# Episode Information
# Episode Length: 61
# Stock Level (Previous Timestep): [4.0, 194.0, 201.0]
# Stock Level: [ 44. 194. 191.]
# Planned Demand: [ 9.  0. 11.]
# Actual Demand: [10.  0. 10.]
# Action: [50, 0, 0]
# Deliveries: [50  0  0]
# Step Reward: -3647.6500000000005
# Total Reward: -118468.75
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([50, 50, 50], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  1
# **************************************************
#
# Episode Information
# Episode Length: 62
# Stock Level (Previous Timestep): [44.0, 194.0, 191.0]
# Stock Level: [ 94. 187. 191.]
# Planned Demand: [0. 7. 0.]
# Actual Demand: [0. 7. 0.]
# Action: [0, 0, 0]
# Deliveries: [50  0  0]
# Step Reward: -3944.3
# Total Reward: -122413.05
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([50, 50, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  1
# **************************************************
#
# Episode Information
# Episode Length: 63
# Stock Level (Previous Timestep): [94.0, 187.0, 191.0]
# Stock Level: [144. 177. 191.]
# Planned Demand: [0. 9. 0.]
# Actual Demand: [ 0. 10.  0.]
# Action: [0, 0, 0]
# Deliveries: [50  0  0]
# Step Reward: -4327.3
# Total Reward: -126740.35
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([50, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  1
# **************************************************
#
# Episode Information
# Episode Length: 64
# Stock Level (Previous Timestep): [144.0, 177.0, 191.0]
# Stock Level: [182. 177. 191.]
# Planned Demand: [14.  0.  0.]
# Actual Demand: [12.  0.  0.]
# Action: [0, 0, 0]
# Deliveries: [50  0  0]
# Step Reward: -4926.700000000001
# Total Reward: -131667.05000000002
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  1
# **************************************************
#
# Episode Information
# Episode Length: 65
# Stock Level (Previous Timestep): [182.0, 177.0, 191.0]
# Stock Level: [174. 165. 191.]
# Planned Demand: [ 7. 14.  0.]
# Actual Demand: [ 8. 12.  0.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -4499.1
# Total Reward: -136166.15000000002
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  1
# **************************************************
#
# Episode Information
# Episode Length: 66
# Stock Level (Previous Timestep): [174.0, 165.0, 191.0]
# Stock Level: [161. 165. 191.]
# Planned Demand: [10.  0.  0.]
# Actual Demand: [13.  0.  0.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -4351.35
# Total Reward: -140517.50000000003
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  1
# **************************************************
#
# Episode Information
# Episode Length: 67
# Stock Level (Previous Timestep): [161.0, 165.0, 191.0]
# Stock Level: [161. 156. 178.]
# Planned Demand: [ 0.  8. 10.]
# Actual Demand: [ 0.  9. 13.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -3877.05
# Total Reward: -144394.55000000002
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  1
# **************************************************
#
# Episode Information
# Episode Length: 68
# Stock Level (Previous Timestep): [161.0, 156.0, 178.0]
# Stock Level: [150. 145. 168.]
# Planned Demand: [ 9. 11.  9.]
# Actual Demand: [11. 11. 10.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -3267.45
# Total Reward: -147662.00000000003
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  1
# **************************************************
#
# Episode Information
# Episode Length: 69
# Stock Level (Previous Timestep): [150.0, 145.0, 168.0]
# Stock Level: [150. 145. 168.]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -3587.45
# Total Reward: -151249.45000000004
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  1
# **************************************************
#
# Episode Information
# Episode Length: 70
# Stock Level (Previous Timestep): [150.0, 145.0, 168.0]
# Stock Level: [139. 138. 168.]
# Planned Demand: [9. 7. 0.]
# Actual Demand: [11.  7.  0.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -3149.45
# Total Reward: -154398.90000000005
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  1
# **************************************************
#
# Episode Information
# Episode Length: 71
# Stock Level (Previous Timestep): [139.0, 138.0, 168.0]
# Stock Level: [128. 126. 157.]
# Planned Demand: [ 8. 12. 10.]
# Actual Demand: [11. 12. 11.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -2505.45
# Total Reward: -156904.35000000006
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  1
# **************************************************
#
# Episode Information
# Episode Length: 72
# Stock Level (Previous Timestep): [128.0, 126.0, 157.0]
# Stock Level: [128. 126. 145.]
# Planned Demand: [0. 0. 9.]
# Actual Demand: [ 0.  0. 12.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -2544.25
# Total Reward: -159448.60000000006
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  1
# **************************************************
#
# Episode Information
# Episode Length: 73
# Stock Level (Previous Timestep): [128.0, 126.0, 145.0]
# Stock Level: [128. 111. 129.]
# Planned Demand: [ 0. 12. 11.]
# Actual Demand: [ 0. 15. 16.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -1957.3000000000002
# Total Reward: -161405.90000000005
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  1
# **************************************************
#
# Episode Information
# Episode Length: 74
# Stock Level (Previous Timestep): [128.0, 111.0, 129.0]
# Stock Level: [128. 111. 118.]
# Planned Demand: [0. 0. 8.]
# Actual Demand: [ 0.  0. 11.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -2021.4499999999998
# Total Reward: -163427.35000000006
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  1
# **************************************************
#
# Episode Information
# Episode Length: 75
# Stock Level (Previous Timestep): [128.0, 111.0, 118.0]
# Stock Level: [128. 101. 105.]
# Planned Demand: [ 0. 11. 12.]
# Actual Demand: [ 0. 10. 13.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -1650.5
# Total Reward: -165077.85000000006
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  1
# **************************************************
#
# Episode Information
# Episode Length: 76
# Stock Level (Previous Timestep): [128.0, 101.0, 105.0]
# Stock Level: [115. 101. 105.]
# Planned Demand: [11.  0.  0.]
# Actual Demand: [13.  0.  0.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -1592.55
# Total Reward: -166670.40000000005
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  1
# **************************************************
#
# Episode Information
# Episode Length: 77
# Stock Level (Previous Timestep): [115.0, 101.0, 105.0]
# Stock Level: [102. 101. 105.]
# Planned Demand: [14.  0.  0.]
# Actual Demand: [13.  0.  0.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -1451.5
# Total Reward: -168121.90000000005
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  1
# **************************************************
#
# Episode Information
# Episode Length: 78
# Stock Level (Previous Timestep): [102.0, 101.0, 105.0]
# Stock Level: [ 87. 101. 105.]
# Planned Demand: [10.  0.  0.]
# Actual Demand: [15.  0.  0.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -1289.75
# Total Reward: -169411.65000000005
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  1
# **************************************************
#
# Episode Information
# Episode Length: 79
# Stock Level (Previous Timestep): [87.0, 101.0, 105.0]
# Stock Level: [ 87. 101.  96.]
# Planned Demand: [0. 0. 6.]
# Actual Demand: [0. 0. 9.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -1259.3
# Total Reward: -170670.95000000004
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  1
# **************************************************
#
# Episode Information
# Episode Length: 80
# Stock Level (Previous Timestep): [87.0, 101.0, 96.0]
# Stock Level: [87. 93. 89.]
# Planned Demand: [0. 6. 7.]
# Actual Demand: [0. 8. 7.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -1056.95
# Total Reward: -171727.90000000005
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  1
# **************************************************
#
# Episode Information
# Episode Length: 81
# Stock Level (Previous Timestep): [87.0, 93.0, 89.0]
# Stock Level: [87. 93. 77.]
# Planned Demand: [ 0.  0. 13.]
# Actual Demand: [ 0.  0. 12.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -987.3500000000001
# Total Reward: -172715.25000000006
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  1
# **************************************************
#
# Episode Information
# Episode Length: 82
# Stock Level (Previous Timestep): [87.0, 93.0, 77.0]
# Stock Level: [87. 93. 77.]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -1107.3500000000001
# Total Reward: -173822.60000000006
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  1
# **************************************************
#
# Episode Information
# Episode Length: 83
# Stock Level (Previous Timestep): [87.0, 93.0, 77.0]
# Stock Level: [87. 93. 77.]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -1107.3500000000001
# Total Reward: -174929.95000000007
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  1
# **************************************************
#
# Episode Information
# Episode Length: 84
# Stock Level (Previous Timestep): [87.0, 93.0, 77.0]
# Stock Level: [79. 93. 65.]
# Planned Demand: [7. 0. 9.]
# Actual Demand: [ 8.  0. 12.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -755.75
# Total Reward: -175685.70000000007
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  1
# **************************************************
#
# Episode Information
# Episode Length: 85
# Stock Level (Previous Timestep): [79.0, 93.0, 65.0]
# Stock Level: [72. 84. 65.]
# Planned Demand: [8. 6. 0.]
# Actual Demand: [7. 9. 0.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -663.25
# Total Reward: -176348.95000000007
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  1
# **************************************************
#
# Episode Information
# Episode Length: 86
# Stock Level (Previous Timestep): [72.0, 84.0, 65.0]
# Stock Level: [62. 84. 53.]
# Planned Demand: [ 8.  0. 11.]
# Actual Demand: [10.  0. 12.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -465.45000000000005
# Total Reward: -176814.40000000008
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  1
# **************************************************
#
# Episode Information
# Episode Length: 87
# Stock Level (Previous Timestep): [62.0, 84.0, 53.0]
# Stock Level: [55. 84. 53.]
# Planned Demand: [7. 0. 0.]
# Actual Demand: [7. 0. 0.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -574.5
# Total Reward: -177388.90000000008
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  1
# **************************************************
#
# Episode Information
# Episode Length: 88
# Stock Level (Previous Timestep): [55.0, 84.0, 53.0]
# Stock Level: [55. 84. 39.]
# Planned Demand: [ 0.  0. 10.]
# Actual Demand: [ 0.  0. 14.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -440.1
# Total Reward: -177829.0000000001
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  1
# **************************************************
#
# Episode Information
# Episode Length: 89
# Stock Level (Previous Timestep): [55.0, 84.0, 39.0]
# Stock Level: [46. 73. 39.]
# Planned Demand: [10. 11.  0.]
# Actual Demand: [ 9. 11.  0.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -248.3
# Total Reward: -178077.30000000008
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  1
# **************************************************
#
# Episode Information
# Episode Length: 90
# Stock Level (Previous Timestep): [46.0, 73.0, 39.0]
# Stock Level: [46. 73. 39.]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -448.3
# Total Reward: -178525.60000000006
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  1
# **************************************************
#
# Episode Information
# Episode Length: 91
# Stock Level (Previous Timestep): [46.0, 73.0, 39.0]
# Stock Level: [46. 73. 39.]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -448.3
# Total Reward: -178973.90000000005
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  1
# **************************************************
#
# Episode Information
# Episode Length: 92
# Stock Level (Previous Timestep): [46.0, 73.0, 39.0]
# Stock Level: [46. 73. 39.]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -448.3
# Total Reward: -179422.20000000004
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  1
# **************************************************
#
# Episode Information
# Episode Length: 93
# Stock Level (Previous Timestep): [46.0, 73.0, 39.0]
# Stock Level: [46. 73. 39.]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -448.3
# Total Reward: -179870.50000000003
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  1
# **************************************************
#
# Episode Information
# Episode Length: 94
# Stock Level (Previous Timestep): [46.0, 73.0, 39.0]
# Stock Level: [46. 60. 39.]
# Planned Demand: [ 0. 13.  0.]
# Actual Demand: [ 0. 13.  0.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -231.85000000000002
# Total Reward: -180102.35000000003
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  1
# **************************************************
#
# Episode Information
# Episode Length: 95
# Stock Level (Previous Timestep): [46.0, 60.0, 39.0]
# Stock Level: [46. 60. 39.]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -361.85
# Total Reward: -180464.20000000004
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  1
# **************************************************
#
# Episode Information
# Episode Length: 96
# Stock Level (Previous Timestep): [46.0, 60.0, 39.0]
# Stock Level: [34. 47. 32.]
# Planned Demand: [11. 12.  6.]
# Actual Demand: [12. 13.  7.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: 100.55000000000001
# Total Reward: -180363.65000000005
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  1
# **************************************************
#
# Episode Information
# Episode Length: 97
# Stock Level (Previous Timestep): [34.0, 47.0, 32.0]
# Stock Level: [22. 47. 32.]
# Planned Demand: [8. 0. 0.]
# Actual Demand: [12.  0.  0.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -65.85000000000002
# Total Reward: -180429.50000000006
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  1
# **************************************************
#
# Episode Information
# Episode Length: 98
# Stock Level (Previous Timestep): [22.0, 47.0, 32.0]
# Stock Level: [ 9. 47. 32.]
# Planned Demand: [11.  0.  0.]
# Actual Demand: [13.  0.  0.]
# Action: [0, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -35.69999999999999
# Total Reward: -180465.20000000007
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  1
# **************************************************
#
# Episode Information
# Episode Length: 99
# Stock Level (Previous Timestep): [9.0, 47.0, 32.0]
# Stock Level: [ 0. 43. 32.]
# Planned Demand: [9. 6. 0.]
# Actual Demand: [9. 4. 0.]
# Action: [50, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -58.650000000000006
# Total Reward: -180523.85000000006
#
# Backlog:
# [False, False, False]
#
# Order Queue:
# {   'A': deque([0, 0, 50], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  1
# Data saved to ./Data/2024-12-01_20_last_environment_data_heuristics.csv
# **************************************************
#
# Episode Information
# Episode Length: 100
# Stock Level (Previous Timestep): [0.0, 43.0, 32.0]
# Stock Level: [ 0. 43. 32.]
# Planned Demand: [11.  0.  0.]
# Actual Demand: [11.  0.  0.]
# Action: [50, 0, 0]
# Deliveries: [0 0 0]
# Step Reward: -2588.65
# Total Reward: -183112.50000000006
#
# Backlog:
# [True, False, False]
#
# Order Queue:
# {   'A': deque([0, 50, 50], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Stockout Counter:  2
# Episode 1 Score: -183112.50000000006

# %%
df = pd.read_csv('./Data/2024-12-01_20_last_environment_data_heuristics.csv')
plot_data(df)

# %%
plot_safety_stock(df, safety_stock = safety_stock)
