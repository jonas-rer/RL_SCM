# %% [markdown]
# **Installation of Dependencies**

# %%
# Change the line to the path of your python3 interpreter
# %pip install -r requirements.txt

# %% [markdown]
# **Importing Dependencies**

# %%
# Imports
# Gymnasium imports
import gymnasium as gym 
from gymnasium import Env
from gymnasium.spaces import Discrete, Box, Dict, Tuple, MultiBinary, MultiDiscrete 

import networkx as nx
from networkx.drawing.nx_agraph import graphviz_layout

# Import helpers
import numpy as np
import pandas as pd
import random
import os
import json
import matplotlib.pyplot as plt
import seaborn as sns

from collections import deque

# Import stable baselines
from stable_baselines3 import PPO, A2C
from stable_baselines3.common.vec_env import VecFrameStack, DummyVecEnv
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.evaluation import evaluate_policy

from Environment.env_v6 import *
from Functions.visualization_functions import *

# %% [markdown]
# **Configuration of the Scenario**

# %%
# Configuration of the network
with open('./Config/network_config_v0.json') as file:
    network_config = file.read()

# %% [markdown]
# **Building the environment**

# %%
EP_LENGTH = 52 # Length of the episode

env = SS_Mngmt_Env(network_config=network_config,
                   EP_LENGTH=EP_LENGTH,
                   render_mode="human",
                   stockout_cost=1000, # penalty for stockout
                   order_cost=5, # cost for ordering
                   item_cost=0.1, # cost per item ordered
                   stock_cost=0.5, # cost per item in stock
                   item_prize=20, # prize per item sold
                   order_quantities=[0, 15, 50]) # possible order quantities

# %%
env.render_network()
# Out:
# Node Attributes:
# Node A: {'type': 'manufacturer', 'I': 30}
# Node B: {'type': 'manufacturer', 'I': 28}
# Node C: {'type': 'manufacturer', 'I': 32}
# Node D: {'type': 'distributor'}
# Node S: {'type': 'source'}

# %%
from stable_baselines3.common.env_checker import check_env

check_env(env, warn=True)

# %% [markdown]
# **Testing the environment**
#
# The "agent" takes just random actions in the environment.

# %%
episodes = 1
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        action = env.action_space.sample()
        n_state, reward, done, info, _ = env.step(action)
        score += reward

        env.render()
# Out:
# Episode Length: 1
# Stock Level: [[20. 28. 27.]]
# Planned Demand: [11.  0.  5.]
# Actual Demand: [10.  0.  5.]
# Action: [50, 0, 0]
# Order: [0 0 0]
# Reward: 0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 50], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 2
# Stock Level: [[20. 28. 16.]]
# Planned Demand: [ 0.  0. 10.]
# Actual Demand: [ 0.  0. 11.]
# Action: [0, 15, 0]
# Order: [0 0 0]
# Reward: 252.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 50, 0], maxlen=3),
#     'B': deque([0, 0, 15], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 3
# Stock Level: [[20. 15. 16.]]
# Planned Demand: [ 0. 12.  0.]
# Actual Demand: [ 0. 13.  0.]
# Action: [0, 15, 15]
# Order: [0 0 0]
# Reward: 181.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([50, 0, 0], maxlen=3),
#     'B': deque([0, 15, 15], maxlen=3),
#     'C': deque([0, 0, 15], maxlen=3)}
#
# Episode Length: 4
# Stock Level: [[70.  9. 16.]]
# Planned Demand: [0. 5. 0.]
# Actual Demand: [0. 6. 0.]
# Action: [15, 50, 0]
# Order: [50  0  0]
# Reward: 221.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 15], maxlen=3),
#     'B': deque([15, 15, 50], maxlen=3),
#     'C': deque([0, 15, 0], maxlen=3)}
#
# Episode Length: 5
# Stock Level: [[60.  5. 11.]]
# Planned Demand: [10. 17.  6.]
# Actual Demand: [10. 19.  5.]
# Action: [15, 15, 0]
# Order: [ 0 15  0]
# Reward: 56.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 15, 15], maxlen=3),
#     'B': deque([15, 50, 15], maxlen=3),
#     'C': deque([15, 0, 0], maxlen=3)}
#
# Episode Length: 6
# Stock Level: [[60. 20. 26.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [15, 0, 0]
# Order: [ 0 15 15]
# Reward: 629.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([50, 15, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 7
# Stock Level: [[75. 70. 26.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [50, 50, 0]
# Order: [15 50  0]
# Reward: -59.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 50], maxlen=3),
#     'B': deque([15, 0, 50], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 8
# Stock Level: [[80. 85. 26.]]
# Planned Demand: [10.  0.  0.]
# Actual Demand: [10.  0.  0.]
# Action: [0, 15, 50]
# Order: [15 15  0]
# Reward: -105.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 50, 0], maxlen=3),
#     'B': deque([0, 50, 15], maxlen=3),
#     'C': deque([0, 0, 50], maxlen=3)}
#
# Episode Length: 9
# Stock Level: [[95. 85. 21.]]
# Planned Demand: [0. 0. 6.]
# Actual Demand: [0. 0. 5.]
# Action: [15, 50, 0]
# Order: [15  0  0]
# Reward: 88.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([50, 0, 15], maxlen=3),
#     'B': deque([50, 15, 50], maxlen=3),
#     'C': deque([0, 50, 0], maxlen=3)}
#
# Episode Length: 10
# Stock Level: [[135. 135.  21.]]
# Planned Demand: [12.  0.  0.]
# Actual Demand: [10.  0.  0.]
# Action: [0, 50, 50]
# Order: [50 50  0]
# Reward: -17.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 15, 0], maxlen=3),
#     'B': deque([15, 50, 50], maxlen=3),
#     'C': deque([50, 0, 50], maxlen=3)}
#
# Episode Length: 11
# Stock Level: [[135. 150.  66.]]
# Planned Demand: [0. 0. 7.]
# Actual Demand: [0. 0. 5.]
# Action: [50, 0, 15]
# Order: [ 0 15 50]
# Reward: 34.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 0, 50], maxlen=3),
#     'B': deque([50, 50, 0], maxlen=3),
#     'C': deque([0, 50, 15], maxlen=3)}
#
# Episode Length: 12
# Stock Level: [[150. 200.  66.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [15, 50, 15]
# Order: [15 50  0]
# Reward: -92.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 50, 15], maxlen=3),
#     'B': deque([50, 0, 50], maxlen=3),
#     'C': deque([50, 15, 15], maxlen=3)}
#
# Episode Length: 13
# Stock Level: [[136. 250. 116.]]
# Planned Demand: [14.  0.  5.]
# Actual Demand: [14.  0.  0.]
# Action: [15, 15, 0]
# Order: [ 0 50 50]
# Reward: -231.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([50, 15, 15], maxlen=3),
#     'B': deque([0, 50, 15], maxlen=3),
#     'C': deque([15, 15, 0], maxlen=3)}
#
# Episode Length: 14
# Stock Level: [[186. 250. 121.]]
# Planned Demand: [ 0.  0. 10.]
# Actual Demand: [ 0.  0. 10.]
# Action: [15, 0, 0]
# Order: [50  0 15]
# Reward: 16.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([50, 15, 0], maxlen=3),
#     'C': deque([15, 0, 0], maxlen=3)}
#
# Episode Length: 15
# Stock Level: [[188. 300. 136.]]
# Planned Demand: [12.  0.  0.]
# Actual Demand: [13.  0.  0.]
# Action: [0, 0, 15]
# Order: [15 50 15]
# Reward: -85.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 0], maxlen=3),
#     'B': deque([15, 0, 0], maxlen=3),
#     'C': deque([0, 0, 15], maxlen=3)}
#
# Episode Length: 16
# Stock Level: [[203. 315. 136.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [15, 0, 50]
# Order: [15 15  0]
# Reward: -58.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 0, 15], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 15, 50], maxlen=3)}
#
# Episode Length: 17
# Stock Level: [[218. 309. 136.]]
# Planned Demand: [0. 7. 0.]
# Actual Demand: [0. 6. 0.]
# Action: [15, 50, 0]
# Order: [15  0  0]
# Reward: -343.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 15, 15], maxlen=3),
#     'B': deque([0, 0, 50], maxlen=3),
#     'C': deque([15, 50, 0], maxlen=3)}
#
# Episode Length: 18
# Stock Level: [[218. 309. 143.]]
# Planned Demand: [0. 0. 9.]
# Actual Demand: [0. 0. 8.]
# Action: [15, 0, 15]
# Order: [ 0  0 15]
# Reward: -228.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([0, 50, 0], maxlen=3),
#     'C': deque([50, 0, 15], maxlen=3)}
#
# Episode Length: 19
# Stock Level: [[233. 309. 193.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 15, 15]
# Order: [15  0 50]
# Reward: -188.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 0], maxlen=3),
#     'B': deque([50, 0, 15], maxlen=3),
#     'C': deque([0, 15, 15], maxlen=3)}
#
# Episode Length: 20
# Stock Level: [[236. 351. 193.]]
# Planned Demand: [12.  7.  5.]
# Actual Demand: [12.  8.  0.]
# Action: [0, 50, 0]
# Order: [15 50  0]
# Reward: -380.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 0, 0], maxlen=3),
#     'B': deque([0, 15, 50], maxlen=3),
#     'C': deque([15, 15, 0], maxlen=3)}
#
# Episode Length: 21
# Stock Level: [[247. 351. 196.]]
# Planned Demand: [ 6.  0. 16.]
# Actual Demand: [ 4.  0. 12.]
# Action: [15, 15, 50]
# Order: [15  0 15]
# Reward: 0.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 15], maxlen=3),
#     'B': deque([15, 50, 15], maxlen=3),
#     'C': deque([15, 0, 50], maxlen=3)}
#
# Episode Length: 22
# Stock Level: [[247. 366. 211.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [15, 15, 50]
# Order: [ 0 15 15]
# Reward: -100.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 15, 15], maxlen=3),
#     'B': deque([50, 15, 15], maxlen=3),
#     'C': deque([0, 50, 50], maxlen=3)}
#
# Episode Length: 23
# Stock Level: [[240. 416. 200.]]
# Planned Demand: [12.  0. 11.]
# Actual Demand: [ 7.  0. 11.]
# Action: [15, 0, 0]
# Order: [ 0 50  0]
# Reward: -435.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 0], maxlen=3),
#     'C': deque([50, 50, 0], maxlen=3)}
#
# Episode Length: 24
# Stock Level: [[255. 431. 243.]]
# Planned Demand: [0. 0. 9.]
# Actual Demand: [0. 0. 7.]
# Action: [50, 15, 15]
# Order: [15 15 50]
# Reward: -74.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 50], maxlen=3),
#     'B': deque([15, 0, 15], maxlen=3),
#     'C': deque([50, 0, 15], maxlen=3)}
#
# Episode Length: 25
# Stock Level: [[270. 446. 293.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [50, 15, 50]
# Order: [15 15 50]
# Reward: -347.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 50, 50], maxlen=3),
#     'B': deque([0, 15, 15], maxlen=3),
#     'C': deque([0, 15, 50], maxlen=3)}
#
# Episode Length: 26
# Stock Level: [[277. 446. 288.]]
# Planned Demand: [12.  0.  9.]
# Actual Demand: [8. 0. 5.]
# Action: [15, 50, 15]
# Order: [15  0  0]
# Reward: -531.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([50, 50, 15], maxlen=3),
#     'B': deque([15, 15, 50], maxlen=3),
#     'C': deque([15, 50, 15], maxlen=3)}
#
# Episode Length: 27
# Stock Level: [[315. 461. 296.]]
# Planned Demand: [14.  0.  9.]
# Actual Demand: [12.  0.  7.]
# Action: [0, 15, 50]
# Order: [50 15 15]
# Reward: -268.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([50, 15, 0], maxlen=3),
#     'B': deque([15, 50, 15], maxlen=3),
#     'C': deque([50, 15, 50], maxlen=3)}
#
# Episode Length: 28
# Stock Level: [[362. 476. 334.]]
# Planned Demand: [ 2.  0. 11.]
# Actual Demand: [ 3.  0. 12.]
# Action: [50, 15, 0]
# Order: [50 15 50]
# Reward: -172.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 0, 50], maxlen=3),
#     'B': deque([50, 15, 15], maxlen=3),
#     'C': deque([15, 50, 0], maxlen=3)}
#
# Episode Length: 29
# Stock Level: [[368. 526. 335.]]
# Planned Demand: [ 8.  0. 16.]
# Actual Demand: [ 9.  0. 14.]
# Action: [0, 50, 15]
# Order: [15 50 15]
# Reward: -302.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 50, 0], maxlen=3),
#     'B': deque([15, 15, 50], maxlen=3),
#     'C': deque([50, 0, 15], maxlen=3)}
#
# Episode Length: 30
# Stock Level: [[355. 541. 374.]]
# Planned Demand: [12.  0. 11.]
# Actual Demand: [13.  0. 11.]
# Action: [50, 0, 50]
# Order: [ 0 15 50]
# Reward: -171.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([50, 0, 50], maxlen=3),
#     'B': deque([15, 50, 0], maxlen=3),
#     'C': deque([0, 15, 50], maxlen=3)}
#
# Episode Length: 31
# Stock Level: [[401. 556. 365.]]
# Planned Demand: [7. 0. 7.]
# Actual Demand: [4. 0. 9.]
# Action: [50, 0, 15]
# Order: [50 15  0]
# Reward: -175.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 50, 50], maxlen=3),
#     'B': deque([50, 0, 0], maxlen=3),
#     'C': deque([15, 50, 15], maxlen=3)}
#
# Episode Length: 32
# Stock Level: [[395. 606. 374.]]
# Planned Demand: [10.  0. 10.]
# Actual Demand: [6. 0. 6.]
# Action: [0, 0, 50]
# Order: [ 0 50 15]
# Reward: -417.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([50, 50, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([50, 15, 50], maxlen=3)}
#
# Episode Length: 33
# Stock Level: [[431. 593. 415.]]
# Planned Demand: [12. 11. 10.]
# Actual Demand: [14. 13.  9.]
# Action: [15, 15, 0]
# Order: [50  0 50]
# Reward: -457.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([50, 0, 15], maxlen=3),
#     'B': deque([0, 0, 15], maxlen=3),
#     'C': deque([15, 50, 0], maxlen=3)}
#
# Episode Length: 34
# Stock Level: [[475. 593. 425.]]
# Planned Demand: [3. 0. 4.]
# Actual Demand: [6. 0. 5.]
# Action: [0, 0, 15]
# Order: [50  0 15]
# Reward: -12.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 15, 0], maxlen=3),
#     'B': deque([0, 15, 0], maxlen=3),
#     'C': deque([50, 0, 15], maxlen=3)}
#
# Episode Length: 35
# Stock Level: [[475. 576. 475.]]
# Planned Demand: [ 0. 13.  3.]
# Actual Demand: [ 0. 17.  0.]
# Action: [15, 0, 15]
# Order: [ 0  0 50]
# Reward: -533.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 0, 15], maxlen=3),
#     'B': deque([15, 0, 0], maxlen=3),
#     'C': deque([0, 15, 15], maxlen=3)}
#
# Episode Length: 36
# Stock Level: [[490. 580. 470.]]
# Planned Demand: [ 0. 10.  8.]
# Actual Demand: [ 0. 11.  5.]
# Action: [15, 15, 15]
# Order: [15 15  0]
# Reward: -436.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 15, 15], maxlen=3),
#     'B': deque([0, 0, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 37
# Stock Level: [[479. 572. 474.]]
# Planned Demand: [10.  9. 12.]
# Actual Demand: [11.  8. 11.]
# Action: [0, 0, 50]
# Order: [ 0  0 15]
# Reward: -469.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 0], maxlen=3),
#     'B': deque([0, 15, 0], maxlen=3),
#     'C': deque([15, 15, 50], maxlen=3)}
#
# Episode Length: 38
# Stock Level: [[481. 558. 489.]]
# Planned Demand: [12. 13.  0.]
# Actual Demand: [13. 14.  0.]
# Action: [0, 50, 0]
# Order: [15  0 15]
# Reward: -172.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 0, 0], maxlen=3),
#     'B': deque([15, 0, 50], maxlen=3),
#     'C': deque([15, 50, 0], maxlen=3)}
#
# Episode Length: 39
# Stock Level: [[483. 563. 497.]]
# Planned Demand: [13. 11.  8.]
# Actual Demand: [13. 10.  7.]
# Action: [0, 50, 50]
# Order: [15 15 15]
# Reward: -234.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 50, 50], maxlen=3),
#     'C': deque([50, 0, 50], maxlen=3)}
#
# Episode Length: 40
# Stock Level: [[483. 559. 544.]]
# Planned Demand: [0. 5. 3.]
# Actual Demand: [0. 4. 3.]
# Action: [0, 0, 50]
# Order: [ 0  0 50]
# Reward: -191.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([50, 50, 0], maxlen=3),
#     'C': deque([0, 50, 50], maxlen=3)}
#
# Episode Length: 41
# Stock Level: [[479. 603. 538.]]
# Planned Demand: [6. 8. 7.]
# Actual Demand: [4. 6. 6.]
# Action: [15, 0, 15]
# Order: [ 0 50  0]
# Reward: -663.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 15], maxlen=3),
#     'B': deque([50, 0, 0], maxlen=3),
#     'C': deque([50, 50, 15], maxlen=3)}
#
# Episode Length: 42
# Stock Level: [[471. 653. 588.]]
# Planned Demand: [6. 0. 0.]
# Actual Demand: [8. 0. 0.]
# Action: [50, 0, 0]
# Order: [ 0 50 50]
# Reward: -503.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 15, 50], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([50, 15, 0], maxlen=3)}
#
# Episode Length: 43
# Stock Level: [[462. 653. 629.]]
# Planned Demand: [ 9.  0. 11.]
# Actual Demand: [9. 0. 9.]
# Action: [15, 0, 50]
# Order: [ 0  0 50]
# Reward: -706.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 50, 15], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([15, 0, 50], maxlen=3)}
#
# Episode Length: 44
# Stock Level: [[477. 653. 644.]]
# Planned Demand: [0. 2. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [50, 50, 15]
# Order: [15  0 15]
# Reward: -528.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([50, 15, 50], maxlen=3),
#     'B': deque([0, 0, 50], maxlen=3),
#     'C': deque([0, 50, 15], maxlen=3)}
#
# Episode Length: 45
# Stock Level: [[527. 653. 644.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [15, 15, 50]
# Order: [50  0  0]
# Reward: -913.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 50, 15], maxlen=3),
#     'B': deque([0, 50, 15], maxlen=3),
#     'C': deque([50, 15, 50], maxlen=3)}
#
# Episode Length: 46
# Stock Level: [[542. 644. 686.]]
# Planned Demand: [0. 9. 5.]
# Actual Demand: [0. 9. 8.]
# Action: [50, 15, 50]
# Order: [15  0 50]
# Reward: -935.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([50, 15, 50], maxlen=3),
#     'B': deque([50, 15, 15], maxlen=3),
#     'C': deque([15, 50, 50], maxlen=3)}
#
# Episode Length: 47
# Stock Level: [[592. 689. 701.]]
# Planned Demand: [0. 6. 0.]
# Actual Demand: [0. 5. 0.]
# Action: [50, 50, 0]
# Order: [50 50 15]
# Reward: -622.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 50, 50], maxlen=3),
#     'B': deque([15, 15, 50], maxlen=3),
#     'C': deque([50, 50, 0], maxlen=3)}
#
# Episode Length: 48
# Stock Level: [[607. 704. 751.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 0, 50]
# Order: [15 15 50]
# Reward: -911.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([50, 50, 0], maxlen=3),
#     'B': deque([15, 50, 0], maxlen=3),
#     'C': deque([50, 0, 50], maxlen=3)}
#
# Episode Length: 49
# Stock Level: [[657. 719. 801.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [15, 0, 50]
# Order: [50 15 50]
# Reward: -1041.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([50, 0, 15], maxlen=3),
#     'B': deque([50, 0, 0], maxlen=3),
#     'C': deque([0, 50, 50], maxlen=3)}
#
# Episode Length: 50
# Stock Level: [[698. 759. 801.]]
# Planned Demand: [ 8. 11.  0.]
# Actual Demand: [ 9. 10.  0.]
# Action: [50, 15, 0]
# Order: [50 50  0]
# Reward: -1105.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 15, 50], maxlen=3),
#     'B': deque([0, 0, 15], maxlen=3),
#     'C': deque([50, 50, 0], maxlen=3)}
#
# Episode Length: 51
# Stock Level: [[698. 759. 851.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [50, 0, 0]
# Order: [ 0  0 50]
# Reward: -765.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 50, 50], maxlen=3),
#     'B': deque([0, 15, 0], maxlen=3),
#     'C': deque([50, 0, 0], maxlen=3)}
#
# Episode Length: 52
# Stock Level: [[713. 755. 897.]]
# Planned Demand: [0. 5. 5.]
# Actual Demand: [0. 4. 4.]
# Action: [50, 0, 15]
# Order: [15  0 50]
# Reward: -1164.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([50, 50, 50], maxlen=3),
#     'B': deque([15, 0, 0], maxlen=3),
#     'C': deque([0, 0, 15], maxlen=3)}

# %%
# Adapt the path if required
df = pd.read_csv('./Data/2024-10-25_15_last_environment_data.csv')
plot_data(df)

# %% [markdown]
# **Train Model**
#
# Uncomment the code to choose which kind of model you want to train.
#
# Currently implemented models are:
# - A2C Model
# - PPO Model

# %%
log_path = os.path.join('Training', 'Logs')
model_path = os.path.join('Training', 'Models', 'PPO')
# model_path = os.path.join('Training', 'Models', 'A2C')

# %%
env = SS_Mngmt_Env(network_config=network_config,
                   EP_LENGTH=EP_LENGTH,
                   render_mode="human")

def make_env():
    # Create a new environment here
    env = SS_Mngmt_Env(network_config=network_config, EP_LENGTH=EP_LENGTH, render_mode="human")
    return env

num_envs = 8

dummy_env = DummyVecEnv([lambda: env])
vec_env = make_vec_env(make_env, n_envs=num_envs)

model = PPO("MlpPolicy", 
            dummy_env,
            learning_rate = 0.0007,
            gamma = 0.99,
            verbose=1,
            tensorboard_log=log_path)

# model = A2C("MlpPolicy",
#             vec_env,
#             learning_rate = 0.0005,
#             gamma = 0.99,
#             verbose=1,
#             tensorboard_log=log_path)
# Out:
# Using cpu device

# %% [markdown]
# Training cycle

# %%
model.learn(total_timesteps=1_000_000)
# Out:
# Logging to Training/Logs/PPO_3
# -----------------------------
# | time/              |      |
# |    fps             | 3257 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1973         |
# |    iterations           | 2            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0065603023 |
# |    clip_fraction        | 0.00244      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.29        |
# |    explained_variance   | 2.98e-07     |
# |    learning_rate        | 0.0007       |
# |    loss                 | 2.31e+07     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00593     |
# |    value_loss           | 4.34e+07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1757         |
# |    iterations           | 3            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0039969455 |
# |    clip_fraction        | 0.00132      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.29        |
# |    explained_variance   | 2.98e-06     |
# |    learning_rate        | 0.0007       |
# |    loss                 | 1.66e+07     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00447     |
# |    value_loss           | 3.56e+07     |
# ------------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1663      |
# |    iterations           | 4         |
# |    time_elapsed         | 4         |
# |    total_timesteps      | 8192      |
# | train/                  |           |
# |    approx_kl            | 0.0056652 |
# |    clip_fraction        | 0.0148    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.28     |
# |    explained_variance   | 8.94e-07  |
# |    learning_rate        | 0.0007    |
# |    loss                 | 1.67e+07  |
# |    n_updates            | 30        |
# |    policy_gradient_loss | -0.0058   |
# |    value_loss           | 3.19e+07  |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1610        |
# |    iterations           | 5           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.005292925 |
# |    clip_fraction        | 0.00483     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.26       |
# |    explained_variance   | 3.58e-07    |
# |    learning_rate        | 0.0007      |
# |    loss                 | 1.23e+07    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00525    |
# |    value_loss           | 2.86e+07    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1575        |
# |    iterations           | 6           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.005736527 |
# |    clip_fraction        | 0.0211      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.23       |
# |    explained_variance   | 1.79e-07    |
# |    learning_rate        | 0.0007      |
# |    loss                 | 1.3e+07     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00687    |
# |    value_loss           | 2.54e+07    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1549         |
# |    iterations           | 7            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0063116304 |
# |    clip_fraction        | 0.0501       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.2         |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0007       |
# |    loss                 | 1.21e+07     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00876     |
# |    value_loss           | 2.13e+07     |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1530       |
# |    iterations           | 8          |
# |    time_elapsed         | 10         |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.00609049 |
# |    clip_fraction        | 0.0252     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.17      |
# |    explained_variance   | 5.96e-08   |
# |    learning_rate        | 0.0007     |
# |    loss                 | 8.74e+06   |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.00695   |
# |    value_loss           | 1.65e+07   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1519        |
# |    iterations           | 9           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.006076287 |
# |    clip_fraction        | 0.0204      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.13       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0007      |
# |    loss                 | 7.72e+06    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00759    |
# |    value_loss           | 1.53e+07    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1511        |
# |    iterations           | 10          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.004541738 |
# |    clip_fraction        | 0.00654     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.1        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0007      |
# |    loss                 | 5.56e+06    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00574    |
# |    value_loss           | 1.23e+07    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1502         |
# |    iterations           | 11           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0067474646 |
# |    clip_fraction        | 0.0315       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.04        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0007       |
# |    loss                 | 3.78e+06     |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.0103      |
# |    value_loss           | 8.96e+06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1497        |
# |    iterations           | 12          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.005316264 |
# |    clip_fraction        | 0.026       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.98       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0007      |
# |    loss                 | 5.23e+06    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0083     |
# |    value_loss           | 8.13e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1492        |
# |    iterations           | 13          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.008287361 |
# |    clip_fraction        | 0.0586      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.9        |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0007      |
# |    loss                 | 3.79e+06    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0131     |
# |    value_loss           | 5.97e+06    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1486         |
# |    iterations           | 14           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0065557817 |
# |    clip_fraction        | 0.0337       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0007       |
# |    loss                 | 1.76e+06     |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.0121      |
# |    value_loss           | 4.18e+06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1484        |
# |    iterations           | 15          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.008854398 |
# |    clip_fraction        | 0.0445      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.76       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0007      |
# |    loss                 | 1.24e+06    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0136     |
# |    value_loss           | 3.32e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1480        |
# |    iterations           | 16          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.010127842 |
# |    clip_fraction        | 0.0934      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.65       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0007      |
# |    loss                 | 9.89e+05    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0197     |
# |    value_loss           | 2.46e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1475        |
# |    iterations           | 17          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.016198892 |
# |    clip_fraction        | 0.249       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.66       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0007      |
# |    loss                 | 5.2e+05     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00799    |
# |    value_loss           | 9.85e+05    |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1473          |
# |    iterations           | 18            |
# |    time_elapsed         | 25            |
# |    total_timesteps      | 36864         |
# | train/                  |               |
# |    approx_kl            | 0.00030456067 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.7          |
# |    explained_variance   | 0.117         |
# |    learning_rate        | 0.0007        |
# |    loss                 | 7.89e+05      |
# |    n_updates            | 170           |
# |    policy_gradient_loss | -0.00182      |
# |    value_loss           | 1.31e+06      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1471          |
# |    iterations           | 19            |
# |    time_elapsed         | 26            |
# |    total_timesteps      | 38912         |
# | train/                  |               |
# |    approx_kl            | 0.00039468938 |
# |    clip_fraction        | 4.88e-05      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.64         |
# |    explained_variance   | 0.136         |
# |    learning_rate        | 0.0007        |
# |    loss                 | 8.06e+05      |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.00216      |
# |    value_loss           | 1.28e+06      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1469         |
# |    iterations           | 20           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0002739806 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.66        |
# |    explained_variance   | 0.117        |
# |    learning_rate        | 0.0007       |
# |    loss                 | 8.25e+05     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00149     |
# |    value_loss           | 1.68e+06     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1468          |
# |    iterations           | 21            |
# |    time_elapsed         | 29            |
# |    total_timesteps      | 43008         |
# | train/                  |               |
# |    approx_kl            | 0.00023036881 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.64         |
# |    explained_variance   | 0.126         |
# |    learning_rate        | 0.0007        |
# |    loss                 | 3.65e+05      |
# |    n_updates            | 200           |
# |    policy_gradient_loss | -0.00149      |
# |    value_loss           | 1.05e+06      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1465          |
# |    iterations           | 22            |
# |    time_elapsed         | 30            |
# |    total_timesteps      | 45056         |
# | train/                  |               |
# |    approx_kl            | 0.00016229163 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.62         |
# |    explained_variance   | 0.177         |
# |    learning_rate        | 0.0007        |
# |    loss                 | 4.02e+05      |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -0.000982     |
# |    value_loss           | 9.82e+05      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1462          |
# |    iterations           | 23            |
# |    time_elapsed         | 32            |
# |    total_timesteps      | 47104         |
# | train/                  |               |
# |    approx_kl            | 0.00084323785 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.61         |
# |    explained_variance   | 0.194         |
# |    learning_rate        | 0.0007        |
# |    loss                 | 5.49e+05      |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -0.0025       |
# |    value_loss           | 9.81e+05      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1460         |
# |    iterations           | 24           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0008322071 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.55        |
# |    explained_variance   | 0.117        |
# |    learning_rate        | 0.0007       |
# |    loss                 | 1.08e+06     |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00295     |
# |    value_loss           | 1.41e+06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1459        |
# |    iterations           | 25          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.000734614 |
# |    clip_fraction        | 9.77e-05    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.53       |
# |    explained_variance   | 0.187       |
# |    learning_rate        | 0.0007      |
# |    loss                 | 5.73e+05    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00274    |
# |    value_loss           | 1.1e+06     |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1458          |
# |    iterations           | 26            |
# |    time_elapsed         | 36            |
# |    total_timesteps      | 53248         |
# | train/                  |               |
# |    approx_kl            | 0.00010819346 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.52         |
# |    explained_variance   | 0.196         |
# |    learning_rate        | 0.0007        |
# |    loss                 | 6.29e+05      |
# |    n_updates            | 250           |
# |    policy_gradient_loss | -0.00123      |
# |    value_loss           | 1.06e+06      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1457         |
# |    iterations           | 27           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0006421419 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.5         |
# |    explained_variance   | 0.215        |
# |    learning_rate        | 0.0007       |
# |    loss                 | 5.08e+05     |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00208     |
# |    value_loss           | 1.17e+06     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1456          |
# |    iterations           | 28            |
# |    time_elapsed         | 39            |
# |    total_timesteps      | 57344         |
# | train/                  |               |
# |    approx_kl            | 0.00033314957 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.51         |
# |    explained_variance   | 0.186         |
# |    learning_rate        | 0.0007        |
# |    loss                 | 4.99e+05      |
# |    n_updates            | 270           |
# |    policy_gradient_loss | -0.00166      |
# |    value_loss           | 1.14e+06      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1454          |
# |    iterations           | 29            |
# |    time_elapsed         | 40            |
# |    total_timesteps      | 59392         |
# | train/                  |               |
# |    approx_kl            | 0.00070166576 |
# |    clip_fraction        | 0.000244      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.44         |
# |    explained_variance   | 0.216         |
# |    learning_rate        | 0.0007        |
# |    loss                 | 6.45e+05      |
# |    n_updates            | 280           |
# |    policy_gradient_loss | -0.00249      |
# |    value_loss           | 9.79e+05      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1453         |
# |    iterations           | 30           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 9.829545e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.46        |
# |    explained_variance   | 0.2          |
# |    learning_rate        | 0.0007       |
# |    loss                 | 4.26e+05     |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00114     |
# |    value_loss           | 1.13e+06     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1451          |
# |    iterations           | 31            |
# |    time_elapsed         | 43            |
# |    total_timesteps      | 63488         |
# | train/                  |               |
# |    approx_kl            | 0.00027829065 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.43         |
# |    explained_variance   | 0.221         |
# |    learning_rate        | 0.0007        |
# |    loss                 | 5.44e+05      |
# |    n_updates            | 300           |
# |    policy_gradient_loss | -0.00163      |
# |    value_loss           | 1.09e+06      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1450          |
# |    iterations           | 32            |
# |    time_elapsed         | 45            |
# |    total_timesteps      | 65536         |
# | train/                  |               |
# |    approx_kl            | 0.00025401302 |
# |    clip_fraction        | 9.77e-05      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.46         |
# |    explained_variance   | 0.188         |
# |    learning_rate        | 0.0007        |
# |    loss                 | 4.27e+05      |
# |    n_updates            | 310           |
# |    policy_gradient_loss | -0.00159      |
# |    value_loss           | 1.23e+06      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1449          |
# |    iterations           | 33            |
# |    time_elapsed         | 46            |
# |    total_timesteps      | 67584         |
# | train/                  |               |
# |    approx_kl            | 0.00022844042 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.4          |
# |    explained_variance   | 0.245         |
# |    learning_rate        | 0.0007        |
# |    loss                 | 5.11e+05      |
# |    n_updates            | 320           |
# |    policy_gradient_loss | -0.00136      |
# |    value_loss           | 1e+06         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1448         |
# |    iterations           | 34           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0003500108 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.39        |
# |    explained_variance   | 0.144        |
# |    learning_rate        | 0.0007       |
# |    loss                 | 6.08e+05     |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00176     |
# |    value_loss           | 1.1e+06      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1447          |
# |    iterations           | 35            |
# |    time_elapsed         | 49            |
# |    total_timesteps      | 71680         |
# | train/                  |               |
# |    approx_kl            | 0.00025187858 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.39         |
# |    explained_variance   | 0.107         |
# |    learning_rate        | 0.0007        |
# |    loss                 | 5.58e+05      |
# |    n_updates            | 340           |
# |    policy_gradient_loss | -0.00151      |
# |    value_loss           | 1.07e+06      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1447          |
# |    iterations           | 36            |
# |    time_elapsed         | 50            |
# |    total_timesteps      | 73728         |
# | train/                  |               |
# |    approx_kl            | 0.00010707503 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.37         |
# |    explained_variance   | 0.182         |
# |    learning_rate        | 0.0007        |
# |    loss                 | 5.69e+05      |
# |    n_updates            | 350           |
# |    policy_gradient_loss | -0.00107      |
# |    value_loss           | 1.18e+06      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1446          |
# |    iterations           | 37            |
# |    time_elapsed         | 52            |
# |    total_timesteps      | 75776         |
# | train/                  |               |
# |    approx_kl            | 0.00058789697 |
# |    clip_fraction        | 9.77e-05      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.35         |
# |    explained_variance   | 0.219         |
# |    learning_rate        | 0.0007        |
# |    loss                 | 5.02e+05      |
# |    n_updates            | 360           |
# |    policy_gradient_loss | -0.00189      |
# |    value_loss           | 1.05e+06      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1445          |
# |    iterations           | 38            |
# |    time_elapsed         | 53            |
# |    total_timesteps      | 77824         |
# | train/                  |               |
# |    approx_kl            | 0.00031558351 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.34         |
# |    explained_variance   | 0.139         |
# |    learning_rate        | 0.0007        |
# |    loss                 | 6.87e+05      |
# |    n_updates            | 370           |
# |    policy_gradient_loss | -0.00115      |
# |    value_loss           | 1.34e+06      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1445         |
# |    iterations           | 39           |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0005531999 |
# |    clip_fraction        | 4.88e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.33        |
# |    explained_variance   | 0.103        |
# |    learning_rate        | 0.0007       |
# |    loss                 | 4.08e+05     |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00222     |
# |    value_loss           | 1.23e+06     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1443          |
# |    iterations           | 40            |
# |    time_elapsed         | 56            |
# |    total_timesteps      | 81920         |
# | train/                  |               |
# |    approx_kl            | 0.00018668047 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.36         |
# |    explained_variance   | 0.158         |
# |    learning_rate        | 0.0007        |
# |    loss                 | 7.92e+05      |
# |    n_updates            | 390           |
# |    policy_gradient_loss | -0.00133      |
# |    value_loss           | 1.41e+06      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1443         |
# |    iterations           | 41           |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0003776177 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.32        |
# |    explained_variance   | 0.0734       |
# |    learning_rate        | 0.0007       |
# |    loss                 | 5.14e+05     |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00192     |
# |    value_loss           | 1.41e+06     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1443          |
# |    iterations           | 42            |
# |    time_elapsed         | 59            |
# |    total_timesteps      | 86016         |
# | train/                  |               |
# |    approx_kl            | 0.00028004474 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.31         |
# |    explained_variance   | 0.0921        |
# |    learning_rate        | 0.0007        |
# |    loss                 | 8.49e+05      |
# |    n_updates            | 410           |
# |    policy_gradient_loss | -0.00186      |
# |    value_loss           | 1.47e+06      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1442          |
# |    iterations           | 43            |
# |    time_elapsed         | 61            |
# |    total_timesteps      | 88064         |
# | train/                  |               |
# |    approx_kl            | 8.2477054e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.33         |
# |    explained_variance   | 0.124         |
# |    learning_rate        | 0.0007        |
# |    loss                 | 6.86e+05      |
# |    n_updates            | 420           |
# |    policy_gradient_loss | -0.000732     |
# |    value_loss           | 1.27e+06      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1442          |
# |    iterations           | 44            |
# |    time_elapsed         | 62            |
# |    total_timesteps      | 90112         |
# | train/                  |               |
# |    approx_kl            | 0.00028478954 |
# |    clip_fraction        | 4.88e-05      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.28         |
# |    explained_variance   | 0.172         |
# |    learning_rate        | 0.0007        |
# |    loss                 | 6.23e+05      |
# |    n_updates            | 430           |
# |    policy_gradient_loss | -0.00168      |
# |    value_loss           | 1.34e+06      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1441         |
# |    iterations           | 45           |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0006058458 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.31        |
# |    explained_variance   | 0.154        |
# |    learning_rate        | 0.0007       |
# |    loss                 | 4.63e+05     |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.0023      |
# |    value_loss           | 1.31e+06     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1441          |
# |    iterations           | 46            |
# |    time_elapsed         | 65            |
# |    total_timesteps      | 94208         |
# | train/                  |               |
# |    approx_kl            | 0.00043516248 |
# |    clip_fraction        | 0.000146      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.28         |
# |    explained_variance   | 0.12          |
# |    learning_rate        | 0.0007        |
# |    loss                 | 5.93e+05      |
# |    n_updates            | 450           |
# |    policy_gradient_loss | -0.00222      |
# |    value_loss           | 1.53e+06      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1440          |
# |    iterations           | 47            |
# |    time_elapsed         | 66            |
# |    total_timesteps      | 96256         |
# | train/                  |               |
# |    approx_kl            | 0.00015811008 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.27         |
# |    explained_variance   | 0.101         |
# |    learning_rate        | 0.0007        |
# |    loss                 | 7.03e+05      |
# |    n_updates            | 460           |
# |    policy_gradient_loss | -0.0012       |
# |    value_loss           | 1.62e+06      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1440         |
# |    iterations           | 48           |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0004541706 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.27        |
# |    explained_variance   | 0.168        |
# |    learning_rate        | 0.0007       |
# |    loss                 | 7.46e+05     |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.002       |
# |    value_loss           | 1.72e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1440         |
# |    iterations           | 49           |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 5.734939e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.26        |
# |    explained_variance   | 0.071        |
# |    learning_rate        | 0.0007       |
# |    loss                 | 1.74e+06     |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.000809    |
# |    value_loss           | 2.19e+06     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1439          |
# |    iterations           | 50            |
# |    time_elapsed         | 71            |
# |    total_timesteps      | 102400        |
# | train/                  |               |
# |    approx_kl            | 7.5112766e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.22         |
# |    explained_variance   | 0.163         |
# |    learning_rate        | 0.0007        |
# |    loss                 | 5.72e+05      |
# |    n_updates            | 490           |
# |    policy_gradient_loss | -0.000948     |
# |    value_loss           | 1.41e+06      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1439         |
# |    iterations           | 51           |
# |    time_elapsed         | 72           |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0003798079 |
# |    clip_fraction        | 4.88e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.21        |
# |    explained_variance   | 0.123        |
# |    learning_rate        | 0.0007       |
# |    loss                 | 7.24e+05     |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00209     |
# |    value_loss           | 1.64e+06     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1439          |
# |    iterations           | 52            |
# |    time_elapsed         | 74            |
# |    total_timesteps      | 106496        |
# | train/                  |               |
# |    approx_kl            | 0.00028545168 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.21         |
# |    explained_variance   | 0.144         |
# |    learning_rate        | 0.0007        |
# |    loss                 | 1.01e+06      |
# |    n_updates            | 510           |
# |    policy_gradient_loss | -0.00157      |
# |    value_loss           | 1.92e+06      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1438         |
# |    iterations           | 53           |
# |    time_elapsed         | 75           |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0003906895 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.22        |
# |    explained_variance   | 0.143        |
# |    learning_rate        | 0.0007       |
# |    loss                 | 6.42e+05     |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00226     |
# |    value_loss           | 1.55e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1438         |
# |    iterations           | 54           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0005156796 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.21        |
# |    explained_variance   | 0.0923       |
# |    learning_rate        | 0.0007       |
# |    loss                 | 9.08e+05     |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.00159     |
# |    value_loss           | 1.84e+06     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1437          |
# |    iterations           | 55            |
# |    time_elapsed         | 78            |
# |    total_timesteps      | 112640        |
# | train/                  |               |
# |    approx_kl            | 0.00016833114 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.19         |
# |    explained_variance   | 0.118         |
# |    learning_rate        | 0.0007        |
# |    loss                 | 5.65e+05      |
# |    n_updates            | 540           |
# |    policy_gradient_loss | -0.00154      |
# |    value_loss           | 1.53e+06      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1437          |
# |    iterations           | 56            |
# |    time_elapsed         | 79            |
# |    total_timesteps      | 114688        |
# | train/                  |               |
# |    approx_kl            | 0.00013949053 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.22         |
# |    explained_variance   | 0.0591        |
# |    learning_rate        | 0.0007        |
# |    loss                 | 1.11e+06      |
# |    n_updates            | 550           |
# |    policy_gradient_loss | -0.0013       |
# |    value_loss           | 2e+06         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1437          |
# |    iterations           | 57            |
# |    time_elapsed         | 81            |
# |    total_timesteps      | 116736        |
# | train/                  |               |
# |    approx_kl            | 0.00063756027 |
# |    clip_fraction        | 9.77e-05      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.22         |
# |    explained_variance   | 0.133         |
# |    learning_rate        | 0.0007        |
# |    loss                 | 1.02e+06      |
# |    n_updates            | 560           |
# |    policy_gradient_loss | -0.00231      |
# |    value_loss           | 1.85e+06      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1437          |
# |    iterations           | 58            |
# |    time_elapsed         | 82            |
# |    total_timesteps      | 118784        |
# | train/                  |               |
# |    approx_kl            | 0.00056643866 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.19         |
# |    explained_variance   | 0.0249        |
# |    learning_rate        | 0.0007        |
# |    loss                 | 8.02e+05      |
# |    n_updates            | 570           |
# |    policy_gradient_loss | -0.00249      |
# |    value_loss           | 1.78e+06      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1436          |
# |    iterations           | 59            |
# |    time_elapsed         | 84            |
# |    total_timesteps      | 120832        |
# | train/                  |               |
# |    approx_kl            | 0.00027357778 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.21         |
# |    explained_variance   | 0.109         |
# |    learning_rate        | 0.0007        |
# |    loss                 | 8.82e+05      |
# |    n_updates            | 580           |
# |    policy_gradient_loss | -0.0019       |
# |    value_loss           | 2.24e+06      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1436          |
# |    iterations           | 60            |
# |    time_elapsed         | 85            |
# |    total_timesteps      | 122880        |
# | train/                  |               |
# |    approx_kl            | 0.00012838215 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.16         |
# |    explained_variance   | 0.172         |
# |    learning_rate        | 0.0007        |
# |    loss                 | 6.21e+05      |
# |    n_updates            | 590           |
# |    policy_gradient_loss | -0.00114      |
# |    value_loss           | 1.4e+06       |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1436          |
# |    iterations           | 61            |
# |    time_elapsed         | 86            |
# |    total_timesteps      | 124928        |
# | train/                  |               |
# |    approx_kl            | 0.00039030015 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.22         |
# |    explained_variance   | 0.147         |
# |    learning_rate        | 0.0007        |
# |    loss                 | 7.42e+05      |
# |    n_updates            | 600           |
# |    policy_gradient_loss | -0.00214      |
# |    value_loss           | 1.52e+06      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1436         |
# |    iterations           | 62           |
# |    time_elapsed         | 88           |
# |    total_timesteps      | 126976       |
# | train/                  |              |
# |    approx_kl            | 4.267521e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.19        |
# |    explained_variance   | 0.106        |
# |    learning_rate        | 0.0007       |
# |    loss                 | 1.03e+06     |
# |    n_updates            | 610          |
# |    policy_gradient_loss | -0.000808    |
# |    value_loss           | 2e+06        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1436          |
# |    iterations           | 63            |
# |    time_elapsed         | 89            |
# |    total_timesteps      | 129024        |
# ...
# |    approx_kl            | 0.0013647196 |
# |    clip_fraction        | 0.00298      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.13        |
# |    explained_variance   | 0.205        |
# |    learning_rate        | 0.0007       |
# |    loss                 | 8.33e+05     |
# |    n_updates            | 4680         |
# |    policy_gradient_loss | -0.00241     |
# |    value_loss           | 2.24e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1402         |
# |    iterations           | 470          |
# |    time_elapsed         | 686          |
# |    total_timesteps      | 962560       |
# | train/                  |              |
# |    approx_kl            | 0.0012529183 |
# |    clip_fraction        | 0.00342      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.133        |
# |    learning_rate        | 0.0007       |
# |    loss                 | 9.73e+05     |
# |    n_updates            | 4690         |
# |    policy_gradient_loss | -0.00257     |
# |    value_loss           | 2.37e+06     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1402          |
# |    iterations           | 471           |
# |    time_elapsed         | 687           |
# |    total_timesteps      | 964608        |
# | train/                  |               |
# |    approx_kl            | 0.00075691333 |
# |    clip_fraction        | 0.00244       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.11         |
# |    explained_variance   | 0.109         |
# |    learning_rate        | 0.0007        |
# |    loss                 | 1.27e+06      |
# |    n_updates            | 4700          |
# |    policy_gradient_loss | -0.00187      |
# |    value_loss           | 2.54e+06      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1402          |
# |    iterations           | 472           |
# |    time_elapsed         | 689           |
# |    total_timesteps      | 966656        |
# | train/                  |               |
# |    approx_kl            | 0.00052425975 |
# |    clip_fraction        | 0.000879      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.13         |
# |    explained_variance   | 0.234         |
# |    learning_rate        | 0.0007        |
# |    loss                 | 8.61e+05      |
# |    n_updates            | 4710          |
# |    policy_gradient_loss | -0.00165      |
# |    value_loss           | 2.08e+06      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1402         |
# |    iterations           | 473          |
# |    time_elapsed         | 690          |
# |    total_timesteps      | 968704       |
# | train/                  |              |
# |    approx_kl            | 0.0008127839 |
# |    clip_fraction        | 0.00273      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.14        |
# |    explained_variance   | 0.14         |
# |    learning_rate        | 0.0007       |
# |    loss                 | 1.18e+06     |
# |    n_updates            | 4720         |
# |    policy_gradient_loss | -0.0024      |
# |    value_loss           | 2.47e+06     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1402          |
# |    iterations           | 474           |
# |    time_elapsed         | 692           |
# |    total_timesteps      | 970752        |
# | train/                  |               |
# |    approx_kl            | 0.00095854467 |
# |    clip_fraction        | 0.00171       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.11         |
# |    explained_variance   | 0.156         |
# |    learning_rate        | 0.0007        |
# |    loss                 | 8.98e+05      |
# |    n_updates            | 4730          |
# |    policy_gradient_loss | -0.00167      |
# |    value_loss           | 2.11e+06      |
# -------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1402       |
# |    iterations           | 475        |
# |    time_elapsed         | 693        |
# |    total_timesteps      | 972800     |
# | train/                  |            |
# |    approx_kl            | 0.03608924 |
# |    clip_fraction        | 0.0586     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.13      |
# |    explained_variance   | 0.119      |
# |    learning_rate        | 0.0007     |
# |    loss                 | 9.31e+05   |
# |    n_updates            | 4740       |
# |    policy_gradient_loss | 0.000942   |
# |    value_loss           | 2.35e+06   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1402        |
# |    iterations           | 476         |
# |    time_elapsed         | 694         |
# |    total_timesteps      | 974848      |
# | train/                  |             |
# |    approx_kl            | 0.001696438 |
# |    clip_fraction        | 0.00752     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.179       |
# |    learning_rate        | 0.0007      |
# |    loss                 | 1.45e+06    |
# |    n_updates            | 4750        |
# |    policy_gradient_loss | -0.00349    |
# |    value_loss           | 2.46e+06    |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1402          |
# |    iterations           | 477           |
# |    time_elapsed         | 696           |
# |    total_timesteps      | 976896        |
# | train/                  |               |
# |    approx_kl            | 0.00041607165 |
# |    clip_fraction        | 0.000732      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.18         |
# |    explained_variance   | 0.244         |
# |    learning_rate        | 0.0007        |
# |    loss                 | 8.81e+05      |
# |    n_updates            | 4760          |
# |    policy_gradient_loss | -0.00136      |
# |    value_loss           | 2.32e+06      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1402          |
# |    iterations           | 478           |
# |    time_elapsed         | 697           |
# |    total_timesteps      | 978944        |
# | train/                  |               |
# |    approx_kl            | 0.00079958804 |
# |    clip_fraction        | 0.00288       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.12         |
# |    explained_variance   | 0.194         |
# |    learning_rate        | 0.0007        |
# |    loss                 | 8.86e+05      |
# |    n_updates            | 4770          |
# |    policy_gradient_loss | -0.00296      |
# |    value_loss           | 2.3e+06       |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1402          |
# |    iterations           | 479           |
# |    time_elapsed         | 699           |
# |    total_timesteps      | 980992        |
# | train/                  |               |
# |    approx_kl            | 0.00073604216 |
# |    clip_fraction        | 0.00332       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.15         |
# |    explained_variance   | 0.154         |
# |    learning_rate        | 0.0007        |
# |    loss                 | 1.18e+06      |
# |    n_updates            | 4780          |
# |    policy_gradient_loss | -0.00144      |
# |    value_loss           | 2.21e+06      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1402         |
# |    iterations           | 480          |
# |    time_elapsed         | 701          |
# |    total_timesteps      | 983040       |
# | train/                  |              |
# |    approx_kl            | 0.0018662988 |
# |    clip_fraction        | 0.00576      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | 0.0721       |
# |    learning_rate        | 0.0007       |
# |    loss                 | 1.16e+06     |
# |    n_updates            | 4790         |
# |    policy_gradient_loss | -0.00272     |
# |    value_loss           | 2.33e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1402         |
# |    iterations           | 481          |
# |    time_elapsed         | 702          |
# |    total_timesteps      | 985088       |
# | train/                  |              |
# |    approx_kl            | 0.0021988112 |
# |    clip_fraction        | 0.012        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.0567       |
# |    learning_rate        | 0.0007       |
# |    loss                 | 1.19e+06     |
# |    n_updates            | 4800         |
# |    policy_gradient_loss | -0.00303     |
# |    value_loss           | 2.44e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1401         |
# |    iterations           | 482          |
# |    time_elapsed         | 704          |
# |    total_timesteps      | 987136       |
# | train/                  |              |
# |    approx_kl            | 0.0014922487 |
# |    clip_fraction        | 0.00498      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.13        |
# |    explained_variance   | 0.13         |
# |    learning_rate        | 0.0007       |
# |    loss                 | 7.71e+05     |
# |    n_updates            | 4810         |
# |    policy_gradient_loss | -0.00285     |
# |    value_loss           | 2.31e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1401         |
# |    iterations           | 483          |
# |    time_elapsed         | 705          |
# |    total_timesteps      | 989184       |
# | train/                  |              |
# |    approx_kl            | 0.0020623484 |
# |    clip_fraction        | 0.015        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | 0.147        |
# |    learning_rate        | 0.0007       |
# |    loss                 | 1.04e+06     |
# |    n_updates            | 4820         |
# |    policy_gradient_loss | -0.00214     |
# |    value_loss           | 2.35e+06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1401        |
# |    iterations           | 484         |
# |    time_elapsed         | 707         |
# |    total_timesteps      | 991232      |
# | train/                  |             |
# |    approx_kl            | 0.000933748 |
# |    clip_fraction        | 0.002       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.161       |
# |    learning_rate        | 0.0007      |
# |    loss                 | 8.79e+05    |
# |    n_updates            | 4830        |
# |    policy_gradient_loss | -0.00204    |
# |    value_loss           | 2.3e+06     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1401         |
# |    iterations           | 485          |
# |    time_elapsed         | 708          |
# |    total_timesteps      | 993280       |
# | train/                  |              |
# |    approx_kl            | 0.0028783388 |
# |    clip_fraction        | 0.0183       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.094        |
# |    learning_rate        | 0.0007       |
# |    loss                 | 1.13e+06     |
# |    n_updates            | 4840         |
# |    policy_gradient_loss | -0.00343     |
# |    value_loss           | 2.59e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1401         |
# |    iterations           | 486          |
# |    time_elapsed         | 710          |
# |    total_timesteps      | 995328       |
# | train/                  |              |
# |    approx_kl            | 0.0015048836 |
# |    clip_fraction        | 0.00313      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.16        |
# |    explained_variance   | 0.0735       |
# |    learning_rate        | 0.0007       |
# |    loss                 | 1.28e+06     |
# |    n_updates            | 4850         |
# |    policy_gradient_loss | -0.00293     |
# |    value_loss           | 2.67e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1400         |
# |    iterations           | 487          |
# |    time_elapsed         | 711          |
# |    total_timesteps      | 997376       |
# | train/                  |              |
# |    approx_kl            | 0.0021175407 |
# |    clip_fraction        | 0.0133       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.0817       |
# |    learning_rate        | 0.0007       |
# |    loss                 | 1.45e+06     |
# |    n_updates            | 4860         |
# |    policy_gradient_loss | -0.00432     |
# |    value_loss           | 2.48e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1400         |
# |    iterations           | 488          |
# |    time_elapsed         | 713          |
# |    total_timesteps      | 999424       |
# | train/                  |              |
# |    approx_kl            | 0.0018393637 |
# |    clip_fraction        | 0.00967      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.107        |
# |    learning_rate        | 0.0007       |
# |    loss                 | 1.32e+06     |
# |    n_updates            | 4870         |
# |    policy_gradient_loss | -0.0033      |
# |    value_loss           | 2.45e+06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1400        |
# |    iterations           | 489         |
# |    time_elapsed         | 714         |
# |    total_timesteps      | 1001472     |
# | train/                  |             |
# |    approx_kl            | 0.003271069 |
# |    clip_fraction        | 0.0277      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.0358      |
# |    learning_rate        | 0.0007      |
# |    loss                 | 1.26e+06    |
# |    n_updates            | 4880        |
# |    policy_gradient_loss | -0.00628    |
# |    value_loss           | 2.46e+06    |
# -----------------------------------------

# %%
model.save(model_path)
model.load(model_path)

evaluate_policy(model, vec_env, n_eval_episodes=10, render=True, return_episode_rewards=True)
# evaluate_policy(model, dummy_env, n_eval_episodes=1, render=True, return_episode_rewards=True)
# Out:
# Episode Length: 1
# Stock Level: [[21. 20. 32.]]
# Planned Demand: [ 8. 10.  0.]
# Actual Demand: [9. 8. 0.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 15], maxlen=3),
#     'B': deque([0, 0, 15], maxlen=3),
#     'C': deque([0, 0, 15], maxlen=3)}
#
# Episode Length: 1
# Stock Level: [[22. 19. 32.]]
# Planned Demand: [12. 11.  0.]
# Actual Demand: [8. 9. 0.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 15], maxlen=3),
#     'B': deque([0, 0, 15], maxlen=3),
#     'C': deque([0, 0, 15], maxlen=3)}
#
# Episode Length: 1
# Stock Level: [[30. 16. 32.]]
# Planned Demand: [ 0. 13.  0.]
# Actual Demand: [ 0. 12.  0.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 15], maxlen=3),
#     'B': deque([0, 0, 15], maxlen=3),
#     'C': deque([0, 0, 15], maxlen=3)}
#
# Episode Length: 1
# Stock Level: [[21. 28. 32.]]
# Planned Demand: [10.  0.  0.]
# Actual Demand: [9. 0. 0.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 15], maxlen=3),
#     'B': deque([0, 0, 15], maxlen=3),
#     'C': deque([0, 0, 15], maxlen=3)}
#
# Episode Length: 1
# Stock Level: [[30. 28. 29.]]
# Planned Demand: [0. 0. 6.]
# Actual Demand: [0. 0. 3.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 15], maxlen=3),
#     'B': deque([0, 0, 15], maxlen=3),
#     'C': deque([0, 0, 15], maxlen=3)}
#
# Episode Length: 1
# Stock Level: [[15. 28. 21.]]
# Planned Demand: [13.  0. 12.]
# Actual Demand: [15.  0. 11.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 15], maxlen=3),
#     'B': deque([0, 0, 15], maxlen=3),
#     'C': deque([0, 0, 15], maxlen=3)}
#
# Episode Length: 1
# Stock Level: [[14. 28. 32.]]
# Planned Demand: [15.  0.  0.]
# Actual Demand: [16.  0.  0.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 15], maxlen=3),
#     'B': deque([0, 0, 15], maxlen=3),
#     'C': deque([0, 0, 15], maxlen=3)}
#
# Episode Length: 1
# Stock Level: [[30. 28. 29.]]
# Planned Demand: [0. 0. 4.]
# Actual Demand: [0. 0. 3.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 15], maxlen=3),
#     'B': deque([0, 0, 15], maxlen=3),
#     'C': deque([0, 0, 15], maxlen=3)}
#
# Episode Length: 2
# Stock Level: [[11. 20. 32.]]
# Planned Demand: [8. 0. 0.]
# Actual Demand: [10.  0.  0.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 284.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 15, 15], maxlen=3),
#     'B': deque([0, 15, 15], maxlen=3),
#     'C': deque([0, 15, 15], maxlen=3)}
#
# Episode Length: 2
# Stock Level: [[22. 10. 32.]]
# Planned Demand: [ 0. 12.  0.]
# Actual Demand: [0. 9. 0.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 284.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 15, 15], maxlen=3),
#     'B': deque([0, 15, 15], maxlen=3),
#     'C': deque([0, 15, 15], maxlen=3)}
#
# Episode Length: 2
# Stock Level: [[30.  8. 22.]]
# Planned Demand: [ 0.  8. 14.]
# Actual Demand: [ 0.  8. 10.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 181.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 15, 15], maxlen=3),
#     'B': deque([0, 15, 15], maxlen=3),
#     'C': deque([0, 15, 15], maxlen=3)}
#
# Episode Length: 2
# Stock Level: [[21. 12. 21.]]
# Planned Demand: [ 0. 14.  9.]
# Actual Demand: [ 0. 16. 11.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 120.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 15, 15], maxlen=3),
#     'B': deque([0, 15, 15], maxlen=3),
#     'C': deque([0, 15, 15], maxlen=3)}
#
# Episode Length: 2
# Stock Level: [[30. 21. 29.]]
# Planned Demand: [ 0. 11.  0.]
# Actual Demand: [0. 7. 0.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: -3.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 15, 15], maxlen=3),
#     'B': deque([0, 15, 15], maxlen=3),
#     'C': deque([0, 15, 15], maxlen=3)}
#
# Episode Length: 2
# Stock Level: [[ 3. 22. 15.]]
# Planned Demand: [11.  6.  5.]
# Actual Demand: [12.  6.  6.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 468.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 15, 15], maxlen=3),
#     'B': deque([0, 15, 15], maxlen=3),
#     'C': deque([0, 15, 15], maxlen=3)}
#
# Episode Length: 2
# Stock Level: [[10. 17. 25.]]
# Planned Demand: [ 7. 11.  8.]
# Actual Demand: [ 4. 11.  7.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 263.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 15, 15], maxlen=3),
#     'B': deque([0, 15, 15], maxlen=3),
#     'C': deque([0, 15, 15], maxlen=3)}
#
# Episode Length: 2
# Stock Level: [[30. 20. 29.]]
# Planned Demand: [0. 9. 0.]
# Actual Demand: [0. 8. 0.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: -3.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 15, 15], maxlen=3),
#     'B': deque([0, 15, 15], maxlen=3),
#     'C': deque([0, 15, 15], maxlen=3)}
#
# Episode Length: 3
# Stock Level: [[11.  8. 32.]]
# Planned Demand: [ 0. 13.  0.]
# Actual Demand: [ 0. 12.  0.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 149.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 3
# Stock Level: [[22. 10. 27.]]
# Planned Demand: [0. 6. 3.]
# Actual Demand: [0. 0. 5.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 128.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 3
# Stock Level: [[30.  8. 22.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 310.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 3
# Stock Level: [[21. 12. 10.]]
# Planned Demand: [ 0.  0. 10.]
# Actual Demand: [ 0.  0. 11.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 493.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 3
# Stock Level: [[30. 11. 29.]]
# Planned Demand: [ 0. 10.  0.]
# Actual Demand: [ 0. 10.  0.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 80.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 3
# Stock Level: [[ 3. 14. 15.]]
# Planned Demand: [0. 9. 0.]
# Actual Demand: [0. 8. 0.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 440.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 3
# Stock Level: [[10.  8. 25.]]
# Planned Demand: [0. 8. 0.]
# Actual Demand: [0. 9. 0.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 394.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 3
# Stock Level: [[22. 20. 22.]]
# Planned Demand: [8. 0. 8.]
# Actual Demand: [8. 0. 7.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 101.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 4
# Stock Level: [[26. 23. 47.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: 195.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 4
# Stock Level: [[37. 14. 42.]]
# Planned Demand: [ 0. 10.  0.]
# Actual Demand: [ 0. 11.  0.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: 51.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 4
# Stock Level: [[35. 15. 24.]]
# Planned Demand: [11. 12. 15.]
# Actual Demand: [10.  8. 13.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: -49.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 4
# Stock Level: [[26. 19. 25.]]
# Planned Demand: [12. 12.  0.]
# Actual Demand: [10.  8.  0.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: 179.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 4
# Stock Level: [[45. 17. 44.]]
# Planned Demand: [ 0. 10.  0.]
# Actual Demand: [0. 9. 0.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: 145.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 4
# Stock Level: [[18. 15. 22.]]
# Planned Demand: [ 0. 12.  9.]
# Actual Demand: [ 0. 14.  8.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: 124.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 4
# Stock Level: [[25. 13. 40.]]
# Planned Demand: [ 0. 10.  0.]
# Actual Demand: [ 0. 10.  0.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: 139.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 4
# Stock Level: [[27. 22. 37.]]
# Planned Demand: [12. 11.  0.]
# Actual Demand: [10. 13.  0.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: 248.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 5
# Stock Level: [[27. 31. 62.]]
# Planned Demand: [10.  9.  0.]
# Actual Demand: [14.  7.  0.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: -67.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 5
# Stock Level: [[43. 29. 48.]]
# Planned Demand: [13.  0. 11.]
# Actual Demand: [9. 0. 9.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: 154.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 5
# Stock Level: [[43. 21. 30.]]
# Planned Demand: [ 8. 10. 13.]
# Actual Demand: [7. 9. 9.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: 563.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 5
# Stock Level: [[41. 34. 38.]]
# Planned Demand: [0. 0. 6.]
# Actual Demand: [0. 0. 2.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: 305.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 5
# Stock Level: [[50. 20. 48.]]
# Planned Demand: [10. 10. 10.]
# Actual Demand: [10. 12. 11.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: 107.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 5
# Stock Level: [[27. 24. 37.]]
# Planned Demand: [7. 8. 0.]
# Actual Demand: [6. 6. 0.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: 393.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 5
# Stock Level: [[40. 21. 55.]]
# Planned Demand: [0. 9. 0.]
# Actual Demand: [0. 7. 0.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: 141.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 5
# Stock Level: [[42. 37. 52.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: 397.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 6
# Stock Level: [[27. 32. 63.]]
# Planned Demand: [15. 13.  9.]
# Actual Demand: [15. 14. 14.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: 340.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 6
# Stock Level: [[58. 44. 63.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: 280.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 6
# Stock Level: [[48. 36. 32.]]
# Planned Demand: [ 8.  0. 10.]
# Actual Demand: [10.  0. 13.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: 433.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 6
# Stock Level: [[50. 49. 53.]]
# Planned Demand: [7. 0. 0.]
# Actual Demand: [6. 0. 0.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: -36.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 6
# Stock Level: [[65. 35. 63.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: 581.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 6
# Stock Level: [[35. 27. 40.]]
# Planned Demand: [7. 9. 9.]
# Actual Demand: [ 7. 12. 12.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: 176.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 6
# Stock Level: [[55. 36. 59.]]
# Planned Demand: [0. 0. 9.]
# Actual Demand: [ 0.  0. 11.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: 62.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 6
# Stock Level: [[46. 47. 67.]]
# Planned Demand: [13.  5.  0.]
# Actual Demand: [11.  5.  0.]
# Action: [15, 0, 0]
# Order: [15 15 15]
# Reward: -85.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 0], maxlen=3),
#     'C': deque([15, 15, 0], maxlen=3)}
#
# Episode Length: 7
# Stock Level: [[32. 40. 78.]]
# Planned Demand: [13. 10.  0.]
# Actual Demand: [10.  7.  0.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: 779.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 7
# Stock Level: [[73. 44. 67.]]
# Planned Demand: [ 0. 13.  9.]
# Actual Demand: [ 0. 15. 11.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: -102.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 7
# Stock Level: [[63. 51. 47.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: 382.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 7
# Stock Level: [[65. 51. 68.]]
# Planned Demand: [ 0. 12.  0.]
# Actual Demand: [ 0. 13.  0.]
# Action: [0, 15, 0]
# Order: [15 15 15]
# Reward: 24.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 0], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 0], maxlen=3)}
#
# Episode Length: 7
# Stock Level: [[80. 39. 78.]]
# Planned Demand: [ 0. 13.  0.]
# Actual Demand: [ 0. 11.  0.]
# Action: [0, 15, 0]
# Order: [15 15 15]
# Reward: -101.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 0], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 0], maxlen=3)}
#
# Episode Length: 7
# Stock Level: [[50. 42. 55.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: 549.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 7
# Stock Level: [[70. 51. 74.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 15, 0]
# Order: [15 15 15]
# Reward: 125.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 0], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 0], maxlen=3)}
#
# Episode Length: 7
# Stock Level: [[61. 62. 82.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 0, 0]
# Order: [15 15 15]
# Reward: 233.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 0], maxlen=3),
#     'B': deque([15, 0, 0], maxlen=3),
#     'C': deque([15, 0, 0], maxlen=3)}
#
# Episode Length: 8
# Stock Level: [[47. 46. 93.]]
# Planned Demand: [0. 9. 0.]
# Actual Demand: [0. 9. 0.]
# Action: [0, 0, 0]
# Order: [15 15 15]
# Reward: 245.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 0], maxlen=3),
#     'B': deque([15, 15, 0], maxlen=3),
#     'C': deque([15, 15, 0], maxlen=3)}
#
# Episode Length: 8
# Stock Level: [[81. 55. 82.]]
# Planned Demand: [9. 6. 0.]
# Actual Demand: [7. 4. 0.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: 408.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 8
# Stock Level: [[70. 51. 62.]]
# Planned Demand: [ 8. 13.  0.]
# Actual Demand: [ 8. 15.  0.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: -100.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 8
# Stock Level: [[80. 55. 83.]]
# Planned Demand: [ 0. 13.  0.]
# Actual Demand: [ 0. 11.  0.]
# Action: [0, 0, 0]
# Order: [15 15 15]
# Reward: 161.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 0, 0], maxlen=3),
#     'B': deque([15, 15, 0], maxlen=3),
#     'C': deque([15, 0, 0], maxlen=3)}
#
# Episode Length: 8
# Stock Level: [[95. 47. 85.]]
# Planned Demand: [0. 9. 7.]
# Actual Demand: [0. 7. 8.]
# Action: [0, 0, 0]
# Order: [15 15 15]
# Reward: 115.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 0, 0], maxlen=3),
#     'B': deque([15, 15, 0], maxlen=3),
#     'C': deque([15, 0, 0], maxlen=3)}
#
# Episode Length: 8
# Stock Level: [[55. 57. 59.]]
# Planned Demand: [ 8.  0. 12.]
# Actual Demand: [10.  0. 11.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: -93.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 8
# Stock Level: [[74. 66. 89.]]
# Planned Demand: [12.  0.  0.]
# Actual Demand: [11.  0.  0.]
# Action: [0, 15, 0]
# Order: [15 15 15]
# Reward: -104.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 0, 0], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 0, 0], maxlen=3)}
#
# Episode Length: 8
# Stock Level: [[72. 77. 97.]]
# Planned Demand: [7. 0. 0.]
# Actual Demand: [4. 0. 0.]
# Action: [0, 0, 0]
# Order: [15 15 15]
# Reward: -102.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 9
# Stock Level: [[56. 61. 99.]]
# Planned Demand: [ 8.  0. 10.]
# Actual Demand: [6. 0. 9.]
# Action: [0, 0, 0]
# Order: [15 15 15]
# Reward: 87.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 0, 0], maxlen=3),
#     'B': deque([15, 0, 0], maxlen=3),
#     'C': deque([15, 0, 0], maxlen=3)}
#
# Episode Length: 9
# Stock Level: [[90. 61. 97.]]
# Planned Demand: [6. 9. 0.]
# Actual Demand: [6. 9. 0.]
# Action: [0, 15, 15]
# Order: [15 15 15]
# Reward: 91.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 0], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
# Episode Length: 9
# Stock Level: [[79. 61. 66.]]
# Planned Demand: [8. 9. 7.]
# Actual Demand: [ 6.  5. 11.]
# Action: [0, 0, 0]
# Order: [15 15 15]
# Reward: 349.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 0], maxlen=3),
#     'B': deque([15, 15, 0], maxlen=3),
#     'C': deque([15, 15, 0], maxlen=3)}
#
# Episode Length: 9
# Stock Level: [[82. 63. 98.]]
# Planned Demand: [ 9. 10.  0.]
# Actual Demand: [13.  7.  0.]
# Action: [0, 0, 0]
# Order: [15 15 15]
# Reward: 111.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([15, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 9
# Stock Level: [[110.  62.  94.]]
# Planned Demand: [0. 0. 5.]
# Actual Demand: [0. 0. 6.]
# Action: [0, 0, 0]
# Order: [15 15 15]
# Reward: 186.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([15, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 9
# Stock Level: [[62. 67. 74.]]
# Planned Demand: [7. 6. 0.]
# Actual Demand: [8. 5. 0.]
# Action: [0, 15, 0]
# Order: [15 15 15]
# Reward: 315.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 0], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 0], maxlen=3)}
#
# Episode Length: 9
# Stock Level: [[78. 81. 92.]]
# Planned Demand: [ 9.  0. 12.]
# Actual Demand: [11.  0. 12.]
# Action: [0, 15, 0]
# Order: [15 15 15]
# Reward: 99.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 9
# Stock Level: [[77. 77. 97.]]
# Planned Demand: [12.  0.  0.]
# Actual Demand: [10.  0.  0.]
# Action: [0, 0, 0]
# Order: [15  0  0]
# Reward: -43.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 10
# Stock Level: [[ 69.  76. 114.]]
# Planned Demand: [3. 0. 0.]
# Actual Demand: [2. 0. 0.]
# Action: [0, 0, 0]
# Order: [15 15 15]
# Reward: 192.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 10
# Stock Level: [[ 91.  73. 106.]]
# Planned Demand: [13.  7.  8.]
# Actual Demand: [14.  3.  6.]
# Action: [0, 0, 0]
# Order: [15 15 15]
# Reward: 163.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 0, 0], maxlen=3),
#     'B': deque([15, 15, 0], maxlen=3),
#     'C': deque([15, 15, 0], maxlen=3)}
#
# Episode Length: 10
# Stock Level: [[94. 67. 81.]]
# Planned Demand: [ 0. 13.  0.]
# Actual Demand: [0. 9. 0.]
# Action: [0, 0, 0]
# Order: [15 15 15]
# Reward: 337.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 0, 0], maxlen=3),
#     'B': deque([15, 0, 0], maxlen=3),
#     'C': deque([15, 0, 0], maxlen=3)}
#
# Episode Length: 10
# Stock Level: [[72. 69. 98.]]
# Planned Demand: [11. 11.  0.]
# Actual Demand: [10.  9.  0.]
# Action: [0, 0, 0]
# Order: [ 0 15  0]
# Reward: 278.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 10
# Stock Level: [[110.  68.  94.]]
# Planned Demand: [ 0. 11.  0.]
# Actual Demand: [0. 9. 0.]
# Action: [0, 0, 0]
# Order: [ 0 15  0]
# Reward: -13.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 10
# Stock Level: [[77. 70. 79.]]
# Planned Demand: [ 0.  8. 10.]
# Actual Demand: [ 0. 12. 10.]
# Action: [0, 15, 0]
# Order: [15 15 15]
# Reward: 152.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 0, 0], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 0, 0], maxlen=3)}
#
# Episode Length: 10
# Stock Level: [[73. 96. 84.]]
# Planned Demand: [9. 0. 7.]
# Actual Demand: [5. 0. 8.]
# Action: [0, 0, 0]
# Order: [ 0 15  0]
# Reward: 328.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([15, 15, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 10
# Stock Level: [[68. 77. 87.]]
# Planned Demand: [12.  0. 10.]
# Actual Demand: [ 9.  0. 10.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 74.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 11
# Stock Level: [[ 56.  76. 101.]]
# Planned Demand: [13.  0. 11.]
# Actual Demand: [13.  0. 13.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: -89.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 11
# Stock Level: [[ 93.  83. 121.]]
# Planned Demand: [10.  6.  0.]
# Actual Demand: [13.  5.  0.]
# Action: [0, 0, 0]
# Order: [15 15 15]
# Reward: 325.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([15, 0, 0], maxlen=3),
#     'C': deque([15, 0, 0], maxlen=3)}
#
# Episode Length: 11
# Stock Level: [[109.  82.  96.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 0, 0]
# Order: [15 15 15]
# Reward: 59.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 11
# Stock Level: [[72. 69. 92.]]
# Planned Demand: [0. 0. 7.]
# Actual Demand: [0. 0. 6.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 260.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 11
# Stock Level: [[110.  68.  81.]]
# Planned Demand: [ 0.  0. 15.]
# Actual Demand: [ 0.  0. 13.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 44.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 11
# Stock Level: [[82. 85. 94.]]
# Planned Demand: [13.  0.  0.]
# Actual Demand: [10.  0.  0.]
# Action: [0, 0, 0]
# Order: [15 15 15]
# Reward: 320.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([15, 15, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 11
# Stock Level: [[ 73. 111.  84.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 0, 0]
# Order: [ 0 15  0]
# Reward: 133.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([15, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 11
# Stock Level: [[68. 72. 87.]]
# Planned Demand: [0. 6. 0.]
# Actual Demand: [0. 5. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 264.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 12
# Stock Level: [[56. 76. 97.]]
# Planned Demand: [0. 0. 7.]
# Actual Demand: [0. 0. 4.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 403.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 12
# Stock Level: [[ 82.  98. 121.]]
# Planned Demand: [10.  0. 16.]
# Actual Demand: [11.  0. 15.]
# Action: [0, 0, 0]
# Order: [ 0 15 15]
# Reward: 211.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 12
# Stock Level: [[100.  82.  96.]]
# Planned Demand: [8. 0. 0.]
# Actual Demand: [9. 0. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: -143.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 12
# Stock Level: [[68. 64. 80.]]
# Planned Demand: [ 4.  5. 11.]
# Actual Demand: [ 4.  5. 12.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 3.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 12
# Stock Level: [[110.  68.  69.]]
# Planned Demand: [ 0.  0. 13.]
# Actual Demand: [ 0.  0. 12.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 130.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 12
# Stock Level: [[69. 91. 94.]]
# Planned Demand: [ 9. 12.  0.]
# Actual Demand: [13.  9.  0.]
# Action: [0, 0, 0]
# Order: [ 0 15  0]
# Reward: 69.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([15, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 12
# Stock Level: [[ 73. 115.  84.]]
# Planned Demand: [ 0. 11.  3.]
# Actual Demand: [ 0. 11.  0.]
# Action: [0, 0, 0]
# Order: [ 0 15  0]
# Reward: -134.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 12
# Stock Level: [[54. 62. 80.]]
# Planned Demand: [13. 12. 11.]
# Actual Demand: [14. 10.  7.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: -13.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 13
# Stock Level: [[45. 72. 84.]]
# Planned Demand: [12.  5. 10.]
# Actual Demand: [11.  4. 13.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: -34.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 13
# Stock Level: [[ 71.  91. 117.]]
# Planned Demand: [14. 10.  6.]
# Actual Demand: [11.  7.  4.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 369.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 13
# Stock Level: [[100.  82.  82.]]
# Planned Demand: [ 0.  0. 11.]
# Actual Demand: [ 0.  0. 14.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 41.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 13
# Stock Level: [[63. 56. 80.]]
# Planned Demand: [4. 9. 0.]
# Actual Demand: [5. 8. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 314.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 13
# Stock Level: [[102.  63.  65.]]
# Planned Demand: [7. 8. 7.]
# Actual Demand: [8. 5. 4.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 116.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 13
# Stock Level: [[54. 96. 88.]]
# Planned Demand: [13.  9.  4.]
# Actual Demand: [15. 10.  6.]
# Action: [0, 0, 0]
# Order: [ 0 15  0]
# Reward: 313.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 13
# Stock Level: [[ 73. 106.  80.]]
# Planned Demand: [ 0. 11.  4.]
# Actual Demand: [0. 9. 4.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 84.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 13
# Stock Level: [[54. 54. 70.]]
# Planned Demand: [ 0.  6. 11.]
# Actual Demand: [ 0.  8. 10.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 522.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 14
# Stock Level: [[45. 66. 84.]]
# Planned Demand: [0. 7. 4.]
# Actual Demand: [0. 6. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 459.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 14
# Stock Level: [[ 62.  91. 117.]]
# Planned Demand: [11.  0.  0.]
# Actual Demand: [9. 0. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 300.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 14
# Stock Level: [[100.  82.  82.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 148.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 14
# Stock Level: [[58. 52. 80.]]
# Planned Demand: [9. 7. 0.]
# Actual Demand: [5. 4. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 160.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 14
# Stock Level: [[102.  63.  57.]]
# Planned Demand: [ 0.  0. 10.]
# Actual Demand: [0. 0. 8.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 225.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 14
# Stock Level: [[54. 96. 88.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 501.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 14
# Stock Level: [[ 73. 106.  70.]]
# Planned Demand: [0. 0. 8.]
# Actual Demand: [ 0.  0. 10.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 130.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 14
# Stock Level: [[54. 54. 65.]]
# Planned Demand: [0. 0. 4.]
# Actual Demand: [0. 0. 5.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 271.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 15
# Stock Level: [[45. 60. 84.]]
# Planned Demand: [0. 5. 0.]
# Actual Demand: [0. 6. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 22.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 15
# Stock Level: [[ 51.  91. 117.]]
# Planned Demand: [10.  0.  0.]
# Actual Demand: [11.  0.  0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 45.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 15
# Stock Level: [[100.  79.  82.]]
# Planned Demand: [0. 5. 0.]
# Actual Demand: [0. 3. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: -132.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 15
# Stock Level: [[58. 50. 80.]]
# Planned Demand: [0. 3. 0.]
# Actual Demand: [0. 2. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 85.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 15
# Stock Level: [[94. 46. 57.]]
# Planned Demand: [10. 14.  0.]
# Actual Demand: [ 8. 17.  0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 49.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 15
# Stock Level: [[54. 89. 88.]]
# Planned Demand: [0. 5. 0.]
# Actual Demand: [0. 7. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: -119.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 15
# Stock Level: [[ 73. 106.  60.]]
# Planned Demand: [ 0.  0. 10.]
# Actual Demand: [ 0.  0. 10.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 75.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 15
# Stock Level: [[54. 47. 65.]]
# Planned Demand: [0. 8. 0.]
# Actual Demand: [0. 7. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 13.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 16
# Stock Level: [[45. 60. 84.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 25.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 16
# Stock Level: [[ 39.  80. 117.]]
# Planned Demand: [14. 10.  0.]
# Actual Demand: [12. 11.  0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 90.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 16
# Stock Level: [[88. 66. 75.]]
# Planned Demand: [10. 10. 10.]
# Actual Demand: [12. 13.  7.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: -70.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 16
# Stock Level: [[58. 50. 67.]]
# Planned Demand: [ 0.  0. 15.]
# Actual Demand: [ 0.  0. 13.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: -54.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 16
# Stock Level: [[83. 29. 57.]]
# Planned Demand: [12. 15.  0.]
# Actual Demand: [11. 17.  0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 401.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 16
# Stock Level: [[54. 89. 82.]]
# Planned Demand: [ 0.  0. 12.]
# Actual Demand: [0. 0. 6.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 24.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 16
# Stock Level: [[73. 96. 49.]]
# Planned Demand: [ 0. 11. 10.]
# Actual Demand: [ 0. 10. 11.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 80.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 16
# Stock Level: [[46. 39. 52.]]
# Planned Demand: [10.  7. 14.]
# Actual Demand: [ 8.  8. 13.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 57.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 17
# Stock Level: [[35. 55. 84.]]
# Planned Demand: [14.  4.  0.]
# Actual Demand: [10.  5.  0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: -94.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 17
# Stock Level: [[ 23.  80. 111.]]
# Planned Demand: [11.  0.  7.]
# Actual Demand: [16.  0.  6.]
# Action: [15, 0, 0]
# Order: [0 0 0]
# Reward: 342.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 15], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 17
# Stock Level: [[88. 58. 75.]]
# Planned Demand: [0. 8. 0.]
# Actual Demand: [0. 8. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 525.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 17
# Stock Level: [[52. 50. 55.]]
# Planned Demand: [11.  0. 15.]
# Actual Demand: [ 6.  0. 12.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 172.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 17
# Stock Level: [[78. 17. 45.]]
# Planned Demand: [ 8. 12. 14.]
# Actual Demand: [ 5. 12. 12.]
# Action: [0, 15, 0]
# Order: [0 0 0]
# Reward: 475.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 15], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 17
# Stock Level: [[47. 89. 82.]]
# Planned Demand: [8. 0. 0.]
# Actual Demand: [7. 0. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 7.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 17
# Stock Level: [[62. 84. 42.]]
# Planned Demand: [12. 10.  8.]
# Actual Demand: [11. 12.  7.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 311.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 17
# Stock Level: [[46. 39. 52.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 511.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 18
# Stock Level: [[27. 55. 84.]]
# Planned Demand: [8. 0. 0.]
# Actual Demand: [8. 0. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 213.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 18
# Stock Level: [[ 18.  73. 111.]]
# Planned Demand: [6. 8. 0.]
# Actual Demand: [5. 7. 0.]
# Action: [15, 0, 0]
# Order: [0 0 0]
# Reward: 326.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 15, 15], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 18
# Stock Level: [[88. 52. 75.]]
# Planned Demand: [0. 9. 0.]
# Actual Demand: [0. 6. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 49.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 18
# Stock Level: [[34. 37. 45.]]
# Planned Demand: [17. 13. 11.]
# Actual Demand: [18. 13. 10.]
# Action: [0, 15, 0]
# Order: [0 0 0]
# Reward: 281.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 15], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
# Episode Length: 18
# Stock Level: [[78. 17. 45.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 15, 15]
# Order: [0 0 0]
# Reward: 503.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# ...
#
#
# Episode Length: 47
# Stock Level: [[75. 44. 97.]]
# Planned Demand: [ 9. 12.  0.]
# Actual Demand: [ 5. 10.  0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 424.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Episode Length: 47
# Stock Level: [[21. 18. 47.]]
# Planned Demand: [ 9.  6. 10.]
# Actual Demand: [10.  6. 12.]
# Action: [15, 15, 15]
# Order: [15 15  0]
# Reward: -61.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
#
# Episode Length: 47
# Stock Level: [[39. 63. 82.]]
# Planned Demand: [0. 7. 0.]
# Actual Demand: [0. 9. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: -56.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Episode Length: 47
# Stock Level: [[84. 66. 84.]]
# Planned Demand: [ 0. 11.  0.]
# Actual Demand: [ 0. 12.  0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 17.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Episode Length: 47
# Stock Level: [[40. 20. 62.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: -61.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Episode Length: 47
# Stock Level: [[ 73. 125.  65.]]
# Planned Demand: [7. 0. 6.]
# Actual Demand: [3. 0. 4.]
# Action: [0, 0, 0]
# Order: [15 15 15]
# Reward: 27.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Episode Length: 47
# Stock Level: [[79. 95. 36.]]
# Planned Demand: [ 0. 10.  0.]
# Actual Demand: [0. 9. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: -109.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Episode Length: 48
# Stock Level: [[39. 89. 99.]]
# Planned Demand: [13. 11.  0.]
# Actual Demand: [9. 9. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 37.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Episode Length: 48
# Stock Level: [[75. 44. 97.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 192.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Episode Length: 48
# Stock Level: [[31. 25. 62.]]
# Planned Demand: [6. 8. 0.]
# Actual Demand: [5. 8. 0.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: 497.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
#
# Episode Length: 48
# Stock Level: [[34. 63. 82.]]
# Planned Demand: [8. 0. 0.]
# Actual Demand: [5. 0. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 88.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Episode Length: 48
# Stock Level: [[84. 59. 81.]]
# Planned Demand: [0. 9. 5.]
# Actual Demand: [0. 7. 3.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 123.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Episode Length: 48
# Stock Level: [[36. 16. 62.]]
# Planned Demand: [3. 6. 0.]
# Actual Demand: [4. 4. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: -61.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Episode Length: 48
# Stock Level: [[ 73. 125.  65.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 8.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Episode Length: 48
# Stock Level: [[64. 95. 36.]]
# Planned Demand: [15.  0.  0.]
# Actual Demand: [15.  0.  0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 75.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Episode Length: 49
# Stock Level: [[34. 89. 83.]]
# Planned Demand: [ 7.  0. 13.]
# Actual Demand: [ 5.  0. 16.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 246.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Episode Length: 49
# Stock Level: [[66. 44. 89.]]
# Planned Demand: [10.  0.  8.]
# Actual Demand: [9. 0. 8.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: -108.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Episode Length: 49
# Stock Level: [[34. 28. 77.]]
# Planned Demand: [13.  9.  0.]
# Actual Demand: [12. 12.  0.]
# Action: [15, 15, 15]
# Order: [15 15 15]
# Reward: 181.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 15], maxlen=3)}
#
#
# Episode Length: 49
# Stock Level: [[34. 63. 82.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 10.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Episode Length: 49
# Stock Level: [[73. 59. 69.]]
# Planned Demand: [ 8.  0. 12.]
# Actual Demand: [11.  0. 12.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 88.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Episode Length: 49
# Stock Level: [[36. 16. 62.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 103.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Episode Length: 49
# Stock Level: [[ 67. 125.  60.]]
# Planned Demand: [4. 0. 7.]
# Actual Demand: [6. 0. 5.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: -131.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Episode Length: 49
# Stock Level: [[54. 84. 25.]]
# Planned Demand: [11. 10. 10.]
# Actual Demand: [10. 11. 11.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 202.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Episode Length: 50
# Stock Level: [[34. 79. 73.]]
# Planned Demand: [ 0. 10. 10.]
# Actual Demand: [ 0. 10. 10.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 317.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Episode Length: 50
# Stock Level: [[59. 44. 76.]]
# Planned Demand: [ 9.  0. 14.]
# Actual Demand: [ 7.  0. 13.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 240.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Episode Length: 50
# Stock Level: [[49. 31. 87.]]
# Planned Demand: [ 0. 12.  6.]
# Actual Demand: [ 0. 12.  5.]
# Action: [15, 15, 0]
# Order: [15 15 15]
# Reward: 391.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 15], maxlen=3),
#     'B': deque([15, 15, 15], maxlen=3),
#     'C': deque([15, 15, 0], maxlen=3)}
#
#
# Episode Length: 50
# Stock Level: [[34. 63. 77.]]
# Planned Demand: [0. 0. 7.]
# Actual Demand: [0. 0. 5.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: -89.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Episode Length: 50
# Stock Level: [[60. 59. 69.]]
# Planned Demand: [13.  0.  0.]
# Actual Demand: [13.  0.  0.]
# Action: [0, 15, 15]
# Order: [0 0 0]
# Reward: 359.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 15], maxlen=3),
#     'C': deque([0, 0, 15], maxlen=3)}
#
#
# Episode Length: 50
# Stock Level: [[36. 16. 54.]]
# Planned Demand: [0. 0. 9.]
# Actual Demand: [0. 0. 8.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: -57.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Episode Length: 50
# Stock Level: [[ 56. 117.  53.]]
# Planned Demand: [12. 10.  8.]
# Actual Demand: [11.  8.  7.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 94.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Episode Length: 50
# Stock Level: [[54. 77. 25.]]
# Planned Demand: [0. 8. 0.]
# Actual Demand: [0. 7. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 558.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Episode Length: 51
# Stock Level: [[24. 79. 67.]]
# Planned Demand: [12.  0.  5.]
# Actual Demand: [10.  0.  6.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 307.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Episode Length: 51
# Stock Level: [[49. 30. 76.]]
# Planned Demand: [ 7. 16.  0.]
# Actual Demand: [10. 14.  0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 310.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Episode Length: 51
# Stock Level: [[54. 46. 94.]]
# Planned Demand: [11.  0.  8.]
# Actual Demand: [10.  0.  8.]
# Action: [0, 0, 0]
# Order: [15 15 15]
# Reward: 243.5
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([15, 15, 0], maxlen=3),
#     'B': deque([15, 15, 0], maxlen=3),
#     'C': deque([15, 0, 0], maxlen=3)}
#
#
# Episode Length: 51
# Stock Level: [[34. 51. 77.]]
# Planned Demand: [ 0. 14.  0.]
# Actual Demand: [ 0. 12.  0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 13.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Episode Length: 51
# Stock Level: [[60. 51. 69.]]
# Planned Demand: [0. 6. 0.]
# Actual Demand: [0. 8. 0.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 153.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 15], maxlen=3),
#     'B': deque([0, 15, 15], maxlen=3),
#     'C': deque([0, 15, 15], maxlen=3)}
#
#
# Episode Length: 51
# Stock Level: [[36.  7. 54.]]
# Planned Demand: [0. 7. 0.]
# Actual Demand: [0. 9. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 107.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Episode Length: 51
# Stock Level: [[ 43. 117.  53.]]
# Planned Demand: [11.  0.  0.]
# Actual Demand: [13.  0.  0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 407.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Episode Length: 51
# Stock Level: [[54. 77. 25.]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [0. 0. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 62.0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Episode Length: 0
# Stock Level: [[30 28 32]]
# Planned Demand: [10. 11. 10.]
# Actual Demand: [0. 0. 8.]
# Action: [15, 0, 0]
# Order: [0 0 0]
# Reward: 0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Episode Length: 0
# Stock Level: [[30 28 32]]
# Planned Demand: [9. 8. 0.]
# Actual Demand: [ 0.  0. 12.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Episode Length: 0
# Stock Level: [[30 28 32]]
# Planned Demand: [11.  0. 10.]
# Actual Demand: [ 0. 11.  9.]
# Action: [0, 0, 0]
# Order: [15 15 15]
# Reward: 0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Episode Length: 0
# Stock Level: [[30 28 32]]
# Planned Demand: [0. 0. 0.]
# Actual Demand: [9. 0. 7.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Episode Length: 0
# Stock Level: [[30 28 32]]
# Planned Demand: [11.  8.  0.]
# Actual Demand: [ 0.  9. 12.]
# Action: [15, 15, 15]
# Order: [0 0 0]
# Reward: 0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Episode Length: 0
# Stock Level: [[30 28 32]]
# Planned Demand: [ 0. 11.  0.]
# Actual Demand: [15.  0.  5.]
# Action: [0, 15, 0]
# Order: [0 0 0]
# Reward: 0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Episode Length: 0
# Stock Level: [[30 28 32]]
# Planned Demand: [ 0. 12. 10.]
# Actual Demand: [10.  0.  5.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
#
#
# Episode Length: 0
# Stock Level: [[30 28 32]]
# Planned Demand: [11.  4. 14.]
# Actual Demand: [7. 0. 0.]
# Action: [0, 0, 0]
# Order: [0 0 0]
# Reward: 0
#
# Backlog:
# {'A': deque([]), 'B': deque([]), 'C': deque([])}
# Order Queue:
# {   'A': deque([0, 0, 0], maxlen=3),
#     'B': deque([0, 0, 0], maxlen=3),
#     'C': deque([0, 0, 0], maxlen=3)}
# ([8500.0,
#   9628.0,
#   7536.5,
#   9480.0,
#   9790.5,
#   9504.0,
#   8694.0,
#   8748.0,
#   7673.5,
#   7413.0],
#  [52, 52, 52, 52, 52, 52, 52, 52, 52, 52])

# %%
# Adapt the path if required
file = './Data/2024-10-25_15_last_environment_data.csv'
df = pd.read_csv(file)

plot_data(df)
