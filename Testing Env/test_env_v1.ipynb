# %% [markdown]
# Change from v0
#
# - Added more information to the observation space (expected demand)
# - Added cost for orders as well as the cost for the inventory
# - Added delivery
# - Change from stable baselines to ray rllib

# %% [markdown]
# **Importing Dependencies**

# %%
# Gymnasium imports
import gymnasium as gym 
from gymnasium import Env
from gymnasium.spaces import Discrete, Box, Dict, Tuple, MultiBinary, MultiDiscrete 

import pygame
import pygame.gfxdraw

import networkx as nx

# Import helpers
import numpy as np
import pandas as pd
import random
import os
import matplotlib.pyplot as plt
import seaborn as sns

from collections import deque

# Import stable baselines
# Probably not needed --> test ray lib instead
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import VecFrameStack, DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# **Building the environment**

# %%
class SS_Mngmt_Env(Env):

    metadata = {"render_modes": ["human"], "render_fps": 4}
    
    # Define the action and observation space
    def __init__(self, render_mode = None):

        # To implement
        # storage capacities
        # campaign size
        # safety stock

        self.I = 30 # Initial stock level

        # Demand
        self.expected_demand = 6 # Expected demand for production
        self.actual_demand = 6 # Actual demand for production

        # Costs
        self.c_fixed = 50 # Fixed costs for ordering
        self.c_variable = 1 # Variable costs for ordering per unit
        self.p = 1 # Cost for storing each item
        self.stockout_cost = 1000 # Cost of stockout

        self.episode_length = 29 # Length of the episode

        # Order delay and queue
        self.order_delay = 3
        self.order_queue = deque(maxlen = self.order_delay)

        self.delivered = 0  # Delivered stock
        
        # Define action space
        # Change the action space for different campaign sizes
        self.action_space = Discrete(10)
        
        # Define observation space (Stock level) --> to add expected demand, etc.
        self.observation_space = Box(low = np.array([0, 0]), 
                                     high = np.array([100, 10]),
                                     dtype = np.int64)

        # Define the initial state
        self.state = np.array([self.I, self.expected_demand])

        # History
        self.reward_history = []
        self.stock_history = []
        self.demand_history = []
        self.expected_demand_history = []
        self.order_history = []
        self.delivery_history = []

        # Empty dataframe for plotting the history and analysis
        self.history = pd.DataFrame(columns = ['Stock Level', 'Order', 'Demand'])

        self.render_mode = render_mode
        self.screen_initialized = False


    # Defining the step function
    def step(self, action):
        # Returns the next state, reward and whether the episode is done

        # Demand for production --> random for now
        self.demand = self.state[1] + random.randint(-1, 1)

        # Subtract the demand from the stock
        self.state[0] = self.state[0] - self.demand

        # To Do: Implement the cost of ordering stock
        # To Do: Campaign Size
        # To Do: Demand can only be fullfilled if sufficient stock is available demand is then placed in the backlog queue

        # If there are enough steps passed since the order was placed, add the order to the stock
        if len(self.order_queue) == self.order_delay:
            self.delivered = self.order_queue.popleft()
            self.state[0] += self.delivered
        
        # Add the order to the queue
        self.order_queue.append(action)

        # Calculate the reward based on order costs
        if action > 0:
            reward = - self.c_fixed - self.c_variable * action
        else:
            reward = 0

        # Check if the stock level is negative
        if self.state[0] <= 0:
            # If the stock level is negative, the cost is the stockout cost
            reward = reward - self.stockout_cost
        else:
            # If the stock level is positive, the cost is the stock level
            reward = reward - self.state[0]

        # Calculate the cost of the stock
        # Reward is negative since we want to minimize the cost
        # reward = float(reward - (self.state))

        # Check if the episode is done
        done = self.episode_length == 0

        # Decrease the episode length
        self.episode_length -= 1

        obs = np.array([self.state[0], self.state[1]])

        # Append the state to the history
        self.reward_history.append(reward)
        self.stock_history.append(self.state[0])
        self.order_history.append(action)
        self.demand_history.append(self.demand)
        self.expected_demand_history.append(self.state[1])
        self.delivery_history.append(self.delivered)

        # Check if episode is done
        if self.episode_length <= 0: 
            done = True
        else:
            done = False

        # Set placeholder for info
        info = {}

        # Check if the episode is truncated
        truncated = False

        return obs, float(reward), done, truncated, info

    def render(self):
        # Just check episode lenghth and only plot the last one when using matplotlib          
        if self.render_mode is not None:
            if self.render_mode == "human":
                self.render_human()
                # self.render_pygame()

    def render_human(self):

        # To Do
        # Actual vs. Expected Demand

        # Create a list of timestamps for the order history
        timestamps = np.arange(len(self.order_history))

        # Setting up the plot
        fig, ax = plt.subplots(3, 2, figsize=(12, 9)) # 1 row and 2 columns
        bar_width = 0.35
        
        # Plotting the stock level
        ax[0, 0].plot(self.stock_history, color = 'blue', label = 'Stock Level')
        ax[0, 0].set_ylabel('Stock Level')
        # ax[0, 0].set_xlabel('Time')
        ax[0, 0].set_title('Stock Level vs. Time')
        ax[0, 0].set_xticks(np.arange(0, 30, step=5))
        ax[0, 0].set_yticks(np.arange(0, 100, step=10))

        # Plotting the order, delivered and demand
        ax[1, 0].bar(timestamps - bar_width, self.order_history, bar_width, color='blue', alpha = 0.5, label='Order')
        ax[1, 0].bar(timestamps, self.delivery_history, bar_width, color='red', alpha = 0.5, label='Delivery')
        ax[1, 0].bar(timestamps + bar_width, self.demand_history, bar_width, color='green', alpha=0.5, label='Demand')
        ax[1, 0].set_ylabel('Order/Delivery/Demand')
        ax[1, 0].set_title('Order vs. Delivery vs. Demand')
        ax[1, 0].set_xticks(np.arange(0, 30, step=5))
        ax[1, 0].legend(['Order', 'Delivery', 'Demand'])

        # Plotting the reward per timestep
        ax[0, 1].plot(self.reward_history, color = 'purple', label = 'Reward')
        ax[0, 1].set_ylabel('Reward')
        # ax[0, 1].set_xlabel('Time')
        ax[0, 1].set_title('Reward vs. Time')
        ax[0, 1].set_xticks(np.arange(0, 30, step=5))

        # Plotting the accumulated reward
        ax[1, 1].plot(np.cumsum(self.reward_history), color = 'orange', label = 'Accumulated Reward')
        ax[1, 1].set_ylabel('Accumulated Reward')
        # ax[1, 1].set_xlabel('Time')
        ax[1, 1].set_title('Accumulated Reward vs. Time')
        ax[1, 1].set_xticks(np.arange(0, 30, step=5))

        # Plotting the expected demand and actual demand
        ax[2, 0].plot(self.expected_demand_history, color = 'blue', label = 'Expected Demand')
        ax[2, 0].plot(self.demand_history, color = 'green', label = 'Actual Demand')
        ax[2, 0].set_ylabel('Demand')
        ax[2, 0].set_title('Expected vs. Actual Demand')
        ax[2, 0].set_xticks(np.arange(0, 30, step=5))

        # Show the plot if the episode is done
        if self.episode_length == 0:
            # plt.tight_layout()
            plt.show()
        
        return


    def reset(self, seed = None):
        # Reset the state of the environment back to an initial state

        super().reset(seed = seed) # Reset the seed
        if seed is not None:
            random.seed(seed)

        # Reset the episode length
        self.episode_length = 30

        # Reset the order queue
        self.order_queue.clear()

        # Define the initial state
        self.state = np.array([self.I, self.expected_demand])

        obs = np.array([self.state[0], self.expected_demand])

        # # Append history to the dataframe
        # self.history['Stock Level'] = self.stock_history
        # self.history['Order'] = self.stock_history
        # self.history['Demand'] = self.demand_history

        # Reset the history
        self.reward_history = []
        self.stock_history = []
        self.order_history = []
        self.demand_history = []
        self.expected_demand_history = []
        self.delivery_history = []

        # Placeholder for info
        info = {}

        return obs, info

# %% [markdown]
# **Testng the environment**

# %%
from stable_baselines3.common.env_checker import check_env

env = SS_Mngmt_Env(render_mode="human")
check_env(env, warn=True)

# %%
env = SS_Mngmt_Env(render_mode="human")

episodes = 1
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        action = env.action_space.sample()
        n_state, reward, done, info, _ = env.step(action)
        score+=reward

        # print('Step:{} Score:{} Stock:{} Order:{} Demand:{}'.format(env.episode_length, score, n_state, action, env.demand))

    env.render()

    # print(env.order_history)

# %%
episodes = 10
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        action = env.action_space.sample()
        n_state, reward, done, info, _ = env.step(action)
        score+=reward
    print('Episode:{} Score:{} Stock:{} Last Action:{}'.format(episode, score, n_state, action))
# Out:
# Episode:1 Score:-2560.0 Stock:[77] Last Action:2
# Episode:2 Score:-2093.0 Stock:[63] Last Action:1
# Episode:3 Score:-3017.0 Stock:[57] Last Action:0
# Episode:4 Score:-3256.0 Stock:[125] Last Action:2
# Episode:5 Score:-2971.0 Stock:[119] Last Action:1
# Episode:6 Score:-2163.0 Stock:[32] Last Action:2
# Episode:7 Score:-2316.0 Stock:[54] Last Action:0
# Episode:8 Score:-2928.0 Stock:[73] Last Action:2
# Episode:9 Score:-2936.0 Stock:[69] Last Action:2
# Episode:10 Score:-2293.0 Stock:[76] Last Action:2

# %% [markdown]
# **Train Model**

# %%
log_path = os.path.join('Training', 'Logs')
model_path = os.path.join('Training', 'Models', 'PPO')

# %%
env = SS_Mngmt_Env(render_mode="human")

# wrapping the environment in a vectorized environment
env = DummyVecEnv([lambda: env])

model = PPO("MlpPolicy", env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=100000)
# Out:
# Logging to Training/Logs/PPO_4
# -----------------------------
# | time/              |      |
# |    fps             | 6918 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4053          |
# |    iterations           | 2             |
# |    time_elapsed         | 1             |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 5.0662726e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | -1.55e-06     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.43e+07      |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -0.000378     |
# |    value_loss           | 1e+08         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3610          |
# |    iterations           | 3             |
# |    time_elapsed         | 1             |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 4.6319212e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | -1.07e-06     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.46e+07      |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -0.000317     |
# |    value_loss           | 9.96e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3418          |
# |    iterations           | 4             |
# |    time_elapsed         | 2             |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 1.7956656e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | -7.15e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.26e+07      |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -0.000157     |
# |    value_loss           | 9.73e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3322          |
# |    iterations           | 5             |
# |    time_elapsed         | 3             |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 7.7249686e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | -3.58e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.73e+07      |
# |    n_updates            | 90            |
# |    policy_gradient_loss | -0.000602     |
# |    value_loss           | 9.91e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3257          |
# |    iterations           | 6             |
# |    time_elapsed         | 3             |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 4.1365885e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | -4.77e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.79e+07      |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -0.000379     |
# |    value_loss           | 9.99e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3207          |
# |    iterations           | 7             |
# |    time_elapsed         | 4             |
# |    total_timesteps      | 14336         |
# | train/                  |               |
# |    approx_kl            | 4.7321373e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | -2.38e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.67e+07      |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -0.000419     |
# |    value_loss           | 9.99e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3171          |
# |    iterations           | 8             |
# |    time_elapsed         | 5             |
# |    total_timesteps      | 16384         |
# | train/                  |               |
# |    approx_kl            | 0.00011112599 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | -2.38e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.37e+07      |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.00074      |
# |    value_loss           | 1.01e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3115          |
# |    iterations           | 9             |
# |    time_elapsed         | 5             |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 2.5732472e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | -2.38e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.61e+07      |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -0.000213     |
# |    value_loss           | 9.91e+07      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3083         |
# |    iterations           | 10           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 6.759836e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.3         |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.39e+07     |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.000489    |
# |    value_loss           | 1.01e+08     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3051          |
# |    iterations           | 11            |
# |    time_elapsed         | 7             |
# |    total_timesteps      | 22528         |
# | train/                  |               |
# |    approx_kl            | 0.00011010928 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | -2.38e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.09e+07      |
# |    n_updates            | 150           |
# |    policy_gradient_loss | -0.000798     |
# |    value_loss           | 1e+08         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3028          |
# |    iterations           | 12            |
# |    time_elapsed         | 8             |
# |    total_timesteps      | 24576         |
# | train/                  |               |
# |    approx_kl            | 2.3136177e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.9e+07       |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -0.000169     |
# |    value_loss           | 9.97e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3020          |
# |    iterations           | 13            |
# |    time_elapsed         | 8             |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 4.6422152e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.89e+07      |
# |    n_updates            | 170           |
# |    policy_gradient_loss | -0.000359     |
# |    value_loss           | 9.62e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3012          |
# |    iterations           | 14            |
# |    time_elapsed         | 9             |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 3.6252546e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.52e+07      |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.000276     |
# |    value_loss           | 1e+08         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3007          |
# |    iterations           | 15            |
# |    time_elapsed         | 10            |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 0.00010181367 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.15e+07      |
# |    n_updates            | 190           |
# |    policy_gradient_loss | -0.000743     |
# |    value_loss           | 1.01e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3001          |
# |    iterations           | 16            |
# |    time_elapsed         | 10            |
# |    total_timesteps      | 32768         |
# | train/                  |               |
# |    approx_kl            | 5.0261355e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.41e+07      |
# |    n_updates            | 200           |
# |    policy_gradient_loss | -0.000381     |
# |    value_loss           | 1.01e+08      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2997         |
# |    iterations           | 17           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 4.699288e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.3         |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.41e+07     |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.000406    |
# |    value_loss           | 9.57e+07     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2992          |
# |    iterations           | 18            |
# |    time_elapsed         | 12            |
# |    total_timesteps      | 36864         |
# | train/                  |               |
# |    approx_kl            | 6.0097984e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.53e+07      |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -0.000427     |
# |    value_loss           | 9.81e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2989          |
# |    iterations           | 19            |
# |    time_elapsed         | 13            |
# |    total_timesteps      | 38912         |
# | train/                  |               |
# |    approx_kl            | 5.1841344e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.38e+07      |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -0.000385     |
# |    value_loss           | 9.88e+07      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2986         |
# |    iterations           | 20           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 4.160154e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.3         |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.69e+07     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.000349    |
# |    value_loss           | 9.91e+07     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2982          |
# |    iterations           | 21            |
# |    time_elapsed         | 14            |
# |    total_timesteps      | 43008         |
# | train/                  |               |
# |    approx_kl            | 4.0503655e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.99e+07      |
# |    n_updates            | 250           |
# |    policy_gradient_loss | -0.000307     |
# |    value_loss           | 9.7e+07       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2979         |
# |    iterations           | 22           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 6.570111e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.3         |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.07e+07     |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.000481    |
# |    value_loss           | 9.69e+07     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2976          |
# |    iterations           | 23            |
# |    time_elapsed         | 15            |
# |    total_timesteps      | 47104         |
# | train/                  |               |
# |    approx_kl            | 5.5533863e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.15e+07      |
# |    n_updates            | 270           |
# |    policy_gradient_loss | -0.000405     |
# |    value_loss           | 9.75e+07      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2974         |
# |    iterations           | 24           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 8.970397e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.3         |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.07e+07     |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.000646    |
# |    value_loss           | 9.68e+07     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2972          |
# |    iterations           | 25            |
# |    time_elapsed         | 17            |
# |    total_timesteps      | 51200         |
# | train/                  |               |
# |    approx_kl            | 2.3947854e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.29         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.1e+07       |
# |    n_updates            | 290           |
# |    policy_gradient_loss | -0.00028      |
# |    value_loss           | 9.62e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2969          |
# |    iterations           | 26            |
# |    time_elapsed         | 17            |
# |    total_timesteps      | 53248         |
# | train/                  |               |
# |    approx_kl            | 4.6742527e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.29         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.92e+07      |
# |    n_updates            | 300           |
# |    policy_gradient_loss | -0.000366     |
# |    value_loss           | 9.79e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2967          |
# |    iterations           | 27            |
# |    time_elapsed         | 18            |
# |    total_timesteps      | 55296         |
# | train/                  |               |
# |    approx_kl            | 3.1208212e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.29         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.92e+07      |
# |    n_updates            | 310           |
# |    policy_gradient_loss | -0.000255     |
# |    value_loss           | 9.85e+07      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2966         |
# |    iterations           | 28           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 5.378187e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.29        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.93e+07     |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.000385    |
# |    value_loss           | 9.72e+07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2964         |
# |    iterations           | 29           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 3.513749e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.29        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.9e+07      |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00026     |
# |    value_loss           | 9.5e+07      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2962         |
# |    iterations           | 30           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 3.105073e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.29        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.8e+07      |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00026     |
# |    value_loss           | 9.7e+07      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2961        |
# |    iterations           | 31          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 3.47764e-05 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.29       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.82e+07    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.000271   |
# |    value_loss           | 9.6e+07     |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2959          |
# |    iterations           | 32            |
# |    time_elapsed         | 22            |
# |    total_timesteps      | 65536         |
# | train/                  |               |
# |    approx_kl            | 4.5992405e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.29         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.11e+07      |
# |    n_updates            | 360           |
# |    policy_gradient_loss | -0.000327     |
# |    value_loss           | 9.79e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2958          |
# |    iterations           | 33            |
# |    time_elapsed         | 22            |
# |    total_timesteps      | 67584         |
# | train/                  |               |
# |    approx_kl            | 5.5290468e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.29         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.88e+07      |
# |    n_updates            | 370           |
# |    policy_gradient_loss | -0.000427     |
# |    value_loss           | 9.74e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2956          |
# |    iterations           | 34            |
# |    time_elapsed         | 23            |
# |    total_timesteps      | 69632         |
# | train/                  |               |
# |    approx_kl            | 3.3307035e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.29         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.69e+07      |
# |    n_updates            | 380           |
# |    policy_gradient_loss | -0.000289     |
# |    value_loss           | 9.59e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2955          |
# |    iterations           | 35            |
# |    time_elapsed         | 24            |
# |    total_timesteps      | 71680         |
# | train/                  |               |
# |    approx_kl            | 5.9459446e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.29         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.1e+07       |
# |    n_updates            | 390           |
# |    policy_gradient_loss | -0.000421     |
# |    value_loss           | 9.68e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2954          |
# |    iterations           | 36            |
# |    time_elapsed         | 24            |
# |    total_timesteps      | 73728         |
# | train/                  |               |
# |    approx_kl            | 4.4205866e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.29         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.06e+07      |
# |    n_updates            | 400           |
# |    policy_gradient_loss | -0.000381     |
# |    value_loss           | 9.45e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2953          |
# |    iterations           | 37            |
# |    time_elapsed         | 25            |
# |    total_timesteps      | 75776         |
# | train/                  |               |
# |    approx_kl            | 0.00011465215 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.29         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.77e+07      |
# |    n_updates            | 410           |
# |    policy_gradient_loss | -0.000767     |
# |    value_loss           | 9.62e+07      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2952         |
# |    iterations           | 38           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 7.383182e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.29        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.5e+07      |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.000564    |
# |    value_loss           | 9.39e+07     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2952          |
# |    iterations           | 39            |
# |    time_elapsed         | 27            |
# |    total_timesteps      | 79872         |
# | train/                  |               |
# |    approx_kl            | 1.9688421e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.29         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.4e+07       |
# |    n_updates            | 430           |
# |    policy_gradient_loss | -0.000153     |
# |    value_loss           | 9.7e+07       |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2951          |
# |    iterations           | 40            |
# |    time_elapsed         | 27            |
# |    total_timesteps      | 81920         |
# | train/                  |               |
# |    approx_kl            | 1.9813655e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.29         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.3e+07       |
# |    n_updates            | 440           |
# |    policy_gradient_loss | -0.000176     |
# |    value_loss           | 9.71e+07      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2950         |
# |    iterations           | 41           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 3.461665e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.29        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.05e+07     |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.000305    |
# |    value_loss           | 9.64e+07     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2949          |
# |    iterations           | 42            |
# |    time_elapsed         | 29            |
# |    total_timesteps      | 86016         |
# | train/                  |               |
# |    approx_kl            | 5.6838413e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.29         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.43e+07      |
# |    n_updates            | 460           |
# |    policy_gradient_loss | -0.000461     |
# |    value_loss           | 9.35e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2949          |
# |    iterations           | 43            |
# |    time_elapsed         | 29            |
# |    total_timesteps      | 88064         |
# | train/                  |               |
# |    approx_kl            | 5.7202502e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.29         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.28e+07      |
# |    n_updates            | 470           |
# |    policy_gradient_loss | -0.000465     |
# |    value_loss           | 9.43e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2948          |
# |    iterations           | 44            |
# |    time_elapsed         | 30            |
# |    total_timesteps      | 90112         |
# | train/                  |               |
# |    approx_kl            | 7.0095615e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.29         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.22e+07      |
# |    n_updates            | 480           |
# |    policy_gradient_loss | -0.000541     |
# |    value_loss           | 9.53e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2947          |
# |    iterations           | 45            |
# |    time_elapsed         | 31            |
# |    total_timesteps      | 92160         |
# | train/                  |               |
# |    approx_kl            | 3.8257218e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.29         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.82e+07      |
# |    n_updates            | 490           |
# |    policy_gradient_loss | -0.000272     |
# |    value_loss           | 9.44e+07      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2947         |
# |    iterations           | 46           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 6.089278e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.29        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.71e+07     |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.000389    |
# |    value_loss           | 9.59e+07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2946         |
# |    iterations           | 47           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 5.944434e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.29        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.38e+07     |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.000393    |
# |    value_loss           | 9.77e+07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2946         |
# |    iterations           | 48           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 6.860157e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.29        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.78e+07     |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.000481    |
# |    value_loss           | 9.67e+07     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2945          |
# |    iterations           | 49            |
# |    time_elapsed         | 34            |
# |    total_timesteps      | 100352        |
# | train/                  |               |
# |    approx_kl            | 4.8998103e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.29         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.95e+07      |
# |    n_updates            | 530           |
# |    policy_gradient_loss | -0.000362     |
# |    value_loss           | 9.62e+07      |
# -------------------------------------------

# %%
model.save(model_path)

# %%
model = PPO.load(model_path, env = env)

env = SS_Mngmt_Env(render_mode="human")

evaluate_policy(model, env, n_eval_episodes=1, render=True, return_episode_rewards=True)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# /Users/jonasrenfer/miniconda3/envs/rl-scm/lib/python3.12/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# /var/folders/cz/9b93tcz93vxcjrq9_cqhnl3r0000gn/T/ipykernel_36083/701566792.py:146: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots(3, 2, figsize=(12, 9)) # 1 row and 2 columns
# ([-3301.0], [30])

# %%
# predict the action based on the stock level
model.predict((30,), deterministic=True)
# Out:
# (array(1), None)
