# %% [markdown]
# Change from v0
#
# - Added more information to the observation space (expected demand)
# - Added cost for orders as well as the cost for the inventory
# - Added delivery
# - Change from stable baselines to ray rllib

# %% [markdown]
# **Importing Dependencies**

# %%
# Gymnasium imports
import gymnasium as gym 
from gymnasium import Env
from gymnasium.spaces import Discrete, Box, Dict, Tuple, MultiBinary, MultiDiscrete 

import pygame
import pygame.gfxdraw

import networkx as nx

# Import helpers
import numpy as np
import pandas as pd
import random
import os
import matplotlib.pyplot as plt
import seaborn as sns

from collections import deque

# Import stable baselines
# Probably not needed --> test ray lib instead
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import VecFrameStack, DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# **Building the environment**

# %%
class SS_Mngmt_Env(Env):

    metadata = {"render_modes": ["human"], "render_fps": 4}
    
    # Define the action and observation space
    def __init__(self, render_mode = None):

        # To implement
        # storage capacities
        # campaign size
        # safety stock

        self.I = 30 # Initial stock level

        # Demand
        self.expected_demand = 6 # Expected demand for production
        self.actual_demand = 6 # Actual demand for production

        # Costs
        self.c_fixed = 50 # Fixed costs for ordering
        self.c_variable = 1 # Variable costs for ordering per unit
        self.p = 1 # Cost for storing each item
        self.stockout_cost = 1000 # Cost of stockout

        self.episode_length = 29 # Length of the episode

        # Order delay and queue
        self.order_delay = 3
        self.order_queue = deque(maxlen = self.order_delay)

        self.delivered = 0  # Delivered stock
        
        # Define action space
        # Change the action space for different campaign sizes
        self.action_space = Discrete(10)
        
        # Define observation space (Stock level) --> to add expected demand, etc.
        self.observation_space = Box(low = np.array([0, 0]), 
                                     high = np.array([100, 10]),
                                     dtype = np.int64)

        # Define the initial state
        self.state = np.array([self.I, self.expected_demand])

        # History
        self.reward_history = []
        self.stock_history = []
        self.demand_history = []
        self.expected_demand_history = []
        self.order_history = []
        self.delivery_history = []

        # Empty dataframe for plotting the history and analysis
        self.history = pd.DataFrame(columns = ['Stock Level', 'Order', 'Demand'])

        self.render_mode = render_mode
        self.screen_initialized = False


    # Defining the step function
    def step(self, action):
        # Returns the next state, reward and whether the episode is done

        # To Do: Campaign Size
        # To Do: Demand can only be fullfilled if sufficient stock is available demand is then placed in the backlog queue

        # Demand for production --> random for now
        self.demand = self.state[1] + random.randint(-1, 1)

        # Subtract the demand from the stock
        self.state[0] = self.state[0] - self.demand

        # If there are enough steps passed since the order was placed, add the order to the stock
        if len(self.order_queue) == self.order_delay:
            self.delivered = self.order_queue.popleft()
            self.state[0] += self.delivered
        
        # Add the order to the queue
        self.order_queue.append(action)

        # Calculate the reward based on order costs
        if action > 0:
            reward = - self.c_fixed - self.c_variable * action
        else:
            reward = 0

        # Check if the stock level is negative
        if self.state[0] <= 0:
            # If the stock level is negative, the cost is the stockout cost
            reward = reward - self.stockout_cost
        else:
            # If the stock level is positive, the cost is the stock level
            reward = reward - self.state[0]

        # Calculate the cost of the stock
        # Reward is negative since we want to minimize the cost
        # reward = float(reward - (self.state))

        # Check if the episode is done
        done = self.episode_length == 0

        # Decrease the episode length
        self.episode_length -= 1

        obs = np.array([self.state[0], self.state[1]])

        # Append the state to the history
        self.reward_history.append(reward)
        self.stock_history.append(self.state[0])
        self.order_history.append(action)
        self.demand_history.append(self.demand)
        self.expected_demand_history.append(self.state[1])
        self.delivery_history.append(self.delivered)

        # Check if episode is done
        if self.episode_length <= 0: 
            done = True
        else:
            done = False

        # Set placeholder for info
        info = {}

        # Check if the episode is truncated
        truncated = False

        return obs, float(reward), done, truncated, info

    def render(self):
        # Just check episode lenghth and only plot the last one when using matplotlib          
        if self.render_mode is not None:
            if self.render_mode == "human":
                self.render_human()
                # self.render_pygame()

    def render_human(self):

        # To Do
        # Actual vs. Expected Demand

        # Create a list of timestamps for the order history
        timestamps = np.arange(len(self.order_history))

        # Setting up the plot
        fig, ax = plt.subplots(3, 2, figsize=(12, 9)) # 1 row and 2 columns
        bar_width = 0.35
        
        # Plotting the stock level
        ax[0, 0].plot(self.stock_history, color = 'blue', label = 'Stock Level')
        ax[0, 0].set_ylabel('Stock Level')
        # ax[0, 0].set_xlabel('Time')
        ax[0, 0].set_title('Stock Level vs. Time')
        ax[0, 0].set_xticks(np.arange(0, 30, step=5))
        ax[0, 0].set_yticks(np.arange(0, 100, step=10))

        # Plotting the order, delivered and demand
        ax[1, 0].bar(timestamps - bar_width, self.order_history, bar_width, color='blue', alpha = 0.5, label='Order')
        ax[1, 0].bar(timestamps, self.delivery_history, bar_width, color='red', alpha = 0.5, label='Delivery')
        ax[1, 0].bar(timestamps + bar_width, self.demand_history, bar_width, color='green', alpha=0.5, label='Demand')
        ax[1, 0].set_ylabel('Order/Delivery/Demand')
        ax[1, 0].set_title('Order vs. Delivery vs. Demand')
        ax[1, 0].set_xticks(np.arange(0, 30, step=5))
        ax[1, 0].legend(['Order', 'Delivery', 'Demand'])

        # Plotting the reward per timestep
        ax[0, 1].plot(self.reward_history, color = 'purple', label = 'Reward')
        ax[0, 1].set_ylabel('Reward')
        # ax[0, 1].set_xlabel('Time')
        ax[0, 1].set_title('Reward vs. Time')
        ax[0, 1].set_xticks(np.arange(0, 30, step=5))

        # Plotting the accumulated reward
        ax[1, 1].plot(np.cumsum(self.reward_history), color = 'orange', label = 'Accumulated Reward')
        ax[1, 1].set_ylabel('Accumulated Reward')
        # ax[1, 1].set_xlabel('Time')
        ax[1, 1].set_title('Accumulated Reward vs. Time')
        ax[1, 1].set_xticks(np.arange(0, 30, step=5))

        # Plotting the expected demand and actual demand
        ax[2, 0].plot(self.expected_demand_history, color = 'blue', label = 'Expected Demand')
        ax[2, 0].plot(self.demand_history, color = 'green', label = 'Actual Demand')
        ax[2, 0].set_ylabel('Demand')
        ax[2, 0].set_title('Expected vs. Actual Demand')
        ax[2, 0].set_xticks(np.arange(0, 30, step=5))

        # Show the plot if the episode is done
        if self.episode_length == 0:
            # plt.tight_layout()
            plt.show()
        
        return


    def reset(self, seed = None):
        # Reset the state of the environment back to an initial state

        super().reset(seed = seed) # Reset the seed
        if seed is not None:
            random.seed(seed)

        # Reset the episode length
        self.episode_length = 29

        # Reset the order queue
        self.order_queue.clear()

        # Define the initial state
        self.state = np.array([self.I, self.expected_demand])

        obs = np.array([self.state[0], self.expected_demand])

        # # Append history to the dataframe
        # self.history['Stock Level'] = self.stock_history
        # self.history['Order'] = self.stock_history
        # self.history['Demand'] = self.demand_history

        # Reset the history
        self.reward_history = []
        self.stock_history = []
        self.order_history = []
        self.demand_history = []
        self.expected_demand_history = []
        self.delivery_history = []

        # Placeholder for info
        info = {}

        return obs, info

# %% [markdown]
# **Testng the environment**

# %%
from stable_baselines3.common.env_checker import check_env

env = SS_Mngmt_Env(render_mode="human")
check_env(env, warn=True)

# %%
env = SS_Mngmt_Env(render_mode="human")

episodes = 1
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        action = env.action_space.sample()
        n_state, reward, done, info, _ = env.step(action)
        score+=reward

        # print('Step:{} Score:{} Stock:{} Order:{} Demand:{}'.format(env.episode_length, score, n_state, action, env.demand))

    env.render()

    # print(env.order_history)

# %%
episodes = 10
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        action = env.action_space.sample()
        n_state, reward, done, info, _ = env.step(action)
        score+=reward
    print('Episode:{} Score:{} Stock:{} Last Action:{}'.format(episode, score, n_state, action))
# Out:
# Episode:1 Score:-2560.0 Stock:[77] Last Action:2
# Episode:2 Score:-2093.0 Stock:[63] Last Action:1
# Episode:3 Score:-3017.0 Stock:[57] Last Action:0
# Episode:4 Score:-3256.0 Stock:[125] Last Action:2
# Episode:5 Score:-2971.0 Stock:[119] Last Action:1
# Episode:6 Score:-2163.0 Stock:[32] Last Action:2
# Episode:7 Score:-2316.0 Stock:[54] Last Action:0
# Episode:8 Score:-2928.0 Stock:[73] Last Action:2
# Episode:9 Score:-2936.0 Stock:[69] Last Action:2
# Episode:10 Score:-2293.0 Stock:[76] Last Action:2

# %% [markdown]
# **Train Model**

# %%
log_path = os.path.join('Training', 'Logs')
model_path = os.path.join('Training', 'Models', 'PPO')

# %%
env = SS_Mngmt_Env(render_mode="human")

# wrapping the environment in a vectorized environment
env = DummyVecEnv([lambda: env])

model = PPO("MlpPolicy", env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=100000)
# Out:
# Logging to Training/Logs/PPO_5
# -----------------------------
# | time/              |      |
# |    fps             | 6709 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4067        |
# |    iterations           | 2           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.000283825 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.3        |
# |    explained_variance   | 1.9e-05     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.09e+07    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00243    |
# |    value_loss           | 6.29e+07    |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3574          |
# |    iterations           | 3             |
# |    time_elapsed         | 1             |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.00015298915 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | 3.37e-05      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.32e+07      |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.00164      |
# |    value_loss           | 7.02e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3391          |
# |    iterations           | 4             |
# |    time_elapsed         | 2             |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 0.00013312182 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | 6.14e-06      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.89e+07      |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -0.00129      |
# |    value_loss           | 6.72e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3287          |
# |    iterations           | 5             |
# |    time_elapsed         | 3             |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 0.00023591288 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | 1.97e-06      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.73e+07      |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.00198      |
# |    value_loss           | 5.88e+07      |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3209        |
# |    iterations           | 6           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.000299096 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.3        |
# |    explained_variance   | 9.54e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.76e+07    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00223    |
# |    value_loss           | 5.92e+07    |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3168          |
# |    iterations           | 7             |
# |    time_elapsed         | 4             |
# |    total_timesteps      | 14336         |
# | train/                  |               |
# |    approx_kl            | 0.00031325108 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | 5.96e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.02e+07      |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -0.00228      |
# |    value_loss           | 5.41e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3139          |
# |    iterations           | 8             |
# |    time_elapsed         | 5             |
# |    total_timesteps      | 16384         |
# | train/                  |               |
# |    approx_kl            | 0.00031526844 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.29         |
# |    explained_variance   | 4.17e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.85e+07      |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -0.00221      |
# |    value_loss           | 5.31e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3116          |
# |    iterations           | 9             |
# |    time_elapsed         | 5             |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 0.00041625628 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.29         |
# |    explained_variance   | 2.38e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.99e+07      |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -0.00255      |
# |    value_loss           | 4.84e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3100          |
# |    iterations           | 10            |
# |    time_elapsed         | 6             |
# |    total_timesteps      | 20480         |
# | train/                  |               |
# |    approx_kl            | 0.00057423225 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.28         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.86e+07      |
# |    n_updates            | 90            |
# |    policy_gradient_loss | -0.00319      |
# |    value_loss           | 4.1e+07       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3082         |
# |    iterations           | 11           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0006405128 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.27        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.72e+07     |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00314     |
# |    value_loss           | 3.87e+07     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3069          |
# |    iterations           | 12            |
# |    time_elapsed         | 8             |
# |    total_timesteps      | 24576         |
# | train/                  |               |
# |    approx_kl            | 0.00075640104 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.26         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.06e+07      |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -0.00322      |
# |    value_loss           | 3.8e+07       |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3055          |
# |    iterations           | 13            |
# |    time_elapsed         | 8             |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 0.00063039875 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.25         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.38e+07      |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.0032       |
# |    value_loss           | 3.2e+07       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3046         |
# |    iterations           | 14           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0007417608 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.24        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.38e+07     |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.003       |
# |    value_loss           | 2.93e+07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3038         |
# |    iterations           | 15           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0009826914 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.23        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.75e+07     |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00363     |
# |    value_loss           | 3.46e+07     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3029        |
# |    iterations           | 16          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.001883145 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.19       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.98e+06    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0044     |
# |    value_loss           | 1.82e+07    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3023         |
# |    iterations           | 17           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0054170797 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.13        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.35e+06     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00598     |
# |    value_loss           | 1.08e+07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3015         |
# |    iterations           | 18           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0038660238 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.07        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.7e+06      |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00484     |
# |    value_loss           | 7.65e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3011         |
# |    iterations           | 19           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0057683494 |
# |    clip_fraction        | 0.00313      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.99        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.73e+06     |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.0049      |
# |    value_loss           | 2.81e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3005         |
# |    iterations           | 20           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0036479314 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.21e+06     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00321     |
# |    value_loss           | 4.38e+06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3001        |
# |    iterations           | 21          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.005709428 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.91       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.11e+06    |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00266    |
# |    value_loss           | 3.15e+06    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2997         |
# |    iterations           | 22           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0027399487 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.84        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.22e+05     |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00288     |
# |    value_loss           | 2.97e+06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2992        |
# |    iterations           | 23          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.014787253 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.91       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.05e+05    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00931    |
# |    value_loss           | 6.91e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2989        |
# |    iterations           | 24          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.004270622 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.95       |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.37e+06    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00357    |
# |    value_loss           | 2.08e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2985        |
# |    iterations           | 25          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.012285679 |
# |    clip_fraction        | 0.0619      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.02       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.86e+05    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00795    |
# |    value_loss           | 5.51e+05    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2982         |
# |    iterations           | 26           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0063768006 |
# |    clip_fraction        | 0.0231       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.02        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.03e+05     |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00446     |
# |    value_loss           | 1.02e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2979         |
# |    iterations           | 27           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0053616306 |
# |    clip_fraction        | 0.00576      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2           |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.18e+06     |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00529     |
# |    value_loss           | 2.39e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2976         |
# |    iterations           | 28           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0072036535 |
# |    clip_fraction        | 0.00884      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.67e+05     |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00416     |
# |    value_loss           | 1.47e+06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2974        |
# |    iterations           | 29          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.012162605 |
# |    clip_fraction        | 0.0589      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.99       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.16e+05    |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00811    |
# |    value_loss           | 5.52e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2971        |
# |    iterations           | 30          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.011465414 |
# |    clip_fraction        | 0.0629      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.06       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.63e+05    |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00776    |
# |    value_loss           | 5.02e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2969        |
# |    iterations           | 31          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.002273115 |
# |    clip_fraction        | 0.00762     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.08       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.92e+06    |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00285    |
# |    value_loss           | 1.33e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2967        |
# |    iterations           | 32          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.002330652 |
# |    clip_fraction        | 0.0084      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.07       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.66e+05    |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0032     |
# |    value_loss           | 1.26e+06    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2966         |
# |    iterations           | 33           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0033572635 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.04        |
# |    explained_variance   | -2.38e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.47e+06     |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00319     |
# |    value_loss           | 3.74e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2964         |
# |    iterations           | 34           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0072657205 |
# |    clip_fraction        | 0.00459      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2           |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.25e+06     |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00552     |
# |    value_loss           | 2.63e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2963         |
# |    iterations           | 35           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0020443143 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.98        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.14e+06     |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00162     |
# |    value_loss           | 1.8e+06      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2961        |
# |    iterations           | 36          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.008747784 |
# |    clip_fraction        | 0.0194      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.97       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.36e+05    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00477    |
# |    value_loss           | 1.69e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2960        |
# |    iterations           | 37          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.009926056 |
# |    clip_fraction        | 0.0319      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.99       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.16e+05    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00514    |
# |    value_loss           | 4.9e+05     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2958        |
# |    iterations           | 38          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.008017845 |
# |    clip_fraction        | 0.0198      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.97       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.53e+05    |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00317    |
# |    value_loss           | 4.62e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2957        |
# |    iterations           | 39          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.003154858 |
# |    clip_fraction        | 0.00293     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.97       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.16e+05    |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00209    |
# |    value_loss           | 7.82e+05    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2955         |
# |    iterations           | 40           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0023530317 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.26e+06     |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00211     |
# |    value_loss           | 2.37e+06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2954        |
# |    iterations           | 41          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.008702357 |
# |    clip_fraction        | 0.00752     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.93       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.22e+05    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00357    |
# |    value_loss           | 5.42e+05    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2953         |
# |    iterations           | 42           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0027047985 |
# |    clip_fraction        | 4.88e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.53e+05     |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.0037      |
# |    value_loss           | 1.53e+06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2952        |
# |    iterations           | 43          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.009883534 |
# |    clip_fraction        | 0.042       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.9        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.54e+05    |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00758    |
# |    value_loss           | 7.52e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2950        |
# |    iterations           | 44          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.006952865 |
# |    clip_fraction        | 0.0274      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.9        |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.31e+05    |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00536    |
# |    value_loss           | 4.45e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2950        |
# |    iterations           | 45          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.011941221 |
# |    clip_fraction        | 0.0413      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.86       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.53e+05    |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00707    |
# |    value_loss           | 1.37e+06    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2946         |
# |    iterations           | 46           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0061310004 |
# |    clip_fraction        | 0.00693      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.91        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.02e+05     |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00294     |
# |    value_loss           | 5.2e+05      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2945        |
# |    iterations           | 47          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.007601382 |
# |    clip_fraction        | 0.052       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2          |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.91e+05    |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00639    |
# |    value_loss           | 6.09e+05    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2944       |
# |    iterations           | 48         |
# |    time_elapsed         | 33         |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.00748991 |
# |    clip_fraction        | 0.0315     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.94      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.57e+06   |
# |    n_updates            | 470        |
# |    policy_gradient_loss | -0.0065    |
# |    value_loss           | 3e+06      |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2943         |
# |    iterations           | 49           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0028741541 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.93        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.91e+06     |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00311     |
# |    value_loss           | 1.47e+06     |
# ------------------------------------------

# %%
model.save(model_path)

# %%
model = PPO.load(model_path, env = env)

env = SS_Mngmt_Env(render_mode="human")

evaluate_policy(model, env, n_eval_episodes=1, render=True, return_episode_rewards=True)
# Out:
# /Users/jonasrenfer/miniconda3/envs/rl-scm/lib/python3.12/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# /var/folders/cz/9b93tcz93vxcjrq9_cqhnl3r0000gn/T/ipykernel_36083/3444737716.py:146: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots(3, 2, figsize=(12, 9)) # 1 row and 2 columns
# ([-2901.0], [30])

# %%
# predict the action based on the stock level
model.predict((30,), deterministic=True)
# Out:
# (array(1), None)
